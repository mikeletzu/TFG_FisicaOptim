# %%
#Importación de funciones de los diferentes archivos
import pandas as pd
import numpy as np

df = pd.read_csv('data/clothDataset_35_.csv') 

# Guardo solo las columnas de interés (xyz) y las primeras 100 filas para visualizar mejor el dataset
"""
df_cleaned = df.filter(regex=r'^[xyz]\d+$')
df_cleaned = df_cleaned.drop([0, 1])
df_cleaned = df_cleaned.iloc[:100]
df_cleaned.to_csv('data/clothDataset_37_mini.csv', index=False)
"""
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\mikel\AppData\Local\Temp\ipykernel_21708\2146542588.py:8: SyntaxWarning: invalid escape sequence '\d'
#   """
# "\ndf_cleaned = df.filter(regex=r'^[xyz]\\d+$')\ndf_cleaned = df_cleaned.drop([0, 1])\ndf_cleaned = df_cleaned.iloc[:100]\ndf_cleaned.to_csv('data/clothDataset_37_mini.csv', index=False)\n"

# %%
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import torch
import os, os.path

featureNum = 4

class ClothDataset(Dataset):
    def __init__(self, csv_data, num_vertices=6):
        """
        Args:
            csv_data (str or filepath): Path to the CSV file or raw CSV string.
            num_vertices (int): Number of vertices per frame.
        """
        # Load the CSV data into a pandas DataFrame
        #if isinstance(csv_data, str) and "frame,x0" in csv_data:
            #self.data = pd.read_csv(io.StringIO(csv_data.strip()))
        #else:
            #self.data = pd.read_csv(csv_data)
        self.data = csv_data
            
        #quick fix para espacios en primera fila
        self.data.columns = self.data.columns.str.strip()
        
        self.num_vertices = num_vertices
        
        # Define the base feature names to extract per vertex
        self.feature_prefixes = ['x', 'y', 'z', 'sdf']#, 'vx', 'vy', 'vz', 'nx', 'ny', 'nz', 'md', 'u', 'v']

        self.position_prefixes = ['x', 'y', 'z']
        self.output_positions = self.data.filter(regex=r'^[xyz]\d+$')

        # Quitamos primera fila de outputs (no es el output de nada) y ultima fila de input (no tiene output)
        self.output_positions = self.output_positions.iloc[1:]
        self.data = self.data.iloc[:-1]

        

    def __len__(self):
        # The number of items is the number of frames (rows) in the dataset
        return len(self.data)
    
    def num_features(self):
        # Number of columns in a row (pos, vel, sdf, uv per vertex)
        return len(self.feature_prefixes)
    
    def num_vertex(self):
        return self.num_vertices
    
    def _get_frame_output_tensor(self, idx):
         row = self.output_positions.iloc[idx]
         frame_data = []
         for i in range(self.num_vertices):
            vertex_cols = [f"{prefix}{i}" for prefix in self.position_prefixes]
            vertex_features = row[vertex_cols].values.astype(np.float32)
            frame_data.append(vertex_features)

         tensor_data = torch.tensor(np.array(frame_data))

         return tensor_data
    
    def _get_frame_tensor(self, idx):
        row = self.data.iloc[idx]
        frame_data = []

        for i in range(self.num_vertices):
            vertex_cols = [f"{prefix}{i}" for prefix in self.feature_prefixes]
            vertex_features = row[vertex_cols].values.astype(np.float32)
            frame_data.append(vertex_features)

        tensor_data = torch.tensor(np.array(frame_data))

        return tensor_data
        
    def __getitem__(self, idx):
        frame_t = self._get_frame_tensor(idx)
        frame_t1 = self._get_frame_output_tensor(idx) # +1 ya no TODO: Pillar solo las columnas de pos

        return frame_t, frame_t1

# --- Example Usage ---
dataset = ClothDataset(df)
dataloader = DataLoader(dataset, batch_size=4, shuffle=False)

for batch_data, batch_frames in dataloader:
    print(f"Batch Shape: {batch_data.shape}")
    print(batch_data)
    print(batch_frames)
    break
# Out:
# Batch Shape: torch.Size([4, 6, 4])
# tensor([[[ 0.0000e+00,  0.0000e+00, -2.2550e-01,  5.4967e-01],
#          [ 0.0000e+00, -5.0000e-01,  2.2550e-01,  5.5176e-01],
#          [ 0.0000e+00, -5.0000e-01, -2.2550e-01,  4.6219e-01],
#          [ 0.0000e+00,  0.0000e+00,  2.2550e-01,  6.3234e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01,  8.3334e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01,  8.9936e-01]],
#
#         [[ 0.0000e+00,  0.0000e+00, -2.2550e-01,  5.3507e-01],
#          [ 0.0000e+00, -5.0000e-01,  2.2550e-01,  5.3719e-01],
#          [ 0.0000e+00, -5.0000e-01, -2.2550e-01,  4.4624e-01],
#          [ 0.0000e+00,  0.0000e+00,  2.2550e-01,  6.1883e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01,  8.2188e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01,  8.8844e-01]],
#
#         [[ 0.0000e+00,  2.5947e-05, -2.2544e-01,  5.2053e-01],
#          [ 0.0000e+00, -4.9992e-01,  2.2560e-01,  5.2271e-01],
#          [ 0.0000e+00, -5.0006e-01, -2.2546e-01,  4.3030e-01],
#          [ 0.0000e+00,  7.9979e-05,  2.2558e-01,  6.0544e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01,  8.1052e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01,  8.7763e-01]],
#
#         [[ 0.0000e+00,  2.5947e-05, -2.2544e-01,  5.2053e-01],
#          [ 0.0000e+00, -4.9992e-01,  2.2560e-01,  5.2271e-01],
#          [ 0.0000e+00, -5.0006e-01, -2.2546e-01,  4.3030e-01],
#          [ 0.0000e+00,  7.9979e-05,  2.2558e-01,  6.0544e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01,  8.1052e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01,  8.7763e-01]]])
# tensor([[[ 0.0000e+00,  0.0000e+00, -2.2550e-01],
#          [ 0.0000e+00, -5.0000e-01,  2.2550e-01],
#          [ 0.0000e+00, -5.0000e-01, -2.2550e-01],
#          [ 0.0000e+00,  0.0000e+00,  2.2550e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01]],
#
#         [[ 0.0000e+00,  2.5947e-05, -2.2544e-01],
#          [ 0.0000e+00, -4.9992e-01,  2.2560e-01],
#          [ 0.0000e+00, -5.0006e-01, -2.2546e-01],
#          [ 0.0000e+00,  7.9979e-05,  2.2558e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01]],
#
#         [[ 0.0000e+00,  2.5947e-05, -2.2544e-01],
#          [ 0.0000e+00, -4.9992e-01,  2.2560e-01],
#          [ 0.0000e+00, -5.0006e-01, -2.2546e-01],
#          [ 0.0000e+00,  7.9979e-05,  2.2558e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01]],
#
#         [[ 0.0000e+00,  2.5947e-05, -2.2544e-01],
#          [ 0.0000e+00, -4.9992e-01,  2.2560e-01],
#          [ 0.0000e+00, -5.0006e-01, -2.2546e-01],
#          [ 0.0000e+00,  7.9979e-05,  2.2558e-01],
#          [ 0.0000e+00,  5.0000e-01, -2.2550e-01],
#          [ 0.0000e+00,  5.0000e-01,  2.2550e-01]]])

# %%
import torch.nn as nn
import torch.nn.functional as F #acceso rapido a funciones
import torch.utils.data as data #cargar y manejar el training data

class MyModule(nn.Module):

    def __init__(self, num_inputs, num_hidden, num_outputs):
        super().__init__()
        # Some init for my module
        self.linear1 = nn.Linear(num_inputs, num_hidden)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(num_hidden, num_outputs)

    def forward(self, x):
        # Function for performing the calculation of the module.
        
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        #print(x)
        return x

    #backward se hace automaticamente, podriamos definirla tmbn 

#tmbn clases DataSet y DataLoader

# definir modelo, loss function y optimizer
#TODO: buscar dimensiones reales de las neuronas

# nn.Linear in PyTorch is designed to handle 3D tensors seamlessly.  
# When a 3D input tensor (e.g., batch_size, sequence_length, features) is provided,
#  the layer applies the linear transformation only to the last dimension (the features dimension),
#  preserving all other dimensions.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
import numpy as np

# NO SPLITEAMOS LOS DATOS
train_dataset = dataset

#CONTRA MAS GRANDE EL DATASET MAS GRANDE EL BATCH_SIZE Q PODEMOS USAR
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(train_dataset, batch_size=32, shuffle=False) # No need to shuffle test data

# 2. COMPUTE GLOBAL STATS (Only on training data to prevent data leakage)
# Correct Python logic for mean/std
all_inputs = []
all_targets = []

for batch_t, batch_t1 in dataloader:
    # Flatten batch and vertices: (Batch * Vertices, Features)
    all_inputs.append(batch_t.view(-1, featureNum))
    
    # Do the same for targets (displacements)
    pos_t = batch_t[..., 0:3]
    delta = batch_t1 - pos_t
    all_targets.append(delta.view(-1, 3))

# Combine everything
full_input_tensor = torch.cat(all_inputs, dim=0)
full_target_tensor = torch.cat(all_targets, dim=0)

# Calculate Global Stats
input_mean = full_input_tensor.mean(dim=0)
input_std = full_input_tensor.std(dim=0)
target_mean = full_target_tensor.mean(dim=0)
target_std = full_target_tensor.std(dim=0)

# Save to JSON
norm_data = {
    "mean": input_mean.tolist(),
    "std": input_std.tolist(),
    "target_mean": target_mean.tolist(),
    "target_std": target_std.tolist()
}
# ... save as json ...
import json

with open("cloth_norm_params.json", "w") as f:
    json.dump(norm_data, f)

# 3. SETUP MODEL
model = MyModule(num_inputs=featureNum, num_hidden=64, num_outputs=3)
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
print("start training")

# 4. TRAINING & TESTING LOOP
epochs = 50
for epoch in range(epochs):
    
    # --- TRAINING PHASE ---
    model.train() # Set model to training mode
    train_loss = 0.0
    
    for batch_t, batch_t1 in train_loader:
        batch_t = batch_t.float()

        batch_t1 = batch_t1.float()

        # Normalize Input globally
        batch_t_norm = (batch_t - input_mean) / input_std

        # Target is the DISPLACEMENT (Delta), not the absolute position
        positions_t = batch_t[..., 0:3] 
        target_delta = batch_t1 - positions_t

        target_delta_norm = (target_delta - target_mean) / target_std

        pred_delta = model(batch_t_norm)
        loss = criterion(pred_delta, target_delta_norm)

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        
        train_loss += loss.item()
        
    print(f'Train Epoch {epoch+1:03d}')
        
    avg_train_loss = train_loss / len(train_loader)

    # --- TESTING/VALIDATION PHASE ---
    model.eval() # Set model to evaluation mode
    test_loss = 0.0
    total_distance_error = 0.0
    total_vertices = 0

    all_pred_deltas = []
    all_target_deltas = []

    all_pred_pos = []
    all_target_pos = []
    
    with torch.no_grad(): # Disable gradient calculation for testing (saves memory & speeds up)
        for batch_t, batch_t1 in test_loader:
            batch_t = batch_t.float()
            batch_t1 = batch_t1.float()

            batch_t_norm = (batch_t - input_mean) / input_std
            
            positions_t = batch_t[..., 0:3] 
            target_delta = batch_t1 - positions_t            
            target_delta_norm = (target_delta - target_mean) / target_std

            pred_delta = model(batch_t_norm)
            loss = criterion(pred_delta, target_delta_norm)
            test_loss += loss.item()

            # --- NEW: Reconstruct the absolute positions ---
            #pred_pos = positions_t + (pred_delta * input_std[..., 0:3]  + input_mean[..., 0:3]) #DESNORMALIZAR!
            pred_pos = positions_t + (pred_delta * target_std  + target_mean) #DESNORMALIZAR!
            target_pos = batch_t1[..., 0:3] # The true final position

            # Store them
            all_pred_pos.append(pred_pos.cpu().numpy())
            all_target_pos.append(target_pos.cpu().numpy())
            
            # Calculate our "Accuracy" (Mean Distance Error per vertex)
            # Distance = sqrt((dx_pred - dx_true)^2 + (dy_pred - dy_true)^2 + (dz_pred - dz_true)^2)
            distances = torch.norm(pred_delta - target_delta_norm, dim=-1) # Calculates Euclidean distance
            total_distance_error += distances.sum().item()
            total_vertices += distances.numel()

            # --- NEW: Store the data for PCA ---
            # Move tensors to the CPU and convert to NumPy arrays immediately
            all_pred_deltas.append(pred_delta.cpu().numpy())
            all_target_deltas.append(target_delta_norm.cpu().numpy())

            print(f'Epoch {epoch+1:03d} | Test Loss: {test_loss:.6f} | Vertex Error: {total_distance_error:.6f} units')

    avg_test_loss = test_loss / len(test_loader)
    avg_distance_error = total_distance_error / total_vertices

    # Combine into large arrays
    # Shapes will be: (Total_Frames, Vertices, 3)
    preds_pos_np = np.concatenate(all_pred_pos, axis=0)
    targets_pos_np = np.concatenate(all_target_pos, axis=0)

    print(f'Epoch {epoch+1:03d} | Train Loss: {avg_train_loss:.6f} | Test Loss: {avg_test_loss:.6f} | Avg Vertex Error: {avg_distance_error:.6f} units')
# Out:
# start training
# Train Epoch 001
# Epoch 001 | Test Loss: 0.135700 | Vertex Error: 52.580170 units
# Epoch 001 | Test Loss: 0.484289 | Vertex Error: 182.574097 units
# Epoch 001 | Test Loss: 1.030403 | Vertex Error: 387.877335 units
# Epoch 001 | Test Loss: 1.605425 | Vertex Error: 615.775894 units
# Epoch 001 | Test Loss: 2.188661 | Vertex Error: 841.163712 units
# Epoch 001 | Test Loss: 2.884042 | Vertex Error: 1101.264999 units
# Epoch 001 | Test Loss: 3.394173 | Vertex Error: 1311.503525 units
# Epoch 001 | Test Loss: 3.899542 | Vertex Error: 1501.536575 units
# Epoch 001 | Test Loss: 4.593578 | Vertex Error: 1791.028885 units
# Epoch 001 | Test Loss: 5.268470 | Vertex Error: 2055.246689 units
# Epoch 001 | Test Loss: 5.914251 | Vertex Error: 2318.569382 units
# Epoch 001 | Test Loss: 6.551327 | Vertex Error: 2581.933640 units
# Epoch 001 | Test Loss: 7.186473 | Vertex Error: 2834.429031 units
# Epoch 001 | Test Loss: 7.901798 | Vertex Error: 3115.248703 units
# Epoch 001 | Test Loss: 8.503453 | Vertex Error: 3356.511551 units
# Epoch 001 | Test Loss: 9.102041 | Vertex Error: 3589.517426 units
# Epoch 001 | Test Loss: 9.783313 | Vertex Error: 3858.621735 units
# Epoch 001 | Test Loss: 10.512682 | Vertex Error: 4140.232574 units
# Epoch 001 | Test Loss: 11.219067 | Vertex Error: 4422.633728 units
# Epoch 001 | Test Loss: 11.909517 | Vertex Error: 4691.674805 units
# Epoch 001 | Test Loss: 12.429243 | Vertex Error: 4900.066010 units
# Epoch 001 | Test Loss: 12.974638 | Vertex Error: 5106.524002 units
# Epoch 001 | Test Loss: 13.524148 | Vertex Error: 5321.312973 units
# Epoch 001 | Test Loss: 14.002407 | Vertex Error: 5503.920090 units
# Epoch 001 | Test Loss: 14.779641 | Vertex Error: 5819.329941 units
# Epoch 001 | Test Loss: 15.355308 | Vertex Error: 6041.722275 units
# Epoch 001 | Test Loss: 15.910673 | Vertex Error: 6264.602127 units
# Epoch 001 | Test Loss: 16.753238 | Vertex Error: 6584.442398 units
# Epoch 001 | Test Loss: 17.381938 | Vertex Error: 6828.138901 units
# Epoch 001 | Test Loss: 17.969354 | Vertex Error: 7055.303223 units
# Epoch 001 | Test Loss: 18.712556 | Vertex Error: 7353.706451 units
# Epoch 001 | Test Loss: 19.266496 | Vertex Error: 7565.727783 units
# Epoch 001 | Test Loss: 19.963987 | Vertex Error: 7846.604523 units
# Epoch 001 | Test Loss: 20.661420 | Vertex Error: 8114.995483 units
# Epoch 001 | Test Loss: 21.089806 | Vertex Error: 8275.795441 units
# Epoch 001 | Test Loss: 21.727299 | Vertex Error: 8522.472931 units
# Epoch 001 | Test Loss: 22.300682 | Vertex Error: 8737.447083 units
# Epoch 001 | Test Loss: 22.852632 | Vertex Error: 8946.380585 units
# Epoch 001 | Test Loss: 23.418676 | Vertex Error: 9164.903503 units
# Epoch 001 | Test Loss: 23.937447 | Vertex Error: 9368.792877 units
# Epoch 001 | Test Loss: 24.764767 | Vertex Error: 9710.269440 units
# Epoch 001 | Test Loss: 25.469839 | Vertex Error: 10004.593384 units
# Epoch 001 | Test Loss: 26.059690 | Vertex Error: 10234.721054 units
# Epoch 001 | Test Loss: 26.774591 | Vertex Error: 10509.601181 units
# Epoch 001 | Test Loss: 27.417157 | Vertex Error: 10745.770050 units
# Epoch 001 | Test Loss: 27.970154 | Vertex Error: 10957.584839 units
# Epoch 001 | Test Loss: 28.495358 | Vertex Error: 11160.196060 units
# Epoch 001 | Test Loss: 29.044573 | Vertex Error: 11375.683807 units
# Epoch 001 | Test Loss: 29.881974 | Vertex Error: 11701.499023 units
# Epoch 001 | Test Loss: 30.568520 | Vertex Error: 11957.380737 units
# Epoch 001 | Test Loss: 31.143424 | Vertex Error: 12174.737198 units
# Epoch 001 | Test Loss: 31.745696 | Vertex Error: 12413.425949 units
# Epoch 001 | Test Loss: 32.526500 | Vertex Error: 12719.281662 units
# Epoch 001 | Test Loss: 33.092174 | Vertex Error: 12942.152847 units
# Epoch 001 | Test Loss: 33.652059 | Vertex Error: 13164.562424 units
# Epoch 001 | Test Loss: 34.414921 | Vertex Error: 13473.964371 units
# Epoch 001 | Test Loss: 35.183506 | Vertex Error: 13775.667191 units
# Epoch 001 | Test Loss: 35.926805 | Vertex Error: 14096.374100 units
# Epoch 001 | Test Loss: 36.817082 | Vertex Error: 14443.121445 units
# Epoch 001 | Test Loss: 37.445959 | Vertex Error: 14698.874191 units
# Epoch 001 | Test Loss: 38.039035 | Vertex Error: 14920.074173 units
# Epoch 001 | Test Loss: 38.624950 | Vertex Error: 15143.124725 units
# Epoch 001 | Test Loss: 39.090434 | Vertex Error: 15316.854813 units
# Epoch 001 | Test Loss: 39.649179 | Vertex Error: 15529.098740 units
# Epoch 001 | Test Loss: 40.245317 | Vertex Error: 15757.339691 units
# Epoch 001 | Test Loss: 40.914026 | Vertex Error: 16004.517624 units
# Epoch 001 | Test Loss: 41.502200 | Vertex Error: 16230.891754 units
# Epoch 001 | Test Loss: 42.080525 | Vertex Error: 16457.676239 units
# Epoch 001 | Test Loss: 42.875871 | Vertex Error: 16763.002991 units
# Epoch 001 | Test Loss: 43.423114 | Vertex Error: 16984.997360 units
# Epoch 001 | Test Loss: 43.973590 | Vertex Error: 17196.633392 units
# Epoch 001 | Test Loss: 44.713969 | Vertex Error: 17497.234741 units
# Epoch 001 | Test Loss: 45.461997 | Vertex Error: 17802.648071 units
# Epoch 001 | Test Loss: 45.990263 | Vertex Error: 18012.343445 units
# Epoch 001 | Test Loss: 46.693518 | Vertex Error: 18286.583679 units
# Epoch 001 | Test Loss: 47.219114 | Vertex Error: 18491.693405 units
# Epoch 001 | Test Loss: 47.751004 | Vertex Error: 18693.414963 units
# Epoch 001 | Test Loss: 48.338049 | Vertex Error: 18921.741714 units
# Epoch 001 | Test Loss: 48.796857 | Vertex Error: 19097.815323 units
# Epoch 001 | Test Loss: 49.385924 | Vertex Error: 19330.630280 units
# Epoch 001 | Test Loss: 50.030859 | Vertex Error: 19570.495163 units
# Epoch 001 | Test Loss: 50.583321 | Vertex Error: 19778.511063 units
# Epoch 001 | Test Loss: 51.298379 | Vertex Error: 20058.078506 units
# Epoch 001 | Test Loss: 51.916681 | Vertex Error: 20298.026398 units
# Epoch 001 | Test Loss: 52.553581 | Vertex Error: 20541.551895 units
# Epoch 001 | Test Loss: 53.215679 | Vertex Error: 20803.875687 units
# Epoch 001 | Test Loss: 53.766632 | Vertex Error: 21026.422775 units
# Epoch 001 | Test Loss: 54.506348 | Vertex Error: 21327.558273 units
# Epoch 001 | Test Loss: 55.063160 | Vertex Error: 21548.811066 units
# Epoch 001 | Test Loss: 55.499328 | Vertex Error: 21720.295258 units
# Epoch 001 | Test Loss: 56.200138 | Vertex Error: 21991.037201 units
# Epoch 001 | Test Loss: 56.786668 | Vertex Error: 22210.811707 units
# Epoch 001 | Test Loss: 57.316711 | Vertex Error: 22410.871857 units
# Epoch 001 | Test Loss: 57.906359 | Vertex Error: 22640.575516 units
# Epoch 001 | Test Loss: 58.410139 | Vertex Error: 22838.696808 units
# Epoch 001 | Test Loss: 59.301709 | Vertex Error: 23193.691284 units
# Epoch 001 | Test Loss: 60.022932 | Vertex Error: 23477.879730 units
# Epoch 001 | Test Loss: 60.504394 | Vertex Error: 23660.056732 units
# Epoch 001 | Test Loss: 61.052323 | Vertex Error: 23875.259552 units
# Epoch 001 | Test Loss: 61.719626 | Vertex Error: 24121.662979 units
# Epoch 001 | Test Loss: 62.204618 | Vertex Error: 24308.583420 units
# Epoch 001 | Test Loss: 62.657769 | Vertex Error: 24482.801727 units
# Epoch 001 | Test Loss: 63.320761 | Vertex Error: 24752.065430 units
# Epoch 001 | Test Loss: 63.988040 | Vertex Error: 25018.334961 units
# Epoch 001 | Test Loss: 64.535956 | Vertex Error: 25245.759949 units
# Epoch 001 | Test Loss: 65.103399 | Vertex Error: 25471.601196 units
# Epoch 001 | Test Loss: 65.715663 | Vertex Error: 25710.805634 units
# Epoch 001 | Test Loss: 66.368534 | Vertex Error: 25958.905441 units
# Epoch 001 | Test Loss: 66.893879 | Vertex Error: 26169.348053 units
# Epoch 001 | Test Loss: 67.437691 | Vertex Error: 26375.227829 units
# Epoch 001 | Test Loss: 68.056954 | Vertex Error: 26630.405136 units
# Epoch 001 | Test Loss: 68.838747 | Vertex Error: 26939.528275 units
# Epoch 001 | Test Loss: 69.481440 | Vertex Error: 27191.156372 units
# Epoch 001 | Test Loss: 70.047989 | Vertex Error: 27414.379852 units
# Epoch 001 | Test Loss: 70.612799 | Vertex Error: 27627.763580 units
# Epoch 001 | Test Loss: 71.249328 | Vertex Error: 27864.474808 units
# Epoch 001 | Test Loss: 71.756934 | Vertex Error: 28062.427734 units
# Epoch 001 | Test Loss: 72.217935 | Vertex Error: 28240.501465 units
# Epoch 001 | Test Loss: 72.950092 | Vertex Error: 28547.707764 units
# Epoch 001 | Test Loss: 73.701507 | Vertex Error: 28847.603394 units
# Epoch 001 | Test Loss: 74.131885 | Vertex Error: 29026.244263 units
# Epoch 001 | Test Loss: 74.863835 | Vertex Error: 29317.174927 units
# Epoch 001 | Test Loss: 75.419062 | Vertex Error: 29534.571762 units
# Epoch 001 | Test Loss: 75.958784 | Vertex Error: 29739.110001 units
# Epoch 001 | Test Loss: 76.650740 | Vertex Error: 30012.610184 units
# Epoch 001 | Test Loss: 77.130065 | Vertex Error: 30198.920120 units
# Epoch 001 | Test Loss: 77.905839 | Vertex Error: 30518.548630 units
# Epoch 001 | Test Loss: 78.695158 | Vertex Error: 30826.045090 units
# Epoch 001 | Test Loss: 79.199973 | Vertex Error: 31025.048843 units
# Epoch 001 | Test Loss: 79.826096 | Vertex Error: 31265.042282 units
# Epoch 001 | Test Loss: 80.436542 | Vertex Error: 31494.254471 units
# Epoch 001 | Test Loss: 80.980027 | Vertex Error: 31699.459763 units
# Epoch 001 | Test Loss: 81.511693 | Vertex Error: 31906.148865 units
# Epoch 001 | Test Loss: 82.048631 | Vertex Error: 32119.120377 units
# Epoch 001 | Test Loss: 82.961385 | Vertex Error: 32489.957504 units
# Epoch 001 | Test Loss: 83.636507 | Vertex Error: 32774.321182 units
# Epoch 001 | Test Loss: 84.153731 | Vertex Error: 32977.251358 units
# Epoch 001 | Test Loss: 84.830155 | Vertex Error: 33239.492264 units
# Epoch 001 | Test Loss: 85.442714 | Vertex Error: 33467.521667 units
# Epoch 001 | Test Loss: 85.966424 | Vertex Error: 33669.790421 units
# Epoch 001 | Test Loss: 86.486513 | Vertex Error: 33873.753830 units
# Epoch 001 | Test Loss: 87.036796 | Vertex Error: 34093.615768 units
# Epoch 001 | Test Loss: 87.915849 | Vertex Error: 34439.905472 units
# Epoch 001 | Test Loss: 88.704254 | Vertex Error: 34752.183487 units
# Epoch 001 | Test Loss: 89.214098 | Vertex Error: 34947.068985 units
# Epoch 001 | Test Loss: 89.778022 | Vertex Error: 35172.882751 units
# Epoch 001 | Test Loss: 90.496107 | Vertex Error: 35450.583893 units
# Epoch 001 | Test Loss: 91.032123 | Vertex Error: 35658.904663 units
# Epoch 001 | Test Loss: 91.536446 | Vertex Error: 35855.886261 units
# Epoch 001 | Test Loss: 92.240503 | Vertex Error: 36148.902679 units
# Epoch 001 | Test Loss: 92.891161 | Vertex Error: 36406.745209 units
# Epoch 001 | Test Loss: 93.484941 | Vertex Error: 36648.333130 units
# Epoch 001 | Test Loss: 94.062228 | Vertex Error: 36878.651962 units
# Epoch 001 | Test Loss: 94.681291 | Vertex Error: 37126.458359 units
# Epoch 001 | Test Loss: 95.386410 | Vertex Error: 37399.526474 units
# Epoch 001 | Test Loss: 95.947442 | Vertex Error: 37621.544556 units
# Epoch 001 | Test Loss: 96.669261 | Vertex Error: 37684.993763 units
# Epoch 001 | Train Loss: 0.650874 | Test Loss: 0.615728 | Avg Vertex Error: 1.256418 units
# Train Epoch 002
# Epoch 002 | Test Loss: 0.097291 | Vertex Error: 36.417706 units
# Epoch 002 | Test Loss: 0.409538 | Vertex Error: 150.878712 units
# Epoch 002 | Test Loss: 0.903995 | Vertex Error: 337.936176 units
# Epoch 002 | Test Loss: 1.448585 | Vertex Error: 553.773563 units
# Epoch 002 | Test Loss: 2.004859 | Vertex Error: 767.630833 units
# Epoch 002 | Test Loss: 2.661592 | Vertex Error: 1012.397648 units
# Epoch 002 | Test Loss: 3.149531 | Vertex Error: 1213.730534 units
# Epoch 002 | Test Loss: 3.623490 | Vertex Error: 1390.926823 units
# Epoch 002 | Test Loss: 4.276608 | Vertex Error: 1665.691196 units
# Epoch 002 | Test Loss: 4.931993 | Vertex Error: 1921.816868 units
# Epoch 002 | Test Loss: 5.553953 | Vertex Error: 2174.829502 units
# Epoch 002 | Test Loss: 6.149444 | Vertex Error: 2421.462391 units
# Epoch 002 | Test Loss: 6.736962 | Vertex Error: 2656.209126 units
# Epoch 002 | Test Loss: 7.437677 | Vertex Error: 2930.972431 units
# Epoch 002 | Test Loss: 8.001730 | Vertex Error: 3156.692921 units
# Epoch 002 | Test Loss: 8.555439 | Vertex Error: 3372.715153 units
# Epoch 002 | Test Loss: 9.208568 | Vertex Error: 3632.826023 units
# Epoch 002 | Test Loss: 9.892568 | Vertex Error: 3899.074986 units
# Epoch 002 | Test Loss: 10.548040 | Vertex Error: 4165.505863 units
# Epoch 002 | Test Loss: 11.215073 | Vertex Error: 4425.477116 units
# Epoch 002 | Test Loss: 11.705858 | Vertex Error: 4621.301167 units
# Epoch 002 | Test Loss: 12.215483 | Vertex Error: 4813.738117 units
# Epoch 002 | Test Loss: 12.743463 | Vertex Error: 5019.967579 units
# Epoch 002 | Test Loss: 13.184359 | Vertex Error: 5187.890965 units
# Epoch 002 | Test Loss: 13.929385 | Vertex Error: 5491.001835 units
# Epoch 002 | Test Loss: 14.477104 | Vertex Error: 5701.799244 units
# Epoch 002 | Test Loss: 15.009075 | Vertex Error: 5915.093174 units
# Epoch 002 | Test Loss: 15.807765 | Vertex Error: 6217.071262 units
# Epoch 002 | Test Loss: 16.412348 | Vertex Error: 6450.333424 units
# Epoch 002 | Test Loss: 16.980301 | Vertex Error: 6669.599277 units
# Epoch 002 | Test Loss: 17.681968 | Vertex Error: 6951.438053 units
# Epoch 002 | Test Loss: 18.202757 | Vertex Error: 7151.578159 units
# Epoch 002 | Test Loss: 18.867449 | Vertex Error: 7420.664463 units
# Epoch 002 | Test Loss: 19.520212 | Vertex Error: 7675.146152 units
# Epoch 002 | Test Loss: 19.890076 | Vertex Error: 7815.601139 units
# Epoch 002 | Test Loss: 20.504333 | Vertex Error: 8053.306858 units
# Epoch 002 | Test Loss: 21.048430 | Vertex Error: 8255.497410 units
# Epoch 002 | Test Loss: 21.560064 | Vertex Error: 8449.163486 units
# Epoch 002 | Test Loss: 22.106268 | Vertex Error: 8659.354374 units
# Epoch 002 | Test Loss: 22.583540 | Vertex Error: 8847.691090 units
# Epoch 002 | Test Loss: 23.386121 | Vertex Error: 9179.535816 units
# Epoch 002 | Test Loss: 24.059548 | Vertex Error: 9461.054340 units
# Epoch 002 | Test Loss: 24.622337 | Vertex Error: 9680.732456 units
# Epoch 002 | Test Loss: 25.292041 | Vertex Error: 9938.303806 units
# Epoch 002 | Test Loss: 25.915860 | Vertex Error: 10166.932377 units
# Epoch 002 | Test Loss: 26.444858 | Vertex Error: 10368.074924 units
# Epoch 002 | Test Loss: 26.928834 | Vertex Error: 10555.302219 units
# Epoch 002 | Test Loss: 27.453065 | Vertex Error: 10761.404224 units
# Epoch 002 | Test Loss: 28.248685 | Vertex Error: 11071.649097 units
# Epoch 002 | Test Loss: 28.895744 | Vertex Error: 11314.261341 units
# Epoch 002 | Test Loss: 29.438620 | Vertex Error: 11520.377399 units
# Epoch 002 | Test Loss: 30.015736 | Vertex Error: 11749.207172 units
# Epoch 002 | Test Loss: 30.762731 | Vertex Error: 12040.583118 units
# Epoch 002 | Test Loss: 31.302178 | Vertex Error: 12252.997272 units
# Epoch 002 | Test Loss: 31.834941 | Vertex Error: 12465.168629 units
# Epoch 002 | Test Loss: 32.553418 | Vertex Error: 12757.575184 units
# Epoch 002 | Test Loss: 33.307723 | Vertex Error: 13053.830830 units
# Epoch 002 | Test Loss: 34.016061 | Vertex Error: 13360.764423 units
# Epoch 002 | Test Loss: 34.869513 | Vertex Error: 13693.841846 units
# Epoch 002 | Test Loss: 35.469535 | Vertex Error: 13937.755451 units
# Epoch 002 | Test Loss: 36.036332 | Vertex Error: 14148.489857 units
# Epoch 002 | Test Loss: 36.588505 | Vertex Error: 14357.272465 units
# Epoch 002 | Test Loss: 37.023442 | Vertex Error: 14519.303730 units
# Epoch 002 | Test Loss: 37.550841 | Vertex Error: 14719.996815 units
# Epoch 002 | Test Loss: 38.102946 | Vertex Error: 14932.682545 units
# Epoch 002 | Test Loss: 38.710659 | Vertex Error: 15159.652149 units
# Epoch 002 | Test Loss: 39.273068 | Vertex Error: 15376.559849 units
# Epoch 002 | Test Loss: 39.826504 | Vertex Error: 15591.970844 units
# Epoch 002 | Test Loss: 40.582523 | Vertex Error: 15881.795704 units
# Epoch 002 | Test Loss: 41.100721 | Vertex Error: 16092.919651 units
# Epoch 002 | Test Loss: 41.618929 | Vertex Error: 16291.535145 units
# Epoch 002 | Test Loss: 42.324971 | Vertex Error: 16579.060291 units
# Epoch 002 | Test Loss: 43.050696 | Vertex Error: 16875.361561 units
# Epoch 002 | Test Loss: 43.546470 | Vertex Error: 17072.736652 units
# Epoch 002 | Test Loss: 44.207569 | Vertex Error: 17330.469593 units
# Epoch 002 | Test Loss: 44.710247 | Vertex Error: 17525.996922 units
# Epoch 002 | Test Loss: 45.218204 | Vertex Error: 17717.641209 units
# Epoch 002 | Test Loss: 45.763123 | Vertex Error: 17929.064182 units
# Epoch 002 | Test Loss: 46.194765 | Vertex Error: 18095.104893 units
# Epoch 002 | Test Loss: 46.748992 | Vertex Error: 18314.559742 units
# Epoch 002 | Test Loss: 47.347551 | Vertex Error: 18539.576221 units
# Epoch 002 | Test Loss: 47.838639 | Vertex Error: 18726.624683 units
# Epoch 002 | Test Loss: 48.533720 | Vertex Error: 18998.427540 units
# Epoch 002 | Test Loss: 49.125591 | Vertex Error: 19226.097095 units
# Epoch 002 | Test Loss: 49.714526 | Vertex Error: 19451.961597 units
# Epoch 002 | Test Loss: 50.358368 | Vertex Error: 19706.790394 units
# Epoch 002 | Test Loss: 50.871700 | Vertex Error: 19914.004246 units
# Epoch 002 | Test Loss: 51.584176 | Vertex Error: 20205.501316 units
# Epoch 002 | Test Loss: 52.114068 | Vertex Error: 20415.965900 units
# Epoch 002 | Test Loss: 52.523751 | Vertex Error: 20576.379551 units
# Epoch 002 | Test Loss: 53.178505 | Vertex Error: 20828.958912 units
# Epoch 002 | Test Loss: 53.749337 | Vertex Error: 21042.608418 units
# Epoch 002 | Test Loss: 54.254020 | Vertex Error: 21232.095432 units
# Epoch 002 | Test Loss: 54.796482 | Vertex Error: 21443.415455 units
# Epoch 002 | Test Loss: 55.275952 | Vertex Error: 21633.656895 units
# Epoch 002 | Test Loss: 56.125706 | Vertex Error: 21973.943546 units
# Epoch 002 | Test Loss: 56.801793 | Vertex Error: 22244.479862 units
# Epoch 002 | Test Loss: 57.245203 | Vertex Error: 22411.855824 units
# Epoch 002 | Test Loss: 57.770311 | Vertex Error: 22616.884617 units
# Epoch 002 | Test Loss: 58.402880 | Vertex Error: 22849.465763 units
# Epoch 002 | Test Loss: 58.855294 | Vertex Error: 23024.547260 units
# Epoch 002 | Test Loss: 59.282367 | Vertex Error: 23188.142353 units
# Epoch 002 | Test Loss: 59.898335 | Vertex Error: 23440.224400 units
# Epoch 002 | Test Loss: 60.552010 | Vertex Error: 23700.987827 units
# Epoch 002 | Test Loss: 61.074952 | Vertex Error: 23917.819920 units
# Epoch 002 | Test Loss: 61.603310 | Vertex Error: 24128.621540 units
# Epoch 002 | Test Loss: 62.174525 | Vertex Error: 24352.376850 units
# Epoch 002 | Test Loss: 62.811791 | Vertex Error: 24593.907810 units
# Epoch 002 | Test Loss: 63.302527 | Vertex Error: 24790.235996 units
# Epoch 002 | Test Loss: 63.800128 | Vertex Error: 24978.579304 units
# Epoch 002 | Test Loss: 64.391491 | Vertex Error: 25224.982380 units
# Epoch 002 | Test Loss: 65.130931 | Vertex Error: 25519.850178 units
# Epoch 002 | Test Loss: 65.721238 | Vertex Error: 25754.532917 units
# Epoch 002 | Test Loss: 66.262093 | Vertex Error: 25968.222446 units
# Epoch 002 | Test Loss: 66.797259 | Vertex Error: 26168.858311 units
# Epoch 002 | Test Loss: 67.393090 | Vertex Error: 26389.583744 units
# Epoch 002 | Test Loss: 67.881456 | Vertex Error: 26579.580326 units
# Epoch 002 | Test Loss: 68.311223 | Vertex Error: 26745.067112 units
# Epoch 002 | Test Loss: 69.009336 | Vertex Error: 27039.366703 units
# Epoch 002 | Test Loss: 69.734022 | Vertex Error: 27328.158573 units
# Epoch 002 | Test Loss: 70.140650 | Vertex Error: 27496.917988 units
# Epoch 002 | Test Loss: 70.826931 | Vertex Error: 27770.042591 units
# Epoch 002 | Test Loss: 71.358637 | Vertex Error: 27978.089649 units
# Epoch 002 | Test Loss: 71.876954 | Vertex Error: 28174.035099 units
# Epoch 002 | Test Loss: 72.528769 | Vertex Error: 28431.082035 units
# Epoch 002 | Test Loss: 72.974069 | Vertex Error: 28605.176182 units
# Epoch 002 | Test Loss: 73.714040 | Vertex Error: 28912.857731 units
# Epoch 002 | Test Loss: 74.461958 | Vertex Error: 29207.274937 units
# Epoch 002 | Test Loss: 74.916379 | Vertex Error: 29388.641834 units
# Epoch 002 | Test Loss: 75.520287 | Vertex Error: 29619.682880 units
# Epoch 002 | Test Loss: 76.099930 | Vertex Error: 29835.622974 units
# Epoch 002 | Test Loss: 76.606825 | Vertex Error: 30026.848255 units
# Epoch 002 | Test Loss: 77.117085 | Vertex Error: 30224.739613 units
# Epoch 002 | Test Loss: 77.612650 | Vertex Error: 30421.799900 units
# Epoch 002 | Test Loss: 78.497996 | Vertex Error: 30782.582188 units
# Epoch 002 | Test Loss: 79.143587 | Vertex Error: 31055.639317 units
# Epoch 002 | Test Loss: 79.634092 | Vertex Error: 31248.032902 units
# Epoch 002 | Test Loss: 80.265337 | Vertex Error: 31492.311192 units
# Epoch 002 | Test Loss: 80.862594 | Vertex Error: 31714.078388 units
# Epoch 002 | Test Loss: 81.358517 | Vertex Error: 31904.514957 units
# Epoch 002 | Test Loss: 81.829412 | Vertex Error: 32089.674763 units
# Epoch 002 | Test Loss: 82.355161 | Vertex Error: 32300.827503 units
# Epoch 002 | Test Loss: 83.190895 | Vertex Error: 32631.908985 units
# Epoch 002 | Test Loss: 83.933528 | Vertex Error: 32930.014851 units
# Epoch 002 | Test Loss: 84.411418 | Vertex Error: 33112.721546 units
# Epoch 002 | Test Loss: 84.951541 | Vertex Error: 33328.030735 units
# Epoch 002 | Test Loss: 85.636460 | Vertex Error: 33591.500706 units
# Epoch 002 | Test Loss: 86.143805 | Vertex Error: 33788.510029 units
# Epoch 002 | Test Loss: 86.622905 | Vertex Error: 33974.782566 units
# Epoch 002 | Test Loss: 87.280758 | Vertex Error: 34250.850132 units
# Epoch 002 | Test Loss: 87.919440 | Vertex Error: 34503.132526 units
# Epoch 002 | Test Loss: 88.487566 | Vertex Error: 34734.113605 units
# Epoch 002 | Test Loss: 89.024230 | Vertex Error: 34948.893574 units
# Epoch 002 | Test Loss: 89.597128 | Vertex Error: 35178.697910 units
# Epoch 002 | Test Loss: 90.289101 | Vertex Error: 35445.736607 units
# Epoch 002 | Test Loss: 90.814895 | Vertex Error: 35653.382710 units
# Epoch 002 | Test Loss: 91.492747 | Vertex Error: 35712.854160 units
# Epoch 002 | Train Loss: 0.597357 | Test Loss: 0.582756 | Avg Vertex Error: 1.190667 units
# Train Epoch 003
# Epoch 003 | Test Loss: 0.073190 | Vertex Error: 28.899349 units
# Epoch 003 | Test Loss: 0.363852 | Vertex Error: 136.442638 units
# Epoch 003 | Test Loss: 0.831360 | Vertex Error: 314.072765 units
# Epoch 003 | Test Loss: 1.372179 | Vertex Error: 529.450787 units
# Epoch 003 | Test Loss: 1.918233 | Vertex Error: 740.978771 units
# Epoch 003 | Test Loss: 2.547906 | Vertex Error: 977.689297 units
# Epoch 003 | Test Loss: 3.037242 | Vertex Error: 1180.361736 units
# Epoch 003 | Test Loss: 3.498044 | Vertex Error: 1354.579250 units
# Epoch 003 | Test Loss: 4.138586 | Vertex Error: 1625.114620 units
# Epoch 003 | Test Loss: 4.789839 | Vertex Error: 1880.633572 units
# Epoch 003 | Test Loss: 5.401174 | Vertex Error: 2130.518612 units
# Epoch 003 | Test Loss: 5.983196 | Vertex Error: 2371.904369 units
# Epoch 003 | Test Loss: 6.553069 | Vertex Error: 2600.193295 units
# Epoch 003 | Test Loss: 7.244814 | Vertex Error: 2874.312740 units
# Epoch 003 | Test Loss: 7.792536 | Vertex Error: 3095.299297 units
# Epoch 003 | Test Loss: 8.324660 | Vertex Error: 3304.448879 units
# Epoch 003 | Test Loss: 8.975471 | Vertex Error: 3564.220425 units
# Epoch 003 | Test Loss: 9.641386 | Vertex Error: 3824.999660 units
# Epoch 003 | Test Loss: 10.280744 | Vertex Error: 4088.142239 units
# Epoch 003 | Test Loss: 10.940584 | Vertex Error: 4345.758450 units
# Epoch 003 | Test Loss: 11.424187 | Vertex Error: 4539.240505 units
# Epoch 003 | Test Loss: 11.913944 | Vertex Error: 4725.683147 units
# Epoch 003 | Test Loss: 12.435786 | Vertex Error: 4931.205532 units
# Epoch 003 | Test Loss: 12.867584 | Vertex Error: 5096.762249 units
# Epoch 003 | Test Loss: 13.604300 | Vertex Error: 5396.762463 units
# Epoch 003 | Test Loss: 14.139235 | Vertex Error: 5603.552990 units
# Epoch 003 | Test Loss: 14.660736 | Vertex Error: 5813.828197 units
# Epoch 003 | Test Loss: 15.447872 | Vertex Error: 6110.671032 units
# Epoch 003 | Test Loss: 16.042548 | Vertex Error: 6341.691174 units
# Epoch 003 | Test Loss: 16.597997 | Vertex Error: 6558.430965 units
# Epoch 003 | Test Loss: 17.284159 | Vertex Error: 6835.141903 units
# Epoch 003 | Test Loss: 17.797734 | Vertex Error: 7032.670528 units
# Epoch 003 | Test Loss: 18.456133 | Vertex Error: 7299.790401 units
# Epoch 003 | Test Loss: 19.088826 | Vertex Error: 7547.941708 units
# Epoch 003 | Test Loss: 19.437688 | Vertex Error: 7681.808132 units
# Epoch 003 | Test Loss: 20.044216 | Vertex Error: 7917.451321 units
# Epoch 003 | Test Loss: 20.577260 | Vertex Error: 8116.712872 units
# Epoch 003 | Test Loss: 21.066931 | Vertex Error: 8304.093380 units
# Epoch 003 | Test Loss: 21.606528 | Vertex Error: 8512.901333 units
# Epoch 003 | Test Loss: 22.069183 | Vertex Error: 8697.501720 units
# Epoch 003 | Test Loss: 22.866297 | Vertex Error: 9027.439465 units
# Epoch 003 | Test Loss: 23.527748 | Vertex Error: 9304.156261 units
# Epoch 003 | Test Loss: 24.085967 | Vertex Error: 9523.212017 units
# Epoch 003 | Test Loss: 24.734743 | Vertex Error: 9773.418224 units
# Epoch 003 | Test Loss: 25.353404 | Vertex Error: 10000.762569 units
# Epoch 003 | Test Loss: 25.876210 | Vertex Error: 10200.959164 units
# Epoch 003 | Test Loss: 26.337414 | Vertex Error: 10380.976467 units
# Epoch 003 | Test Loss: 26.855654 | Vertex Error: 10586.142056 units
# Epoch 003 | Test Loss: 27.640183 | Vertex Error: 10892.664791 units
# Epoch 003 | Test Loss: 28.267402 | Vertex Error: 11129.884823 units
# Epoch 003 | Test Loss: 28.804458 | Vertex Error: 11334.042446 units
# Epoch 003 | Test Loss: 29.369646 | Vertex Error: 11559.538692 units
# Epoch 003 | Test Loss: 30.100681 | Vertex Error: 11846.666805 units
# Epoch 003 | Test Loss: 30.630633 | Vertex Error: 12056.842251 units
# Epoch 003 | Test Loss: 31.149506 | Vertex Error: 12265.547512 units
# Epoch 003 | Test Loss: 31.854180 | Vertex Error: 12553.555813 units
# Epoch 003 | Test Loss: 32.606633 | Vertex Error: 12850.529568 units
# Epoch 003 | Test Loss: 33.307949 | Vertex Error: 13154.483852 units
# Epoch 003 | Test Loss: 34.151389 | Vertex Error: 13484.126980 units
# Epoch 003 | Test Loss: 34.745267 | Vertex Error: 13726.369366 units
# Epoch 003 | Test Loss: 35.294596 | Vertex Error: 13931.996502 units
# Epoch 003 | Test Loss: 35.831168 | Vertex Error: 14135.678616 units
# Epoch 003 | Test Loss: 36.258443 | Vertex Error: 14296.164089 units
# Epoch 003 | Test Loss: 36.777973 | Vertex Error: 14494.192638 units
# Epoch 003 | Test Loss: 37.309051 | Vertex Error: 14700.153667 units
# Epoch 003 | Test Loss: 37.887174 | Vertex Error: 14917.719448 units
# Epoch 003 | Test Loss: 38.453050 | Vertex Error: 15135.538967 units
# Epoch 003 | Test Loss: 38.990821 | Vertex Error: 15346.083767 units
# Epoch 003 | Test Loss: 39.720666 | Vertex Error: 15626.922329 units
# Epoch 003 | Test Loss: 40.237358 | Vertex Error: 15838.911785 units
# Epoch 003 | Test Loss: 40.742071 | Vertex Error: 16033.721752 units
# Epoch 003 | Test Loss: 41.441753 | Vertex Error: 16319.082897 units
# Epoch 003 | Test Loss: 42.161962 | Vertex Error: 16613.910839 units
# Epoch 003 | Test Loss: 42.654703 | Vertex Error: 16809.637936 units
# Epoch 003 | Test Loss: 43.298873 | Vertex Error: 17060.855618 units
# Epoch 003 | Test Loss: 43.794440 | Vertex Error: 17255.469006 units
# Epoch 003 | Test Loss: 44.287676 | Vertex Error: 17442.689709 units
# Epoch 003 | Test Loss: 44.812924 | Vertex Error: 17647.029202 units
# Epoch 003 | Test Loss: 45.237850 | Vertex Error: 17811.608562 units
# Epoch 003 | Test Loss: 45.781958 | Vertex Error: 18027.720623 units
# Epoch 003 | Test Loss: 46.359959 | Vertex Error: 18247.049236 units
# Epoch 003 | Test Loss: 46.826671 | Vertex Error: 18426.399563 units
# Epoch 003 | Test Loss: 47.518516 | Vertex Error: 18698.073940 units
# Epoch 003 | Test Loss: 48.096681 | Vertex Error: 18922.000576 units
# Epoch 003 | Test Loss: 48.659001 | Vertex Error: 19139.395550 units
# Epoch 003 | Test Loss: 49.300774 | Vertex Error: 19394.102520 units
# Epoch 003 | Test Loss: 49.801489 | Vertex Error: 19596.862484 units
# Epoch 003 | Test Loss: 50.508052 | Vertex Error: 19886.950619 units
# Epoch 003 | Test Loss: 51.028223 | Vertex Error: 20094.338543 units
# Epoch 003 | Test Loss: 51.433161 | Vertex Error: 20252.616909 units
# Epoch 003 | Test Loss: 52.064992 | Vertex Error: 20497.006863 units
# Epoch 003 | Test Loss: 52.633735 | Vertex Error: 20711.302181 units
# Epoch 003 | Test Loss: 53.129372 | Vertex Error: 20899.023083 units
# Epoch 003 | Test Loss: 53.644693 | Vertex Error: 21101.005917 units
# Epoch 003 | Test Loss: 54.120673 | Vertex Error: 21291.714535 units
# Epoch 003 | Test Loss: 54.956013 | Vertex Error: 21627.481441 units
# Epoch 003 | Test Loss: 55.613356 | Vertex Error: 21893.883053 units
# Epoch 003 | Test Loss: 56.051383 | Vertex Error: 22058.767178 units
# Epoch 003 | Test Loss: 56.567311 | Vertex Error: 22260.878368 units
# Epoch 003 | Test Loss: 57.180057 | Vertex Error: 22487.942318 units
# Epoch 003 | Test Loss: 57.628325 | Vertex Error: 22662.176296 units
# Epoch 003 | Test Loss: 58.041176 | Vertex Error: 22822.143093 units
# Epoch 003 | Test Loss: 58.639152 | Vertex Error: 23068.453503 units
# Epoch 003 | Test Loss: 59.295829 | Vertex Error: 23330.837231 units
# Epoch 003 | Test Loss: 59.810354 | Vertex Error: 23544.468487 units
# Epoch 003 | Test Loss: 60.328380 | Vertex Error: 23753.072231 units
# Epoch 003 | Test Loss: 60.877243 | Vertex Error: 23968.797482 units
# Epoch 003 | Test Loss: 61.510725 | Vertex Error: 24210.178707 units
# Epoch 003 | Test Loss: 61.986495 | Vertex Error: 24403.237698 units
# Epoch 003 | Test Loss: 62.462355 | Vertex Error: 24584.645962 units
# Epoch 003 | Test Loss: 63.049096 | Vertex Error: 24830.553905 units
# Epoch 003 | Test Loss: 63.774838 | Vertex Error: 25121.771465 units
# Epoch 003 | Test Loss: 64.343073 | Vertex Error: 25350.044598 units
# Epoch 003 | Test Loss: 64.882722 | Vertex Error: 25564.129864 units
# Epoch 003 | Test Loss: 65.400808 | Vertex Error: 25759.669811 units
# Epoch 003 | Test Loss: 65.973286 | Vertex Error: 25972.608913 units
# Epoch 003 | Test Loss: 66.461055 | Vertex Error: 26163.682049 units
# Epoch 003 | Test Loss: 66.880573 | Vertex Error: 26326.173321 units
# Epoch 003 | Test Loss: 67.572078 | Vertex Error: 26617.709484 units
# Epoch 003 | Test Loss: 68.285500 | Vertex Error: 26902.087597 units
# Epoch 003 | Test Loss: 68.684774 | Vertex Error: 27068.848049 units
# Epoch 003 | Test Loss: 69.351539 | Vertex Error: 27336.004879 units
# Epoch 003 | Test Loss: 69.877727 | Vertex Error: 27542.443188 units
# Epoch 003 | Test Loss: 70.384503 | Vertex Error: 27735.545574 units
# Epoch 003 | Test Loss: 71.019622 | Vertex Error: 27986.851757 units
# Epoch 003 | Test Loss: 71.457582 | Vertex Error: 28158.903225 units
# Epoch 003 | Test Loss: 72.187866 | Vertex Error: 28464.210964 units
# Epoch 003 | Test Loss: 72.918704 | Vertex Error: 28753.562740 units
# Epoch 003 | Test Loss: 73.359014 | Vertex Error: 28930.895733 units
# Epoch 003 | Test Loss: 73.954790 | Vertex Error: 29159.707226 units
# Epoch 003 | Test Loss: 74.524496 | Vertex Error: 29372.158733 units
# Epoch 003 | Test Loss: 75.012518 | Vertex Error: 29558.298687 units
# Epoch 003 | Test Loss: 75.515872 | Vertex Error: 29754.228954 units
# Epoch 003 | Test Loss: 75.998299 | Vertex Error: 29947.422924 units
# Epoch 003 | Test Loss: 76.875893 | Vertex Error: 30305.310009 units
# Epoch 003 | Test Loss: 77.514987 | Vertex Error: 30575.848095 units
# Epoch 003 | Test Loss: 77.998569 | Vertex Error: 30767.633877 units
# Epoch 003 | Test Loss: 78.607353 | Vertex Error: 31004.242901 units
# Epoch 003 | Test Loss: 79.202384 | Vertex Error: 31226.052242 units
# Epoch 003 | Test Loss: 79.687494 | Vertex Error: 31413.888851 units
# Epoch 003 | Test Loss: 80.135653 | Vertex Error: 31590.665188 units
# Epoch 003 | Test Loss: 80.657661 | Vertex Error: 31801.069393 units
# Epoch 003 | Test Loss: 81.479944 | Vertex Error: 32127.943386 units
# Epoch 003 | Test Loss: 82.203957 | Vertex Error: 32422.100826 units
# Epoch 003 | Test Loss: 82.675487 | Vertex Error: 32602.743649 units
# Epoch 003 | Test Loss: 83.204816 | Vertex Error: 32814.870647 units
# Epoch 003 | Test Loss: 83.871871 | Vertex Error: 33072.962627 units
# Epoch 003 | Test Loss: 84.369448 | Vertex Error: 33267.549725 units
# Epoch 003 | Test Loss: 84.837213 | Vertex Error: 33450.309933 units
# Epoch 003 | Test Loss: 85.479035 | Vertex Error: 33721.498714 units
# Epoch 003 | Test Loss: 86.120999 | Vertex Error: 33975.223965 units
# Epoch 003 | Test Loss: 86.679183 | Vertex Error: 34202.779064 units
# Epoch 003 | Test Loss: 87.200211 | Vertex Error: 34414.286526 units
# Epoch 003 | Test Loss: 87.752035 | Vertex Error: 34636.627041 units
# Epoch 003 | Test Loss: 88.437484 | Vertex Error: 34904.120022 units
# Epoch 003 | Test Loss: 88.948116 | Vertex Error: 35107.920834 units
# Epoch 003 | Test Loss: 89.593647 | Vertex Error: 35165.204372 units
# Epoch 003 | Train Loss: 0.575356 | Test Loss: 0.570660 | Avg Vertex Error: 1.172408 units
# Train Epoch 004
# Epoch 004 | Test Loss: 0.063138 | Vertex Error: 25.508848 units
# Epoch 004 | Test Loss: 0.336760 | Vertex Error: 127.731054 units
# Epoch 004 | Test Loss: 0.782106 | Vertex Error: 297.431112 units
# Epoch 004 | Test Loss: 1.328174 | Vertex Error: 515.035391 units
# Epoch 004 | Test Loss: 1.871755 | Vertex Error: 726.265936 units
# Epoch 004 | Test Loss: 2.489297 | Vertex Error: 959.082327 units
# Epoch 004 | Test Loss: 2.985462 | Vertex Error: 1164.334784 units
# Epoch 004 | Test Loss: 3.443515 | Vertex Error: 1338.149084 units
# Epoch 004 | Test Loss: 4.078147 | Vertex Error: 1606.645849 units
# Epoch 004 | Test Loss: 4.729408 | Vertex Error: 1862.275778 units
# Epoch 004 | Test Loss: 5.334126 | Vertex Error: 2110.610373 units
# Epoch 004 | Test Loss: 5.915285 | Vertex Error: 2351.115652 units
# Epoch 004 | Test Loss: 6.477089 | Vertex Error: 2576.352468 units
# Epoch 004 | Test Loss: 7.166235 | Vertex Error: 2850.506979 units
# Epoch 004 | Test Loss: 7.709187 | Vertex Error: 3070.090673 units
# Epoch 004 | Test Loss: 8.232833 | Vertex Error: 3276.345037 units
# Epoch 004 | Test Loss: 8.886044 | Vertex Error: 3537.374487 units
# Epoch 004 | Test Loss: 9.537285 | Vertex Error: 3793.845251 units
# Epoch 004 | Test Loss: 10.165760 | Vertex Error: 4055.001501 units
# Epoch 004 | Test Loss: 10.827921 | Vertex Error: 4313.311743 units
# Epoch 004 | Test Loss: 11.311348 | Vertex Error: 4506.610693 units
# Epoch 004 | Test Loss: 11.794428 | Vertex Error: 4690.566961 units
# Epoch 004 | Test Loss: 12.317193 | Vertex Error: 4897.024557 units
# Epoch 004 | Test Loss: 12.748493 | Vertex Error: 5062.737371 units
# Epoch 004 | Test Loss: 13.482378 | Vertex Error: 5361.552435 units
# Epoch 004 | Test Loss: 14.010548 | Vertex Error: 5566.248220 units
# Epoch 004 | Test Loss: 14.526236 | Vertex Error: 5775.256186 units
# Epoch 004 | Test Loss: 15.311283 | Vertex Error: 6070.878073 units
# Epoch 004 | Test Loss: 15.903534 | Vertex Error: 6301.505362 units
# Epoch 004 | Test Loss: 16.454426 | Vertex Error: 6517.233679 units
# Epoch 004 | Test Loss: 17.136044 | Vertex Error: 6792.029242 units
# Epoch 004 | Test Loss: 17.650938 | Vertex Error: 6989.939703 units
# Epoch 004 | Test Loss: 18.307030 | Vertex Error: 7256.401983 units
# Epoch 004 | Test Loss: 18.925949 | Vertex Error: 7499.994024 units
# Epoch 004 | Test Loss: 19.260021 | Vertex Error: 7629.157446 units
# Epoch 004 | Test Loss: 19.868232 | Vertex Error: 7865.775457 units
# Epoch 004 | Test Loss: 20.397922 | Vertex Error: 8064.290136 units
# Epoch 004 | Test Loss: 20.878852 | Vertex Error: 8249.009863 units
# Epoch 004 | Test Loss: 21.419051 | Vertex Error: 8458.521490 units
# Epoch 004 | Test Loss: 21.878774 | Vertex Error: 8642.347708 units
# Epoch 004 | Test Loss: 22.673294 | Vertex Error: 8971.293631 units
# Epoch 004 | Test Loss: 23.328687 | Vertex Error: 9245.732595 units
# Epoch 004 | Test Loss: 23.887559 | Vertex Error: 9465.720037 units
# Epoch 004 | Test Loss: 24.527034 | Vertex Error: 9712.462225 units
# Epoch 004 | Test Loss: 25.147020 | Vertex Error: 9940.041876 units
# Epoch 004 | Test Loss: 25.669518 | Vertex Error: 10140.535498 units
# Epoch 004 | Test Loss: 26.120932 | Vertex Error: 10317.359579 units
# Epoch 004 | Test Loss: 26.640182 | Vertex Error: 10523.610357 units
# Epoch 004 | Test Loss: 27.416422 | Vertex Error: 10827.406347 units
# Epoch 004 | Test Loss: 28.030421 | Vertex Error: 11061.420233 units
# Epoch 004 | Test Loss: 28.568418 | Vertex Error: 11266.003363 units
# Epoch 004 | Test Loss: 29.132208 | Vertex Error: 11491.175406 units
# Epoch 004 | Test Loss: 29.857273 | Vertex Error: 11776.426413 units
# Epoch 004 | Test Loss: 30.388066 | Vertex Error: 11987.067480 units
# Epoch 004 | Test Loss: 30.902597 | Vertex Error: 12195.035330 units
# Epoch 004 | Test Loss: 31.604052 | Vertex Error: 12481.672842 units
# Epoch 004 | Test Loss: 32.354325 | Vertex Error: 12778.759024 units
# Epoch 004 | Test Loss: 33.053488 | Vertex Error: 13082.078665 units
# Epoch 004 | Test Loss: 33.894284 | Vertex Error: 13411.016775 units
# Epoch 004 | Test Loss: 34.487721 | Vertex Error: 13653.181875 units
# Epoch 004 | Test Loss: 35.030085 | Vertex Error: 13856.429342 units
# Epoch 004 | Test Loss: 35.561091 | Vertex Error: 14058.055044 units
# Epoch 004 | Test Loss: 35.988691 | Vertex Error: 14219.218359 units
# Epoch 004 | Test Loss: 36.505984 | Vertex Error: 14416.677038 units
# Epoch 004 | Test Loss: 37.022879 | Vertex Error: 14617.892050 units
# Epoch 004 | Test Loss: 37.576094 | Vertex Error: 14827.523382 units
# Epoch 004 | Test Loss: 38.151546 | Vertex Error: 15048.837713 units
# Epoch 004 | Test Loss: 38.682911 | Vertex Error: 15257.279562 units
# Epoch 004 | Test Loss: 39.399271 | Vertex Error: 15533.250296 units
# Epoch 004 | Test Loss: 39.921210 | Vertex Error: 15747.808401 units
# Epoch 004 | Test Loss: 40.422870 | Vertex Error: 15941.985800 units
# Epoch 004 | Test Loss: 41.120847 | Vertex Error: 16226.657980 units
# Epoch 004 | Test Loss: 41.838842 | Vertex Error: 16520.912680 units
# Epoch 004 | Test Loss: 42.332737 | Vertex Error: 16716.995901 units
# Epoch 004 | Test Loss: 42.969815 | Vertex Error: 16965.189001 units
# Epoch 004 | Test Loss: 43.465484 | Vertex Error: 17160.448477 units
# Epoch 004 | Test Loss: 43.952304 | Vertex Error: 17345.696829 units
# Epoch 004 | Test Loss: 44.468980 | Vertex Error: 17546.842413 units
# Epoch 004 | Test Loss: 44.895851 | Vertex Error: 17712.273520 units
# Epoch 004 | Test Loss: 45.435237 | Vertex Error: 17927.186758 units
# Epoch 004 | Test Loss: 45.997410 | Vertex Error: 18142.091528 units
# Epoch 004 | Test Loss: 46.446895 | Vertex Error: 18315.921942 units
# Epoch 004 | Test Loss: 47.144869 | Vertex Error: 18590.207281 units
# Epoch 004 | Test Loss: 47.717410 | Vertex Error: 18812.418219 units
# Epoch 004 | Test Loss: 48.267079 | Vertex Error: 19025.529242 units
# Epoch 004 | Test Loss: 48.913121 | Vertex Error: 19282.022192 units
# Epoch 004 | Test Loss: 49.412263 | Vertex Error: 19483.689901 units
# Epoch 004 | Test Loss: 50.116838 | Vertex Error: 19773.207846 units
# Epoch 004 | Test Loss: 50.632004 | Vertex Error: 19978.982611 units
# Epoch 004 | Test Loss: 51.037256 | Vertex Error: 20137.621969 units
# Epoch 004 | Test Loss: 51.658105 | Vertex Error: 20377.968832 units
# Epoch 004 | Test Loss: 52.228947 | Vertex Error: 20593.316183 units
# Epoch 004 | Test Loss: 52.723645 | Vertex Error: 20781.017202 units
# Epoch 004 | Test Loss: 53.225509 | Vertex Error: 20978.247915 units
# Epoch 004 | Test Loss: 53.706582 | Vertex Error: 21171.475027 units
# Epoch 004 | Test Loss: 54.532115 | Vertex Error: 21503.999685 units
# Epoch 004 | Test Loss: 55.173777 | Vertex Error: 21767.312918 units
# Epoch 004 | Test Loss: 55.612770 | Vertex Error: 21932.110205 units
# Epoch 004 | Test Loss: 56.126946 | Vertex Error: 22133.908514 units
# Epoch 004 | Test Loss: 56.731095 | Vertex Error: 22358.606833 units
# Epoch 004 | Test Loss: 57.181611 | Vertex Error: 22533.751181 units
# Epoch 004 | Test Loss: 57.590612 | Vertex Error: 22692.976553 units
# Epoch 004 | Test Loss: 58.181436 | Vertex Error: 22936.733023 units
# Epoch 004 | Test Loss: 58.841062 | Vertex Error: 23200.080526 units
# Epoch 004 | Test Loss: 59.350042 | Vertex Error: 23412.215841 units
# Epoch 004 | Test Loss: 59.868572 | Vertex Error: 23621.892813 units
# Epoch 004 | Test Loss: 60.407118 | Vertex Error: 23833.644659 units
# Epoch 004 | Test Loss: 61.040276 | Vertex Error: 24075.251699 units
# Epoch 004 | Test Loss: 61.511937 | Vertex Error: 24267.850790 units
# Epoch 004 | Test Loss: 61.978304 | Vertex Error: 24446.176382 units
# Epoch 004 | Test Loss: 62.568189 | Vertex Error: 24693.420523 units
# Epoch 004 | Test Loss: 63.282741 | Vertex Error: 24981.449850 units
# Epoch 004 | Test Loss: 63.833639 | Vertex Error: 25204.692251 units
# Epoch 004 | Test Loss: 64.379815 | Vertex Error: 25421.458349 units
# Epoch 004 | Test Loss: 64.891249 | Vertex Error: 25615.179296 units
# Epoch 004 | Test Loss: 65.452652 | Vertex Error: 25824.108297 units
# Epoch 004 | Test Loss: 65.946564 | Vertex Error: 26017.865622 units
# Epoch 004 | Test Loss: 66.364907 | Vertex Error: 26180.100821 units
# Epoch 004 | Test Loss: 67.054118 | Vertex Error: 26470.291891 units
# Epoch 004 | Test Loss: 67.761595 | Vertex Error: 26752.529806 units
# Epoch 004 | Test Loss: 68.157761 | Vertex Error: 26918.899435 units
# Epoch 004 | Test Loss: 68.819242 | Vertex Error: 27184.338247 units
# Epoch 004 | Test Loss: 69.345261 | Vertex Error: 27390.534719 units
# Epoch 004 | Test Loss: 69.847829 | Vertex Error: 27582.478613 units
# Epoch 004 | Test Loss: 70.477027 | Vertex Error: 27831.490408 units
# Epoch 004 | Test Loss: 70.917114 | Vertex Error: 28004.412634 units
# Epoch 004 | Test Loss: 71.644212 | Vertex Error: 28308.923925 units
# Epoch 004 | Test Loss: 72.362652 | Vertex Error: 28594.547827 units
# Epoch 004 | Test Loss: 72.792855 | Vertex Error: 28769.179739 units
# Epoch 004 | Test Loss: 73.390506 | Vertex Error: 28998.720419 units
# Epoch 004 | Test Loss: 73.957471 | Vertex Error: 29210.108587 units
# Epoch 004 | Test Loss: 74.438912 | Vertex Error: 29394.449926 units
# Epoch 004 | Test Loss: 74.942310 | Vertex Error: 29590.669073 units
# Epoch 004 | Test Loss: 75.422046 | Vertex Error: 29782.879675 units
# Epoch 004 | Test Loss: 76.296434 | Vertex Error: 30139.244757 units
# Epoch 004 | Test Loss: 76.932424 | Vertex Error: 30408.817907 units
# Epoch 004 | Test Loss: 77.415935 | Vertex Error: 30601.729391 units
# Epoch 004 | Test Loss: 78.013625 | Vertex Error: 30834.472525 units
# Epoch 004 | Test Loss: 78.611111 | Vertex Error: 31057.115484 units
# Epoch 004 | Test Loss: 79.093678 | Vertex Error: 31244.463522 units
# Epoch 004 | Test Loss: 79.530369 | Vertex Error: 31417.082998 units
# Epoch 004 | Test Loss: 80.055831 | Vertex Error: 31628.999411 units
# Epoch 004 | Test Loss: 80.868274 | Vertex Error: 31952.588644 units
# Epoch 004 | Test Loss: 81.576879 | Vertex Error: 32243.953726 units
# Epoch 004 | Test Loss: 82.049668 | Vertex Error: 32424.927908 units
# Epoch 004 | Test Loss: 82.576136 | Vertex Error: 32636.624838 units
# Epoch 004 | Test Loss: 83.234920 | Vertex Error: 32892.170980 units
# Epoch 004 | Test Loss: 83.733026 | Vertex Error: 33086.938833 units
# Epoch 004 | Test Loss: 84.198341 | Vertex Error: 33268.989676 units
# Epoch 004 | Test Loss: 84.836082 | Vertex Error: 33538.317617 units
# Epoch 004 | Test Loss: 85.480912 | Vertex Error: 33792.917273 units
# Epoch 004 | Test Loss: 86.033192 | Vertex Error: 34018.831274 units
# Epoch 004 | Test Loss: 86.551823 | Vertex Error: 34230.735571 units
# Epoch 004 | Test Loss: 87.093727 | Vertex Error: 34449.322912 units
# Epoch 004 | Test Loss: 87.777547 | Vertex Error: 34717.453772 units
# Epoch 004 | Test Loss: 88.285799 | Vertex Error: 34920.536795 units
# Epoch 004 | Test Loss: 88.915096 | Vertex Error: 34976.653978 units
# Epoch 004 | Train Loss: 0.568397 | Test Loss: 0.566338 | Avg Vertex Error: 1.166122 units
# Train Epoch 005
# Epoch 005 | Test Loss: 0.057495 | Vertex Error: 23.057693 units
# Epoch 005 | Test Loss: 0.317899 | Vertex Error: 121.189651 units
# Epoch 005 | Test Loss: 0.745334 | Vertex Error: 284.366135 units
# Epoch 005 | Test Loss: 1.296791 | Vertex Error: 504.023514 units
# Epoch 005 | Test Loss: 1.839488 | Vertex Error: 715.137329 units
# Epoch 005 | Test Loss: 2.448045 | Vertex Error: 944.809479 units
# Epoch 005 | Test Loss: 2.951373 | Vertex Error: 1152.755508 units
# Epoch 005 | Test Loss: 3.408101 | Vertex Error: 1326.337128 units
# Epoch 005 | Test Loss: 4.038365 | Vertex Error: 1593.155243 units
# Epoch 005 | Test Loss: 4.690566 | Vertex Error: 1848.900726 units
# Epoch 005 | Test Loss: 5.291488 | Vertex Error: 2096.288528 units
# Epoch 005 | Test Loss: 5.872752 | Vertex Error: 2336.383896 units
# Epoch 005 | Test Loss: 6.428678 | Vertex Error: 2559.189835 units
# Epoch 005 | Test Loss: 7.119054 | Vertex Error: 2834.317825 units
# Epoch 005 | Test Loss: 7.659971 | Vertex Error: 3053.092514 units
# Epoch 005 | Test Loss: 8.177069 | Vertex Error: 3257.037613 units
# Epoch 005 | Test Loss: 8.833092 | Vertex Error: 3519.395187 units
# Epoch 005 | Test Loss: 9.472237 | Vertex Error: 3772.299072 units
# Epoch 005 | Test Loss: 10.091731 | Vertex Error: 4031.552002 units
# Epoch 005 | Test Loss: 10.757605 | Vertex Error: 4291.024475 units
# Epoch 005 | Test Loss: 11.241118 | Vertex Error: 4484.168274 units
# Epoch 005 | Test Loss: 11.720335 | Vertex Error: 4666.351227 units
# Epoch 005 | Test Loss: 12.246345 | Vertex Error: 4874.317627 units
# Epoch 005 | Test Loss: 12.677035 | Vertex Error: 5039.968338 units
# Epoch 005 | Test Loss: 13.409361 | Vertex Error: 5337.843948 units
# Epoch 005 | Test Loss: 13.934456 | Vertex Error: 5541.428085 units
# Epoch 005 | Test Loss: 14.446597 | Vertex Error: 5749.550446 units
# Epoch 005 | Test Loss: 15.229232 | Vertex Error: 6043.979828 units
# Epoch 005 | Test Loss: 15.821028 | Vertex Error: 6274.651337 units
# Epoch 005 | Test Loss: 16.370994 | Vertex Error: 6490.266022 units
# Epoch 005 | Test Loss: 17.048788 | Vertex Error: 6763.255127 units
# Epoch 005 | Test Loss: 17.565371 | Vertex Error: 6961.701874 units
# Epoch 005 | Test Loss: 18.219815 | Vertex Error: 7227.711182 units
# Epoch 005 | Test Loss: 18.828165 | Vertex Error: 7467.759567 units
# Epoch 005 | Test Loss: 19.149149 | Vertex Error: 7592.755737 units
# Epoch 005 | Test Loss: 19.760803 | Vertex Error: 7830.866119 units
# Epoch 005 | Test Loss: 20.288477 | Vertex Error: 8028.839478 units
# Epoch 005 | Test Loss: 20.763413 | Vertex Error: 8211.621994 units
# Epoch 005 | Test Loss: 21.306289 | Vertex Error: 8422.382095 units
# Epoch 005 | Test Loss: 21.764038 | Vertex Error: 8605.566162 units
# Epoch 005 | Test Loss: 22.557174 | Vertex Error: 8933.707916 units
# Epoch 005 | Test Loss: 23.209630 | Vertex Error: 9207.056152 units
# Epoch 005 | Test Loss: 23.768324 | Vertex Error: 9427.366943 units
# Epoch 005 | Test Loss: 24.400542 | Vertex Error: 9671.288696 units
# Epoch 005 | Test Loss: 25.024059 | Vertex Error: 9900.025253 units
# Epoch 005 | Test Loss: 25.546374 | Vertex Error: 10100.668762 units
# Epoch 005 | Test Loss: 25.990885 | Vertex Error: 10275.040634 units
# Epoch 005 | Test Loss: 26.511985 | Vertex Error: 10482.418640 units
# Epoch 005 | Test Loss: 27.281267 | Vertex Error: 10783.771912 units
# Epoch 005 | Test Loss: 27.885991 | Vertex Error: 11015.497955 units
# Epoch 005 | Test Loss: 28.425206 | Vertex Error: 11220.790649 units
# Epoch 005 | Test Loss: 28.989833 | Vertex Error: 11446.328033 units
# Epoch 005 | Test Loss: 29.710358 | Vertex Error: 11729.783997 units
# Epoch 005 | Test Loss: 30.243726 | Vertex Error: 11941.448120 units
# Epoch 005 | Test Loss: 30.756857 | Vertex Error: 12149.352692 units
# Epoch 005 | Test Loss: 31.456294 | Vertex Error: 12434.865509 units
# Epoch 005 | Test Loss: 32.205528 | Vertex Error: 12731.904236 units
# Epoch 005 | Test Loss: 32.903957 | Vertex Error: 13034.913391 units
# Epoch 005 | Test Loss: 33.742117 | Vertex Error: 13363.145508 units
# Epoch 005 | Test Loss: 34.336463 | Vertex Error: 13605.438797 units
# Epoch 005 | Test Loss: 34.876255 | Vertex Error: 13807.810181 units
# Epoch 005 | Test Loss: 35.402899 | Vertex Error: 14007.673706 units
# Epoch 005 | Test Loss: 35.831716 | Vertex Error: 14169.597382 units
# Epoch 005 | Test Loss: 36.347738 | Vertex Error: 14366.748947 units
# Epoch 005 | Test Loss: 36.854308 | Vertex Error: 14564.413391 units
# Epoch 005 | Test Loss: 37.386239 | Vertex Error: 14767.123489 units
# Epoch 005 | Test Loss: 37.971022 | Vertex Error: 14991.946304 units
# Epoch 005 | Test Loss: 38.499587 | Vertex Error: 15199.439896 units
# Epoch 005 | Test Loss: 39.205353 | Vertex Error: 15471.485062 units
# Epoch 005 | Test Loss: 39.733642 | Vertex Error: 15688.756973 units
# Epoch 005 | Test Loss: 40.234408 | Vertex Error: 15882.680740 units
# Epoch 005 | Test Loss: 40.930965 | Vertex Error: 16166.641403 units
# Epoch 005 | Test Loss: 41.647931 | Vertex Error: 16460.550247 units
# Epoch 005 | Test Loss: 42.142548 | Vertex Error: 16656.710022 units
# Epoch 005 | Test Loss: 42.773130 | Vertex Error: 16902.328842 units
# Epoch 005 | Test Loss: 43.271223 | Vertex Error: 17098.843155 units
# ...
# Epoch 049 | Test Loss: 45.422675 | Vertex Error: 17932.298002 units
# Epoch 049 | Test Loss: 46.165872 | Vertex Error: 18224.842253 units
# Epoch 049 | Test Loss: 46.723170 | Vertex Error: 18440.225950 units
# Epoch 049 | Test Loss: 47.239329 | Vertex Error: 18640.900267 units
# Epoch 049 | Test Loss: 47.921303 | Vertex Error: 18911.630796 units
# Epoch 049 | Test Loss: 48.411935 | Vertex Error: 19108.501661 units
# Epoch 049 | Test Loss: 49.115741 | Vertex Error: 19395.404951 units
# Epoch 049 | Test Loss: 49.624254 | Vertex Error: 19599.068953 units
# Epoch 049 | Test Loss: 50.020282 | Vertex Error: 19754.466932 units
# Epoch 049 | Test Loss: 50.600759 | Vertex Error: 19978.894270 units
# Epoch 049 | Test Loss: 51.184518 | Vertex Error: 20199.477079 units
# Epoch 049 | Test Loss: 51.674271 | Vertex Error: 20385.462645 units
# Epoch 049 | Test Loss: 52.129991 | Vertex Error: 20563.503874 units
# Epoch 049 | Test Loss: 52.637542 | Vertex Error: 20766.164900 units
# Epoch 049 | Test Loss: 53.425190 | Vertex Error: 21084.535749 units
# Epoch 049 | Test Loss: 54.001728 | Vertex Error: 21334.876631 units
# Epoch 049 | Test Loss: 54.449740 | Vertex Error: 21501.226149 units
# Epoch 049 | Test Loss: 54.976240 | Vertex Error: 21707.699446 units
# Epoch 049 | Test Loss: 55.544249 | Vertex Error: 21919.705305 units
# Epoch 049 | Test Loss: 56.007842 | Vertex Error: 22099.897322 units
# Epoch 049 | Test Loss: 56.423092 | Vertex Error: 22261.553816 units
# Epoch 049 | Test Loss: 56.983883 | Vertex Error: 22492.373854 units
# Epoch 049 | Test Loss: 57.654407 | Vertex Error: 22757.437178 units
# Epoch 049 | Test Loss: 58.157638 | Vertex Error: 22967.577772 units
# Epoch 049 | Test Loss: 58.664578 | Vertex Error: 23172.816450 units
# Epoch 049 | Test Loss: 59.171690 | Vertex Error: 23371.069624 units
# Epoch 049 | Test Loss: 59.825094 | Vertex Error: 23620.645384 units
# Epoch 049 | Test Loss: 60.279535 | Vertex Error: 23806.332365 units
# Epoch 049 | Test Loss: 60.719908 | Vertex Error: 23973.887815 units
# Epoch 049 | Test Loss: 61.322976 | Vertex Error: 24227.451933 units
# Epoch 049 | Test Loss: 61.991083 | Vertex Error: 24499.530760 units
# Epoch 049 | Test Loss: 62.463866 | Vertex Error: 24700.856123 units
# Epoch 049 | Test Loss: 63.051893 | Vertex Error: 24931.301573 units
# Epoch 049 | Test Loss: 63.556233 | Vertex Error: 25122.726423 units
# Epoch 049 | Test Loss: 64.075018 | Vertex Error: 25315.618513 units
# Epoch 049 | Test Loss: 64.607845 | Vertex Error: 25523.922682 units
# Epoch 049 | Test Loss: 65.017912 | Vertex Error: 25682.885572 units
# Epoch 049 | Test Loss: 65.696844 | Vertex Error: 25965.595411 units
# Epoch 049 | Test Loss: 66.393906 | Vertex Error: 26244.259138 units
# Epoch 049 | Test Loss: 66.781352 | Vertex Error: 26408.171446 units
# Epoch 049 | Test Loss: 67.416816 | Vertex Error: 26662.075575 units
# Epoch 049 | Test Loss: 67.940106 | Vertex Error: 26865.500746 units
# Epoch 049 | Test Loss: 68.448150 | Vertex Error: 27061.034834 units
# Epoch 049 | Test Loss: 69.045475 | Vertex Error: 27295.733305 units
# Epoch 049 | Test Loss: 69.495833 | Vertex Error: 27471.138578 units
# Epoch 049 | Test Loss: 70.213747 | Vertex Error: 27773.173277 units
# Epoch 049 | Test Loss: 70.874140 | Vertex Error: 28043.053709 units
# Epoch 049 | Test Loss: 71.267823 | Vertex Error: 28206.260847 units
# Epoch 049 | Test Loss: 71.894944 | Vertex Error: 28446.177320 units
# Epoch 049 | Test Loss: 72.442746 | Vertex Error: 28649.914274 units
# Epoch 049 | Test Loss: 72.913026 | Vertex Error: 28829.661467 units
# Epoch 049 | Test Loss: 73.436199 | Vertex Error: 29033.856779 units
# Epoch 049 | Test Loss: 73.894017 | Vertex Error: 29216.847532 units
# Epoch 049 | Test Loss: 74.764973 | Vertex Error: 29568.810240 units
# Epoch 049 | Test Loss: 75.397320 | Vertex Error: 29836.584166 units
# Epoch 049 | Test Loss: 75.873984 | Vertex Error: 30027.303099 units
# Epoch 049 | Test Loss: 76.432813 | Vertex Error: 30245.300261 units
# Epoch 049 | Test Loss: 77.048121 | Vertex Error: 30473.828947 units
# Epoch 049 | Test Loss: 77.520353 | Vertex Error: 30657.038511 units
# Epoch 049 | Test Loss: 77.921701 | Vertex Error: 30814.422636 units
# Epoch 049 | Test Loss: 78.465909 | Vertex Error: 31033.666868 units
# Epoch 049 | Test Loss: 79.235638 | Vertex Error: 31341.232725 units
# Epoch 049 | Test Loss: 79.876950 | Vertex Error: 31620.451139 units
# Epoch 049 | Test Loss: 80.365731 | Vertex Error: 31805.000257 units
# Epoch 049 | Test Loss: 80.901415 | Vertex Error: 32020.985548 units
# Epoch 049 | Test Loss: 81.524442 | Vertex Error: 32262.242109 units
# Epoch 049 | Test Loss: 82.031382 | Vertex Error: 32459.303465 units
# Epoch 049 | Test Loss: 82.495991 | Vertex Error: 32641.364332 units
# Epoch 049 | Test Loss: 83.111757 | Vertex Error: 32900.515882 units
# Epoch 049 | Test Loss: 83.769607 | Vertex Error: 33156.868452 units
# Epoch 049 | Test Loss: 84.315992 | Vertex Error: 33380.801039 units
# Epoch 049 | Test Loss: 84.824129 | Vertex Error: 33587.977186 units
# Epoch 049 | Test Loss: 85.334784 | Vertex Error: 33793.822401 units
# Epoch 049 | Test Loss: 86.034560 | Vertex Error: 34069.955580 units
# Epoch 049 | Test Loss: 86.530183 | Vertex Error: 34267.555555 units
# Epoch 049 | Test Loss: 87.114628 | Vertex Error: 34319.484457 units
# Epoch 049 | Train Loss: 0.554844 | Test Loss: 0.554870 | Avg Vertex Error: 1.144212 units
# Train Epoch 050
# Epoch 050 | Test Loss: 0.024284 | Vertex Error: 9.382644 units
# Epoch 050 | Test Loss: 0.232220 | Vertex Error: 89.119575 units
# Epoch 050 | Test Loss: 0.583457 | Vertex Error: 225.405723 units
# Epoch 050 | Test Loss: 1.167932 | Vertex Error: 454.400443 units
# Epoch 050 | Test Loss: 1.711484 | Vertex Error: 665.215552 units
# Epoch 050 | Test Loss: 2.288416 | Vertex Error: 883.131049 units
# Epoch 050 | Test Loss: 2.820462 | Vertex Error: 1101.289283 units
# Epoch 050 | Test Loss: 3.267702 | Vertex Error: 1270.830894 units
# Epoch 050 | Test Loss: 3.880625 | Vertex Error: 1529.671287 units
# Epoch 050 | Test Loss: 4.536858 | Vertex Error: 1785.630820 units
# Epoch 050 | Test Loss: 5.134578 | Vertex Error: 2031.784919 units
# Epoch 050 | Test Loss: 5.705886 | Vertex Error: 2266.423881 units
# Epoch 050 | Test Loss: 6.248050 | Vertex Error: 2481.487220 units
# Epoch 050 | Test Loss: 6.954441 | Vertex Error: 2764.172400 units
# Epoch 050 | Test Loss: 7.480249 | Vertex Error: 2976.150001 units
# Epoch 050 | Test Loss: 7.981159 | Vertex Error: 3172.767310 units
# Epoch 050 | Test Loss: 8.644062 | Vertex Error: 3438.585944 units
# Epoch 050 | Test Loss: 9.241009 | Vertex Error: 3675.981299 units
# Epoch 050 | Test Loss: 9.831666 | Vertex Error: 3929.056556 units
# Epoch 050 | Test Loss: 10.523803 | Vertex Error: 4196.886970 units
# Epoch 050 | Test Loss: 10.998913 | Vertex Error: 4386.082709 units
# Epoch 050 | Test Loss: 11.467889 | Vertex Error: 4563.174201 units
# Epoch 050 | Test Loss: 12.014593 | Vertex Error: 4779.330192 units
# Epoch 050 | Test Loss: 12.430746 | Vertex Error: 4938.926169 units
# Epoch 050 | Test Loss: 13.158363 | Vertex Error: 5232.994285 units
# Epoch 050 | Test Loss: 13.679780 | Vertex Error: 5434.445151 units
# Epoch 050 | Test Loss: 14.185243 | Vertex Error: 5640.860160 units
# Epoch 050 | Test Loss: 14.950058 | Vertex Error: 5926.928184 units
# Epoch 050 | Test Loss: 15.531581 | Vertex Error: 6152.982032 units
# Epoch 050 | Test Loss: 16.092546 | Vertex Error: 6373.954459 units
# Epoch 050 | Test Loss: 16.743375 | Vertex Error: 6634.492911 units
# Epoch 050 | Test Loss: 17.264154 | Vertex Error: 6833.161155 units
# Epoch 050 | Test Loss: 17.910614 | Vertex Error: 7096.675620 units
# Epoch 050 | Test Loss: 18.477198 | Vertex Error: 7321.604957 units
# Epoch 050 | Test Loss: 18.762064 | Vertex Error: 7431.993629 units
# Epoch 050 | Test Loss: 19.400716 | Vertex Error: 7680.584601 units
# Epoch 050 | Test Loss: 19.911440 | Vertex Error: 7872.369239 units
# Epoch 050 | Test Loss: 20.373755 | Vertex Error: 8049.865104 units
# Epoch 050 | Test Loss: 20.938696 | Vertex Error: 8269.287772 units
# Epoch 050 | Test Loss: 21.379516 | Vertex Error: 8445.451621 units
# Epoch 050 | Test Loss: 22.172895 | Vertex Error: 8770.360068 units
# Epoch 050 | Test Loss: 22.821361 | Vertex Error: 9041.495566 units
# Epoch 050 | Test Loss: 23.372698 | Vertex Error: 9259.165565 units
# Epoch 050 | Test Loss: 23.975683 | Vertex Error: 9491.900748 units
# Epoch 050 | Test Loss: 24.611609 | Vertex Error: 9725.229957 units
# Epoch 050 | Test Loss: 25.122529 | Vertex Error: 9921.545630 units
# Epoch 050 | Test Loss: 25.545305 | Vertex Error: 10086.599311 units
# Epoch 050 | Test Loss: 26.075045 | Vertex Error: 10296.683097 units
# Epoch 050 | Test Loss: 26.809666 | Vertex Error: 10585.711753 units
# Epoch 050 | Test Loss: 27.373912 | Vertex Error: 10808.894340 units
# Epoch 050 | Test Loss: 27.922441 | Vertex Error: 11018.064155 units
# Epoch 050 | Test Loss: 28.500744 | Vertex Error: 11248.965919 units
# Epoch 050 | Test Loss: 29.194576 | Vertex Error: 11520.753242 units
# Epoch 050 | Test Loss: 29.738889 | Vertex Error: 11735.692328 units
# Epoch 050 | Test Loss: 30.256622 | Vertex Error: 11946.835807 units
# Epoch 050 | Test Loss: 30.938393 | Vertex Error: 12223.502189 units
# Epoch 050 | Test Loss: 31.689388 | Vertex Error: 12520.414084 units
# Epoch 050 | Test Loss: 32.384435 | Vertex Error: 12820.953605 units
# Epoch 050 | Test Loss: 33.206475 | Vertex Error: 13143.839164 units
# Epoch 050 | Test Loss: 33.805049 | Vertex Error: 13386.738975 units
# Epoch 050 | Test Loss: 34.348185 | Vertex Error: 13589.990958 units
# Epoch 050 | Test Loss: 34.852271 | Vertex Error: 13780.755210 units
# Epoch 050 | Test Loss: 35.286826 | Vertex Error: 13943.567237 units
# Epoch 050 | Test Loss: 35.800483 | Vertex Error: 14140.102698 units
# Epoch 050 | Test Loss: 36.265754 | Vertex Error: 14323.725272 units
# Epoch 050 | Test Loss: 36.703285 | Vertex Error: 14497.579719 units
# Epoch 050 | Test Loss: 37.335747 | Vertex Error: 14740.650474 units
# Epoch 050 | Test Loss: 37.863578 | Vertex Error: 14947.802817 units
# Epoch 050 | Test Loss: 38.531805 | Vertex Error: 15205.913474 units
# Epoch 050 | Test Loss: 39.088692 | Vertex Error: 15433.739188 units
# Epoch 050 | Test Loss: 39.588544 | Vertex Error: 15626.704200 units
# Epoch 050 | Test Loss: 40.276493 | Vertex Error: 15905.726569 units
# Epoch 050 | Test Loss: 40.990271 | Vertex Error: 16198.078650 units
# Epoch 050 | Test Loss: 41.481470 | Vertex Error: 16391.863395 units
# Epoch 050 | Test Loss: 42.088567 | Vertex Error: 16628.806907 units
# Epoch 050 | Test Loss: 42.589973 | Vertex Error: 16828.038733 units
# Epoch 050 | Test Loss: 43.070654 | Vertex Error: 17011.016089 units
# Epoch 050 | Test Loss: 43.556234 | Vertex Error: 17198.476111 units
# Epoch 050 | Test Loss: 43.992956 | Vertex Error: 17367.298224 units
# Epoch 050 | Test Loss: 44.520375 | Vertex Error: 17578.253303 units
# Epoch 050 | Test Loss: 45.020615 | Vertex Error: 17774.255332 units
# Epoch 050 | Test Loss: 45.405605 | Vertex Error: 17925.940207 units
# Epoch 050 | Test Loss: 46.148431 | Vertex Error: 18218.329368 units
# Epoch 050 | Test Loss: 46.705875 | Vertex Error: 18433.782126 units
# Epoch 050 | Test Loss: 47.222117 | Vertex Error: 18634.487708 units
# Epoch 050 | Test Loss: 47.903844 | Vertex Error: 18905.116828 units
# Epoch 050 | Test Loss: 48.394114 | Vertex Error: 19101.884421 units
# Epoch 050 | Test Loss: 49.097637 | Vertex Error: 19388.672690 units
# Epoch 050 | Test Loss: 49.605825 | Vertex Error: 19592.231162 units
# Epoch 050 | Test Loss: 50.001519 | Vertex Error: 19747.496543 units
# Epoch 050 | Test Loss: 50.581913 | Vertex Error: 19971.905066 units
# Epoch 050 | Test Loss: 51.165557 | Vertex Error: 20192.441398 units
# Epoch 050 | Test Loss: 51.655145 | Vertex Error: 20378.365973 units
# Epoch 050 | Test Loss: 52.110892 | Vertex Error: 20556.422492 units
# Epoch 050 | Test Loss: 52.618055 | Vertex Error: 20758.931800 units
# Epoch 050 | Test Loss: 53.405362 | Vertex Error: 21077.183784 units
# Epoch 050 | Test Loss: 53.981476 | Vertex Error: 21327.373145 units
# Epoch 050 | Test Loss: 54.429213 | Vertex Error: 21493.618690 units
# Epoch 050 | Test Loss: 54.955507 | Vertex Error: 21700.005622 units
# Epoch 050 | Test Loss: 55.523745 | Vertex Error: 21912.104041 units
# Epoch 050 | Test Loss: 55.987185 | Vertex Error: 22092.242728 units
# Epoch 050 | Test Loss: 56.402204 | Vertex Error: 22253.799247 units
# Epoch 050 | Test Loss: 56.962788 | Vertex Error: 22484.547568 units
# Epoch 050 | Test Loss: 57.632870 | Vertex Error: 22749.451194 units
# Epoch 050 | Test Loss: 58.135950 | Vertex Error: 22959.519355 units
# Epoch 050 | Test Loss: 58.642428 | Vertex Error: 23164.568091 units
# Epoch 050 | Test Loss: 59.149531 | Vertex Error: 23362.822043 units
# Epoch 050 | Test Loss: 59.802918 | Vertex Error: 23612.373099 units
# Epoch 050 | Test Loss: 60.257308 | Vertex Error: 23798.037543 units
# Epoch 050 | Test Loss: 60.697563 | Vertex Error: 23965.548911 units
# Epoch 050 | Test Loss: 61.300239 | Vertex Error: 24218.972892 units
# Epoch 050 | Test Loss: 61.967847 | Vertex Error: 24490.882255 units
# Epoch 050 | Test Loss: 62.440292 | Vertex Error: 24692.110358 units
# Epoch 050 | Test Loss: 63.028070 | Vertex Error: 24922.436698 units
# Epoch 050 | Test Loss: 63.532425 | Vertex Error: 25113.866157 units
# Epoch 050 | Test Loss: 64.051415 | Vertex Error: 25306.837012 units
# Epoch 050 | Test Loss: 64.583980 | Vertex Error: 25515.035636 units
# Epoch 050 | Test Loss: 64.993748 | Vertex Error: 25673.875876 units
# Epoch 050 | Test Loss: 65.672374 | Vertex Error: 25956.490806 units
# Epoch 050 | Test Loss: 66.369027 | Vertex Error: 26235.020682 units
# Epoch 050 | Test Loss: 66.756288 | Vertex Error: 26398.836692 units
# Epoch 050 | Test Loss: 67.391486 | Vertex Error: 26652.636634 units
# Epoch 050 | Test Loss: 67.914681 | Vertex Error: 26856.034110 units
# Epoch 050 | Test Loss: 68.422627 | Vertex Error: 27051.523826 units
# Epoch 050 | Test Loss: 69.019958 | Vertex Error: 27286.231299 units
# Epoch 050 | Test Loss: 69.469929 | Vertex Error: 27461.492866 units
# Epoch 050 | Test Loss: 70.187452 | Vertex Error: 27763.398200 units
# Epoch 050 | Test Loss: 70.847390 | Vertex Error: 28033.128852 units
# Epoch 050 | Test Loss: 71.240908 | Vertex Error: 28196.275840 units
# Epoch 050 | Test Loss: 71.867678 | Vertex Error: 28436.053519 units
# Epoch 050 | Test Loss: 72.415628 | Vertex Error: 28639.852256 units
# Epoch 050 | Test Loss: 72.885899 | Vertex Error: 28819.599265 units
# Epoch 050 | Test Loss: 73.408836 | Vertex Error: 29023.697272 units
# Epoch 050 | Test Loss: 73.866400 | Vertex Error: 29206.600883 units
# Epoch 050 | Test Loss: 74.737099 | Vertex Error: 29558.459830 units
# Epoch 050 | Test Loss: 75.369077 | Vertex Error: 29826.105247 units
# Epoch 050 | Test Loss: 75.845410 | Vertex Error: 30016.664435 units
# Epoch 050 | Test Loss: 76.404150 | Vertex Error: 30234.643394 units
# Epoch 050 | Test Loss: 77.019347 | Vertex Error: 30463.122962 units
# Epoch 050 | Test Loss: 77.491492 | Vertex Error: 30646.302039 units
# Epoch 050 | Test Loss: 77.892790 | Vertex Error: 30803.676490 units
# Epoch 050 | Test Loss: 78.436647 | Vertex Error: 31022.785560 units
# Epoch 050 | Test Loss: 79.206001 | Vertex Error: 31330.217139 units
# Epoch 050 | Test Loss: 79.846888 | Vertex Error: 31609.282996 units
# Epoch 050 | Test Loss: 80.335412 | Vertex Error: 31793.723868 units
# Epoch 050 | Test Loss: 80.870915 | Vertex Error: 32009.633613 units
# Epoch 050 | Test Loss: 81.494176 | Vertex Error: 32250.985923 units
# Epoch 050 | Test Loss: 82.000965 | Vertex Error: 32447.984611 units
# Epoch 050 | Test Loss: 82.465308 | Vertex Error: 32629.944938 units
# Epoch 050 | Test Loss: 83.080874 | Vertex Error: 32889.039359 units
# Epoch 050 | Test Loss: 83.738287 | Vertex Error: 33145.236075 units
# Epoch 050 | Test Loss: 84.284556 | Vertex Error: 33369.105552 units
# Epoch 050 | Test Loss: 84.792369 | Vertex Error: 33576.106711 units
# Epoch 050 | Test Loss: 85.303036 | Vertex Error: 33781.961539 units
# Epoch 050 | Test Loss: 86.002762 | Vertex Error: 34058.065848 units
# Epoch 050 | Test Loss: 86.498289 | Vertex Error: 34255.644553 units
# Epoch 050 | Test Loss: 87.082867 | Vertex Error: 34307.587096 units
# Epoch 050 | Train Loss: 0.554822 | Test Loss: 0.554668 | Avg Vertex Error: 1.143815 units

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# 1. Combine the collected batches into single large arrays
preds_np = np.concatenate(all_pred_deltas, axis=0)     # Shape: (Total_Frames, Vertices, 3)
targets_np = np.concatenate(all_target_deltas, axis=0) # Shape: (Total_Frames, Vertices, 3)

# 2. Reshape to 2D: (Total_Frames, Vertices * 3)
preds_2d = preds_np.reshape(preds_np.shape[0], -1)
targets_2d = targets_np.reshape(targets_np.shape[0], -1)

# 3. Initialize PCA
pca = PCA(n_components=2) # 2 components for a 2D scatter plot

# CRITICAL: Fit the PCA on the TARGETS (Ground Truth) to define the coordinate space.
# If you fit two separate PCAs, the axes will mean different things and you cannot compare them!
pca.fit(targets_2d)

# Transform both datasets into this shared PCA space
pca_targets = pca.transform(targets_2d)
pca_preds = pca.transform(preds_2d)

# 4. Plot the comparison
plt.figure(figsize=(10, 8))

# Plot ground truth in blue
plt.scatter(pca_targets[:, 0], pca_targets[:, 1], alpha=0.5, label='Ground Truth (Targets)', color='blue', s=10)

# Plot predictions in red
plt.scatter(pca_preds[:, 0], pca_preds[:, 1], alpha=0.5, label='Model Predictions', color='red', s=10)

plt.title('PCA of Cloth Dynamics: Ground Truth vs Predictions')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Flatten the arrays so we just have a massive list of X, Y, and Z coordinates
true_flat = targets_pos_np.reshape(-1)
pred_flat = preds_pos_np.reshape(-1)

plt.figure(figsize=(12, 12))
plt.scatter(true_flat, pred_flat, alpha=0.1, color='purple', s=2)

# Draw the perfect prediction line (y = x)
min_val = min(true_flat.min(), pred_flat.min())
max_val = max(true_flat.max(), pred_flat.max())
plt.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='--', linewidth=2, label='Perfect Prediction')

plt.title('Predicted vs. Real Positions (All Coordinates)')
plt.xlabel('Real Position Coordinate')
plt.ylabel('Predicted Position Coordinate')
plt.legend()
plt.grid(True)
plt.axis('equal') # Keeps the aspect ratio square
plt.show()

# %%
# Choose a random frame from your test set to visualize
frame_idx = 20 # Change this to look at different moments
num_vertices = targets_pos_np.shape[1]

real_frame = targets_pos_np[frame_idx] # Shape: (Vertices, 3)
pred_frame = preds_pos_np[frame_idx]   # Shape: (Vertices, 3)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Extract X, Y, Z for Real positions
rx, ry, rz = real_frame[:, 0], real_frame[:, 1], real_frame[:, 2]
# Extract X, Y, Z for Predicted positions
px, py, pz = pred_frame[:, 0], pred_frame[:, 1], pred_frame[:, 2]

# Plot the real cloth vertices in Blue
ax.scatter(rx, ry, rz, c='blue', label='Real Shape', s=50, marker='o')

# Plot the predicted cloth vertices in Red
ax.scatter(px, py, pz, c='red', label='Predicted Shape', s=50, marker='x')

# Draw lines connecting the predicted vertex to the real vertex to show the error
for i in range(num_vertices):
    ax.plot([rx[i], px[i]], [ry[i], py[i]], [rz[i], pz[i]], color='gray', linestyle='dotted')

ax.set_title(f'Cloth Shape Comparison (Frame {frame_idx})')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()
plt.show()

# %%
import torch
import sys
import onnx
import onnxruntime

# 1. Load your trained model (make sure it's in eval mode)
model.eval()

# 2. Create a dummy input strictly enforcing the 3D shape: (Batch=3, Vertices=6, Features=13)
# It doesn't matter what the numbers are, ONNX just needs the shape.
dummy_input = torch.randn(1, 6, 4)

# 3. Export to ONNX
onnx_program = torch.onnx.export(
    model,                      # Your trained PyTorch model
    dummy_input,                # The strictly 3D input tensor
    "verificacionBig.onnx",         # Output file name
    export_params=True,         # Store the trained weights
    opset_version=9,            # Sentis handles opset 9-15 well
    input_names=['input'],      # Name the input for Unity
    output_names=['output'],    # Name the output for Unity
)

print("Exported to ONNX with strict 3D shapes!")
# Out:
# Exported to ONNX with strict 3D shapes!

# %%
# Debugging: Check baseline error (predicting zero displacement)
model.eval()
baseline_error = 0.0
total_vertices = 0
with torch.no_grad():
    for batch_t, batch_t1 in test_loader:
        positions_t = batch_t[..., 0:3]
        target_delta = batch_t1 - positions_t
        zero_pred = torch.zeros_like(target_delta)
        distances = torch.norm(zero_pred - target_delta, dim=-1)
        baseline_error += distances.sum().item()
        total_vertices += distances.numel()
avg_baseline_error = baseline_error / total_vertices
print(f"Baseline error (predicting zero): {avg_baseline_error:.6f} units")

# Check initial predictions before training
model = MyModule(num_inputs=13, num_hidden=64, num_outputs=3)  # Reinitialize model
model.eval()
initial_error = 0.0
with torch.no_grad():
    for batch_t, batch_t1 in test_loader:
        batch_t_norm = (batch_t.float() - input_mean) / input_std
        positions_t = batch_t[..., 0:3]
        target_delta = batch_t1 - positions_t
        pred_delta = model(batch_t_norm)
        distances = torch.norm(pred_delta - target_delta, dim=-1)
        initial_error += distances.sum().item()
avg_initial_error = initial_error / total_vertices
print(f"Initial error (random weights): {avg_initial_error:.6f} units")
# Out:
# Baseline error (predicting zero): 0.071775 units
# Initial error (random weights): 0.288819 units
