# %% [markdown]
# - Cloth**Dataset** guarda la info d vertices x caracteristicas () al acceder a estos items con el **DataLoader** le añade la otra dimension d frames(batchsize) para crear el tensor3D
# - Redondear valores para optimizar (ahorra memoria)
#
# Otra idea sería:
# > When to add a frame dimension (Sequence modeling): If your model needs temporal history—meaning it needs to look at, say, the last 5 frames to figure out what happens in the 6th frame. If you were using an LSTM, RNN, or a Spatiotemporal Transformer, your tensor would need to look like [Batch, Sequence_Length, Vertices, Features].
# Por ahora no.
#
# **Links Utilizados:**
# - https://docs.pytorch.org/tutorials/beginner/data_loading_tutorial.html
# - https://lixiaoguang.medium.com/build-cnn-from-scratch-5-convolutional-neural-network-86b4d0323fb0

# %%
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import io
import torch
import os, os.path

# WORKING WITH 
datasetPath = 'data/'

def loadAndMergeCSV(csvRoute):
    """
    Carga de los CSV y mergeo en un único CSV. Todos los CSV estarán en la ruta 'data/', y se excluirá el CSV
    'mergedCSV.csv', producto de los mergeos si se ejecutase antes
    """
    csvRoute= 'data/'
    finalData = pd.DataFrame()
    for csvfile in [f for f in os.listdir(csvRoute) if os.path.isfile(csvRoute + f)]:
        if (csvfile != 'mergedCSV.csv' and os.path.splitext(csvfile)[1] == '.csv'):
            data = pd.read_csv(csvRoute + csvfile)
            finalData = pd.concat([data, finalData], ignore_index=True)

    return finalData

cloth_info = loadAndMergeCSV(datasetPath)

print('cloth_info shape: {}'.format(cloth_info.shape))
print('cloth_info: \n{}'.format(cloth_info))
# Out:
# cloth_info shape: (8651, 79)
# cloth_info:
#       frame        x0        y0        z0       vx0       vy0       vz0  \
# 0       0.0  0.000000  0.000000 -0.225496  0.000000  0.000000  0.000000
# 1       1.0  0.000000  0.000000 -0.225496  0.000000  0.000000  0.000000
# 2       2.0  0.000000  0.000026 -0.225440  0.000000  0.001297  0.002802
# 3       3.0  0.000000  0.000026 -0.225440  0.000000  0.000000  0.000000
# 4       4.0  0.000000  0.000026 -0.225440  0.000000  0.000000  0.000000
# ...     ...       ...       ...       ...       ...       ...       ...
# 8646  962.0  0.157363  0.025369 -0.224964 -1.086650 -0.390958  0.008215
# 8647  963.0 -0.233118  0.057472 -0.225401 -0.294769  0.151934  0.002072
# 8648  964.0  0.119846  0.014439 -0.225210  1.048161  0.232948  0.000405
# 8649  965.0 -0.229389  0.055461 -0.224767 -1.047083  0.520957 -0.001996
# 8650  966.0 -0.123866  0.015047 -0.223186 -0.054961  0.012746 -0.009976
#
#           sdf0       nx0       ny0  ...  vx5  vy5  vz5      sdf5       nx5  \
# 0     0.549670 -0.913620  0.405842  ...  0.0  0.0  0.0  0.899358 -0.685314
# 1     0.535072 -0.911047  0.411565  ...  0.0  0.0  0.0  0.888442 -0.679178
# 2     0.520527 -0.908355  0.417457  ...  0.0  0.0  0.0  0.877625 -0.672897
# 3     0.520527 -0.908355  0.417457  ...  0.0  0.0  0.0  0.877625 -0.672897
# 4     0.520527 -0.908355  0.417457  ...  0.0  0.0  0.0  0.877625 -0.672897
# ...        ...       ...       ...  ...  ...  ...  ...       ...       ...
# 8646  0.932110 -0.948873  0.315178  ...  0.0  0.0  0.0  1.326895 -0.829962
# 8647  0.841503 -0.932607  0.360396  ...  0.0  0.0  0.0  0.940417 -0.706724
# 8648  0.096942 -0.673668  0.737826  ...  0.0  0.0  0.0  0.644986 -0.455889
# 8649  0.046048 -0.469589  0.881719  ...  0.0  0.0  0.0  0.519438 -0.026514
# 8650  0.060474  0.615669  0.786918  ...  0.0  0.0  0.0  0.621793  0.418020
#
#            ny5       nz5  md5   u5   v5
# 0     0.661732  0.304065  0.0  0.0  1.0
# 1     0.666934  0.306456  0.0  0.0  1.0
# 2     0.672171  0.308862  0.0  0.0  1.0
# 3     0.672171  0.308862  0.0  0.0  1.0
# 4     0.672171  0.308862  0.0  0.0  1.0
# ...        ...       ...  ...  ...  ...
# 8646  0.506871  0.232907  0.0  0.0  1.0
# 8647  0.642869  0.295398  0.0  0.0  1.0
# 8648  0.808743  0.371617  0.0  0.0  1.0
# 8649  0.908344  0.417383  0.0  0.0  1.0
# 8650  0.825464  0.379300  0.0  0.0  1.0
#
# [8651 rows x 79 columns]

# %%
#Importación de funciones de los diferentes archivos
import pandas as pd
import numpy as np
import os
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, OneHotEncoder

import matplotlib.pyplot as plt

# Guardo todos los datos
df = pd.read_csv('data/clothDataset_38_.csv') 
md_cols = df.loc[:, df.columns.str.startswith('md')].iloc[0]

print(md_cols)
X = df

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 5. Apply PCA
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

# 6. Visualizationplt.figure(figsize=(10, 7))
plt.figure(figsize=(10, 7))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], cmap='viridis')
plt.title('PCA Distribution of Cloth Classes')
plt.title('PCA Distribution of Cloth Classes')
plt.xlabel(f'Principal Component 1 ({pca.explained_variance_ratio_[0]:.2%} var)')
plt.ylabel(f'Principal Component 2 ({pca.explained_variance_ratio_[1]:.2%} var)')
plt.colorbar(scatter, label='Classes')
plt.grid(True, alpha=0.3)


plt.show()
# Out:
# md0     1
# md1     1
# md2     1
# md3     1
# md4     1
# md5     1
# md6     1
# md7     1
# md8     1
# md9     1
# md10    1
# md11    1
# md12    1
# md13    1
# md14    0
# md15    0
# md16    1
# md17    1
# md18    1
# md19    1
# md20    0
# md21    1
# md22    1
# md23    0
# md24    0
# Name: 0, dtype: int64
# C:\Users\mikel\AppData\Local\Temp\ipykernel_29724\2043368657.py:26: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], cmap='viridis')

# %%
#ADAPTAR DATAFRAME PARA EL RNN
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

# 1. Cargar el dataset
csv_path = 'data/clothDataset_38_.csv' # Asegúrate de que la ruta sea correcta
df = pd.read_csv(csv_path)

# cargamos los merged
#df = cloth_info

num_vertices = 25

# 2. Seleccionar SOLO las columnas que queremos en el orden correcto
# Queremos: x0, y0, z0, sdf0, x1, y1, z1, sdf1...
selected_columns = []
for i in range(num_vertices): # Para los num_vertices vértices
    selected_columns.extend([f'x{i}', f'y{i}', f'z{i}', f'sdf{i}'])

# Filtramos el DataFrame
df_filtered = df[selected_columns]

# 3. Extraer valores y hacer reshape a 3D
data_flat = df_filtered.values
num_frames = data_flat.shape[0]
num_features = 4

# 4. Reestructurar (Reshape) a 3D
# Numpy reorganiza los 78 valores de cada fila en una cuadrícula de num_vertices x num_features
data_3d = data_flat.reshape((num_frames, num_vertices, num_features))

# 5. Convertir a Tensor de PyTorch
data_tensor = torch.tensor(data_3d, dtype=torch.float32)

print(f"Forma de los datos aplanados: {data_flat.shape}")
print(f"Forma del Tensor 3D final: {data_tensor.shape}")
# Salida esperada: 
# Forma de los datos aplanados: (966, 78)
# Forma del Tensor 3D final: torch.Size([966, 6, 13])
# Out:
# Forma de los datos aplanados: (1000, 100)
# Forma del Tensor 3D final: torch.Size([1000, 25, 4])

# %%
class ClothSequenceDataset(Dataset):
    def __init__(self, data_frames, seq_len=5):
        """
        Argumentos:
        data_frames: Tensor o arreglo de NumPy con todos tus frames en orden secuencial.
                     Forma esperada: [Total_Frames, Vertices, Features]
        seq_len: La cantidad de frames "históricos" que la red usará para predecir el siguiente.
        """
        # Convertimos a tensor si aún no lo es
        if not isinstance(data_frames, torch.Tensor):
            self.data_frames = torch.tensor(data_frames, dtype=torch.float32)
        else:
            self.data_frames = data_frames
            
        self.seq_len = seq_len

    def __len__(self):
        # La longitud total es el número de frames menos el tamaño de la secuencia.
        # ¿Por qué? Si tienes 100 frames y secuencias de 5, el último bloque que 
        # puedes formar es del frame 94 al 98, para predecir el frame 99.
        return len(self.data_frames) - self.seq_len

    def __getitem__(self, idx):
        # Extraemos la secuencia histórica (ventana temporal)
        # Forma: [Seq_Len, Vertices, Features]
        sequence = self.data_frames[idx : idx + self.seq_len]
        
        # El "target" es el frame inmediatamente posterior a la secuencia
        # Forma: [Vertices, Features]
        target_frame = self.data_frames[idx + self.seq_len]
        
        return sequence, target_frame

# --- Example Usage ---
# --- Parámetros de la secuencia ---
seq_length = 5 # La RNN mirará 5 frames atrás
batch_size = 32

# Instanciar el Dataset
dataset = ClothSequenceDataset(data_tensor, seq_len=seq_length)

# Crear el DataLoader
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Comprobar el primer Batch
for batch_seq, batch_target in train_loader:
    print(f"\nBatch Secuencia (Entrada RNN): {batch_seq.shape}") 
    # Esperado: [32, 5, 6, 13] -> [Batch, Secuencia, Vértices, Features]
    
    print(f"Batch Objetivo (Target): {batch_target.shape}")   
    # Esperado: [32, 6, 13] -> [Batch, Vértices, Features]
    break
# Out:
# Batch Secuencia (Entrada RNN): torch.Size([32, 5, 25, 4])
# Batch Objetivo (Target): torch.Size([32, 25, 4])

# %%
import torch
import torch.nn as nn

class FlatRNNClothUnity(nn.Module):
    def __init__(self, num_vertices, num_features, hidden_size, num_outputs=3):
        super(FlatRNNClothUnity, self).__init__()
        
        self.num_vertices = num_vertices
        self.num_outputs = num_outputs
        
        self.input_size = num_vertices * num_features 
        self.hidden_size = hidden_size
        
        # 1. CAMBIO: Usamos RNNCell en lugar de RNN
        # Un "Cell" procesa un solo frame a la vez. No usa batch_first.
        self.rnn_cell = nn.RNNCell(input_size=self.input_size, 
                                   hidden_size=self.hidden_size, 
                                   nonlinearity='relu') 
        
        self.fc = nn.Linear(self.hidden_size, num_vertices * num_outputs)

    def forward(self, x):
        # Forma esperada de x: [Batch, Sequence_Length, Vertices, Features]
        batch_size = x.size(0)
        seq_len = x.size(1)
        
        # Aplanar el espacio: [Batch, Seq_Len, Vertices * Features]
        x_flat = x.view(batch_size, seq_len, -1)
        
        # 2. CAMBIO: Inicializamos el estado oculto (memoria de la red) a ceros
        h_t = torch.zeros(batch_size, self.hidden_size, device=x.device)
        
        # 3. CAMBIO: Bucle manual a través de la secuencia temporal (5 frames)
        for t in range(seq_len):
            # Le pasamos el frame actual y la memoria del frame anterior
            h_t = self.rnn_cell(x_flat[:, t, :], h_t)
            
        # Al terminar el bucle, 'h_t' contiene la información del ÚLTIMO frame (el frame 5)
        # Esto evita tener que hacer el slice out[:, -1, :] que rompía Unity
        
        # Pasar por la capa lineal
        pred_flat = self.fc(h_t) 
        
        # Restaurar a 3D
        pred_delta = pred_flat.view(batch_size, self.num_vertices, self.num_outputs)
        
        return pred_delta

# %%
import torch
from torch.utils.data import random_split, DataLoader
import json

# ==============================================================================
# 1. SPLIT THE DATA (80% Training, 20% Testing)
# ==============================================================================
"""
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

#TODO: vigilar esto!!!
# Nota: Al usar random_split, mezclamos secuencias de 5 frames de forma aleatoria.
# Esto suele funcionar bien, aunque para algunos problemas físicos puristas a veces 
# se divide cronológicamente (ej. primeros 80% frames para train, últimos 20% para test).
# Por ahora mantendremos random_split que es el enfoque estándar general.
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
"""

train_dataset, test_dataset = dataset, dataset

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# ==============================================================================
# 2. COMPUTE GLOBAL STATS (Only on training data to prevent data leakage)
# ==============================================================================
all_inputs = []
all_targets = []

# Iteramos sobre el TRAIN LOADER específicamente
for batch_seq, batch_target in train_loader:
    # batch_seq shape: [Batch, Seq_Len, Vertices, Features (4)]
    # Aplanamos para agrupar todas las características y calcular medias por Feature
    # Nueva forma temporal: (Batch * Seq_Len * Vertices, 4)
    all_inputs.append(batch_seq.view(-1, 4))
    
    # Calcular el target (Desplazamiento / Delta)
    # 1. Extraemos las posiciones x, y, z (índices 0:3) del ÚLTIMO frame de la secuencia
    last_frame_pos = batch_seq[:, -1, :, 0:3] 
    
    # 2. Restamos la posición del frame objetivo para sacar el delta
    # batch_target shape: [Batch, Vertices, Features (4)]
    delta = batch_target[:, :, 0:3] - last_frame_pos
    
    # Guardamos los deltas aplanados: (Batch * Vertices, 3)
    all_targets.append(delta.view(-1, 3))

# Combinar todas las listas en un solo tensor gigante
full_input_tensor = torch.cat(all_inputs, dim=0)
full_target_tensor = torch.cat(all_targets, dim=0)

# Calcular las estadísticas globales (mean y std a lo largo de la columna)
input_mean = full_input_tensor.mean(dim=0)
input_std = full_input_tensor.std(dim=0)
target_mean = full_target_tensor.mean(dim=0)
target_std = full_target_tensor.std(dim=0)

print("Forma de input_mean:", input_mean.shape) # Debería ser [13]
print("Forma de target_mean:", target_mean.shape) # Debería ser [3]

# ==============================================================================
# 3. SAVE TO JSON
# ==============================================================================
norm_data = {
    "mean": input_mean.tolist(),
    "std": input_std.tolist(),
    "target_mean": target_mean.tolist(),
    "target_std": target_std.tolist()
}
with open("cloth_norm_params.json", "w") as f:
    json.dump(norm_data, f)

# ==============================================================================
# 4. SETUP MODEL
# ==============================================================================
model = FlatRNNClothUnity(num_vertices=num_vertices, num_features=4, hidden_size=128, num_outputs=3)
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# ==============================================================================
# 5. TRAINING & TESTING LOOP
# ==============================================================================
epochs = 500
for epoch in range(epochs):
    
    # --- TRAINING PHASE ---
    model.train() 
    noise_scale = 0.02
    train_loss = 0.0
    
    for batch_seq_t, batch_target in train_loader:
        batch_seq_t = batch_seq_t.float()  
        batch_target = batch_target.float() 
        
        # 1. Normalizar toda la secuencia de entrada 
        batch_seq_t_norm = (batch_seq_t - input_mean) / input_std
        
        # Creamos un ruido Gaussiano con la misma forma que nuestra entrada
        noise = torch.randn_like(batch_seq_t_norm) * noise_scale
        
        # Le sumamos el ruido al input histórico
        batch_seq_t_norm += noise

        # 2. Target Delta
        last_frame_positions = batch_seq_t[:, -1, :, 0:3] 
        target_delta = batch_target[..., 0:3] - last_frame_positions
        target_delta_norm = (target_delta - target_mean) / target_std
        
        # 3. Predicción
        pred_delta_norm = model(batch_seq_t_norm)
        
        # 4. Retropropagación
        loss = criterion(pred_delta_norm, target_delta_norm)
    
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        
        train_loss += loss.item()

    print(f'Train Epoch {epoch+1:03d}')

    avg_train_loss = train_loss / len(train_loader)

    # --- TESTING/VALIDATION PHASE ---
    model.eval() 
    test_loss = 0.0
    total_distance_error = 0.0
    total_vertices = 0

    all_pred_deltas = []
    all_target_deltas = []
    all_pred_pos = []
    all_target_pos = []
    
    with torch.no_grad():
        # CORRECCIÓN: Usamos batch_seq_t y batch_target igual que en train
        for batch_seq_t, batch_target in test_loader:
            batch_seq_t = batch_seq_t.float()
            batch_target = batch_target.float()

            batch_seq_t_norm = (batch_seq_t - input_mean) / input_std
            
            pred_delta_norm = model(batch_seq_t_norm)
            
            # CORRECCIÓN: Extraemos posiciones del último frame de la secuencia
            last_frame_positions = batch_seq_t[:, -1, :, 0:3] 
            
            # Target delta (Posición real del siguiente frame - Posición del último frame)
            target_delta = batch_target[..., 0:3] - last_frame_positions
            target_delta_norm = (target_delta - target_mean) / target_std

            loss = criterion(pred_delta_norm, target_delta_norm)
            test_loss += loss.item()

            # --- Reconstruct the absolute positions ---
            pred_delta_real = (pred_delta_norm * target_std) + target_mean
            pred_pos = last_frame_positions + pred_delta_real
            target_pos = batch_target[..., 0:3] # The true final position

            # Store them
            all_pred_pos.append(pred_pos.cpu().numpy())
            all_target_pos.append(target_pos.cpu().numpy())
            
            # Calculate our "Accuracy" (Mean Distance Error per vertex)
            distances = torch.norm(pred_delta_real - target_delta, dim=-1)
            total_distance_error += distances.sum().item()
            total_vertices += distances.numel()

            # Store the data for PCA
            all_pred_deltas.append(pred_delta_real.cpu().numpy())
            all_target_deltas.append(target_delta.cpu().numpy())

    avg_test_loss = test_loss / len(test_loader)
    avg_distance_error = total_distance_error / total_vertices

    # Combine into large arrays
    preds_pos_np = np.concatenate(all_pred_pos, axis=0)
    targets_pos_np = np.concatenate(all_target_pos, axis=0)

    print(f'Epoch {epoch+1:03d} | Train Loss: {avg_train_loss:.6f} | Test Loss: {avg_test_loss:.6f} | Avg Vertex Error: {avg_distance_error:.6f} units')
# Out:
# Forma de input_mean: torch.Size([4])
# Forma de target_mean: torch.Size([3])
# Train Epoch 001
# Epoch 001 | Train Loss: 0.577860 | Test Loss: 0.555347 | Avg Vertex Error: 0.058923 units
# Train Epoch 002
# Epoch 002 | Train Loss: 0.546631 | Test Loss: 0.538843 | Avg Vertex Error: 0.057407 units
# Train Epoch 003
# Epoch 003 | Train Loss: 0.534851 | Test Loss: 0.529821 | Avg Vertex Error: 0.056397 units
# Train Epoch 004
# Epoch 004 | Train Loss: 0.526883 | Test Loss: 0.522328 | Avg Vertex Error: 0.055456 units
# Train Epoch 005
# Epoch 005 | Train Loss: 0.518335 | Test Loss: 0.512623 | Avg Vertex Error: 0.054125 units
# Train Epoch 006
# Epoch 006 | Train Loss: 0.506433 | Test Loss: 0.497682 | Avg Vertex Error: 0.051814 units
# Train Epoch 007
# Epoch 007 | Train Loss: 0.487895 | Test Loss: 0.474310 | Avg Vertex Error: 0.047811 units
# Train Epoch 008
# Epoch 008 | Train Loss: 0.459400 | Test Loss: 0.438939 | Avg Vertex Error: 0.041510 units
# Train Epoch 009
# Epoch 009 | Train Loss: 0.419870 | Test Loss: 0.397360 | Avg Vertex Error: 0.034411 units
# Train Epoch 010
# Epoch 010 | Train Loss: 0.379035 | Test Loss: 0.361983 | Avg Vertex Error: 0.029010 units
# Train Epoch 011
# Epoch 011 | Train Loss: 0.350148 | Test Loss: 0.337729 | Avg Vertex Error: 0.026052 units
# Train Epoch 012
# Epoch 012 | Train Loss: 0.331585 | Test Loss: 0.323025 | Avg Vertex Error: 0.024665 units
# Train Epoch 013
# Epoch 013 | Train Loss: 0.318618 | Test Loss: 0.312121 | Avg Vertex Error: 0.023733 units
# Train Epoch 014
# Epoch 014 | Train Loss: 0.309866 | Test Loss: 0.304660 | Avg Vertex Error: 0.023158 units
# Train Epoch 015
# Epoch 015 | Train Loss: 0.302569 | Test Loss: 0.298732 | Avg Vertex Error: 0.022690 units
# Train Epoch 016
# Epoch 016 | Train Loss: 0.297628 | Test Loss: 0.293250 | Avg Vertex Error: 0.022283 units
# Train Epoch 017
# Epoch 017 | Train Loss: 0.292693 | Test Loss: 0.289096 | Avg Vertex Error: 0.021957 units
# Train Epoch 018
# Epoch 018 | Train Loss: 0.288599 | Test Loss: 0.285314 | Avg Vertex Error: 0.021670 units
# Train Epoch 019
# Epoch 019 | Train Loss: 0.285208 | Test Loss: 0.281945 | Avg Vertex Error: 0.021397 units
# Train Epoch 020
# Epoch 020 | Train Loss: 0.281935 | Test Loss: 0.278627 | Avg Vertex Error: 0.021134 units
# Train Epoch 021
# Epoch 021 | Train Loss: 0.278901 | Test Loss: 0.275880 | Avg Vertex Error: 0.020910 units
# Train Epoch 022
# Epoch 022 | Train Loss: 0.276109 | Test Loss: 0.273344 | Avg Vertex Error: 0.020703 units
# Train Epoch 023
# Epoch 023 | Train Loss: 0.273789 | Test Loss: 0.270881 | Avg Vertex Error: 0.020511 units
# Train Epoch 024
# Epoch 024 | Train Loss: 0.271338 | Test Loss: 0.268610 | Avg Vertex Error: 0.020322 units
# Train Epoch 025
# Epoch 025 | Train Loss: 0.269100 | Test Loss: 0.267071 | Avg Vertex Error: 0.020198 units
# Train Epoch 026
# Epoch 026 | Train Loss: 0.267441 | Test Loss: 0.264692 | Avg Vertex Error: 0.020007 units
# Train Epoch 027
# Epoch 027 | Train Loss: 0.265552 | Test Loss: 0.262563 | Avg Vertex Error: 0.019823 units
# Train Epoch 028
# Epoch 028 | Train Loss: 0.263408 | Test Loss: 0.261125 | Avg Vertex Error: 0.019704 units
# Train Epoch 029
# Epoch 029 | Train Loss: 0.262080 | Test Loss: 0.259512 | Avg Vertex Error: 0.019568 units
# Train Epoch 030
# Epoch 030 | Train Loss: 0.260412 | Test Loss: 0.257672 | Avg Vertex Error: 0.019401 units
# Train Epoch 031
# Epoch 031 | Train Loss: 0.258619 | Test Loss: 0.256633 | Avg Vertex Error: 0.019320 units
# Train Epoch 032
# Epoch 032 | Train Loss: 0.257357 | Test Loss: 0.255073 | Avg Vertex Error: 0.019185 units
# Train Epoch 033
# Epoch 033 | Train Loss: 0.256105 | Test Loss: 0.253455 | Avg Vertex Error: 0.019033 units
# Train Epoch 034
# Epoch 034 | Train Loss: 0.254456 | Test Loss: 0.252586 | Avg Vertex Error: 0.018966 units
# Train Epoch 035
# Epoch 035 | Train Loss: 0.253376 | Test Loss: 0.251092 | Avg Vertex Error: 0.018832 units
# Train Epoch 036
# Epoch 036 | Train Loss: 0.252095 | Test Loss: 0.249911 | Avg Vertex Error: 0.018713 units
# Train Epoch 037
# Epoch 037 | Train Loss: 0.250924 | Test Loss: 0.249201 | Avg Vertex Error: 0.018659 units
# Train Epoch 038
# Epoch 038 | Train Loss: 0.250062 | Test Loss: 0.248025 | Avg Vertex Error: 0.018530 units
# Train Epoch 039
# Epoch 039 | Train Loss: 0.249139 | Test Loss: 0.246767 | Avg Vertex Error: 0.018412 units
# Train Epoch 040
# Epoch 040 | Train Loss: 0.247713 | Test Loss: 0.246192 | Avg Vertex Error: 0.018355 units
# Train Epoch 041
# Epoch 041 | Train Loss: 0.247134 | Test Loss: 0.245046 | Avg Vertex Error: 0.018247 units
# Train Epoch 042
# Epoch 042 | Train Loss: 0.246140 | Test Loss: 0.244198 | Avg Vertex Error: 0.018147 units
# Train Epoch 043
# Epoch 043 | Train Loss: 0.245387 | Test Loss: 0.243716 | Avg Vertex Error: 0.018140 units
# Train Epoch 044
# Epoch 044 | Train Loss: 0.244745 | Test Loss: 0.242448 | Avg Vertex Error: 0.017976 units
# Train Epoch 045
# Epoch 045 | Train Loss: 0.243516 | Test Loss: 0.242148 | Avg Vertex Error: 0.017999 units
# Train Epoch 046
# Epoch 046 | Train Loss: 0.242932 | Test Loss: 0.241001 | Avg Vertex Error: 0.017826 units
# Train Epoch 047
# Epoch 047 | Train Loss: 0.242221 | Test Loss: 0.240692 | Avg Vertex Error: 0.017843 units
# Train Epoch 048
# Epoch 048 | Train Loss: 0.241638 | Test Loss: 0.239427 | Avg Vertex Error: 0.017653 units
# Train Epoch 049
# Epoch 049 | Train Loss: 0.240665 | Test Loss: 0.239608 | Avg Vertex Error: 0.017760 units
# Train Epoch 050
# Epoch 050 | Train Loss: 0.240434 | Test Loss: 0.238494 | Avg Vertex Error: 0.017567 units
# Train Epoch 051
# Epoch 051 | Train Loss: 0.239855 | Test Loss: 0.238227 | Avg Vertex Error: 0.017578 units
# Train Epoch 052
# Epoch 052 | Train Loss: 0.239133 | Test Loss: 0.236988 | Avg Vertex Error: 0.017402 units
# Train Epoch 053
# Epoch 053 | Train Loss: 0.238177 | Test Loss: 0.237334 | Avg Vertex Error: 0.017524 units
# Train Epoch 054
# Epoch 054 | Train Loss: 0.238337 | Test Loss: 0.236377 | Avg Vertex Error: 0.017334 units
# Train Epoch 055
# Epoch 055 | Train Loss: 0.237907 | Test Loss: 0.236428 | Avg Vertex Error: 0.017422 units
# Train Epoch 056
# Epoch 056 | Train Loss: 0.237190 | Test Loss: 0.235230 | Avg Vertex Error: 0.017244 units
# Train Epoch 057
# Epoch 057 | Train Loss: 0.236375 | Test Loss: 0.234517 | Avg Vertex Error: 0.017177 units
# Train Epoch 058
# Epoch 058 | Train Loss: 0.235339 | Test Loss: 0.234503 | Avg Vertex Error: 0.017161 units
# Train Epoch 059
# Epoch 059 | Train Loss: 0.235431 | Test Loss: 0.233668 | Avg Vertex Error: 0.017092 units
# Train Epoch 060
# Epoch 060 | Train Loss: 0.234461 | Test Loss: 0.233685 | Avg Vertex Error: 0.017051 units
# Train Epoch 061
# Epoch 061 | Train Loss: 0.234808 | Test Loss: 0.232799 | Avg Vertex Error: 0.016983 units
# Train Epoch 062
# Epoch 062 | Train Loss: 0.233736 | Test Loss: 0.233262 | Avg Vertex Error: 0.017031 units
# Train Epoch 063
# Epoch 063 | Train Loss: 0.234396 | Test Loss: 0.231815 | Avg Vertex Error: 0.016875 units
# Train Epoch 064
# Epoch 064 | Train Loss: 0.232602 | Test Loss: 0.232052 | Avg Vertex Error: 0.016903 units
# Train Epoch 065
# Epoch 065 | Train Loss: 0.233169 | Test Loss: 0.230992 | Avg Vertex Error: 0.016809 units
# Train Epoch 066
# Epoch 066 | Train Loss: 0.231734 | Test Loss: 0.230974 | Avg Vertex Error: 0.016790 units
# Train Epoch 067
# Epoch 067 | Train Loss: 0.232001 | Test Loss: 0.229740 | Avg Vertex Error: 0.016655 units
# Train Epoch 068
# Epoch 068 | Train Loss: 0.230756 | Test Loss: 0.230060 | Avg Vertex Error: 0.016689 units
# Train Epoch 069
# Epoch 069 | Train Loss: 0.231135 | Test Loss: 0.229076 | Avg Vertex Error: 0.016584 units
# Train Epoch 070
# Epoch 070 | Train Loss: 0.229898 | Test Loss: 0.229303 | Avg Vertex Error: 0.016624 units
# Train Epoch 071
# Epoch 071 | Train Loss: 0.230346 | Test Loss: 0.228321 | Avg Vertex Error: 0.016543 units
# Train Epoch 072
# Epoch 072 | Train Loss: 0.229290 | Test Loss: 0.227416 | Avg Vertex Error: 0.016407 units
# Train Epoch 073
# Epoch 073 | Train Loss: 0.228485 | Test Loss: 0.227487 | Avg Vertex Error: 0.016444 units
# Train Epoch 074
# Epoch 074 | Train Loss: 0.228386 | Test Loss: 0.226923 | Avg Vertex Error: 0.016379 units
# Train Epoch 075
# Epoch 075 | Train Loss: 0.227791 | Test Loss: 0.226072 | Avg Vertex Error: 0.016279 units
# Train Epoch 076
# Epoch 076 | Train Loss: 0.227084 | Test Loss: 0.226399 | Avg Vertex Error: 0.016315 units
# Train Epoch 077
# Epoch 077 | Train Loss: 0.227338 | Test Loss: 0.225639 | Avg Vertex Error: 0.016253 units
# Train Epoch 078
# Epoch 078 | Train Loss: 0.226445 | Test Loss: 0.225710 | Avg Vertex Error: 0.016261 units
# Train Epoch 079
# Epoch 079 | Train Loss: 0.226757 | Test Loss: 0.224618 | Avg Vertex Error: 0.016129 units
# Train Epoch 080
# Epoch 080 | Train Loss: 0.225435 | Test Loss: 0.225153 | Avg Vertex Error: 0.016242 units
# Train Epoch 081
# Epoch 081 | Train Loss: 0.226662 | Test Loss: 0.223840 | Avg Vertex Error: 0.016051 units
# Train Epoch 082
# Epoch 082 | Train Loss: 0.224800 | Test Loss: 0.224355 | Avg Vertex Error: 0.016127 units
# Train Epoch 083
# Epoch 083 | Train Loss: 0.225518 | Test Loss: 0.223238 | Avg Vertex Error: 0.016015 units
# Train Epoch 084
# Epoch 084 | Train Loss: 0.224186 | Test Loss: 0.222736 | Avg Vertex Error: 0.015975 units
# Train Epoch 085
# Epoch 085 | Train Loss: 0.223849 | Test Loss: 0.222281 | Avg Vertex Error: 0.015917 units
# Train Epoch 086
# Epoch 086 | Train Loss: 0.223200 | Test Loss: 0.222112 | Avg Vertex Error: 0.015944 units
# Train Epoch 087
# Epoch 087 | Train Loss: 0.223163 | Test Loss: 0.221193 | Avg Vertex Error: 0.015815 units
# Train Epoch 088
# Epoch 088 | Train Loss: 0.222257 | Test Loss: 0.221429 | Avg Vertex Error: 0.015877 units
# Train Epoch 089
# Epoch 089 | Train Loss: 0.222305 | Test Loss: 0.220660 | Avg Vertex Error: 0.015777 units
# Train Epoch 090
# Epoch 090 | Train Loss: 0.221611 | Test Loss: 0.220600 | Avg Vertex Error: 0.015794 units
# Train Epoch 091
# Epoch 091 | Train Loss: 0.221609 | Test Loss: 0.219993 | Avg Vertex Error: 0.015715 units
# Train Epoch 092
# Epoch 092 | Train Loss: 0.220850 | Test Loss: 0.219726 | Avg Vertex Error: 0.015703 units
# Train Epoch 093
# Epoch 093 | Train Loss: 0.220698 | Test Loss: 0.219019 | Avg Vertex Error: 0.015639 units
# Train Epoch 094
# Epoch 094 | Train Loss: 0.219860 | Test Loss: 0.218899 | Avg Vertex Error: 0.015654 units
# Train Epoch 095
# Epoch 095 | Train Loss: 0.219986 | Test Loss: 0.218268 | Avg Vertex Error: 0.015579 units
# Train Epoch 096
# Epoch 096 | Train Loss: 0.219273 | Test Loss: 0.218273 | Avg Vertex Error: 0.015566 units
# Train Epoch 097
# Epoch 097 | Train Loss: 0.219266 | Test Loss: 0.217380 | Avg Vertex Error: 0.015508 units
# Train Epoch 098
# Epoch 098 | Train Loss: 0.218361 | Test Loss: 0.217333 | Avg Vertex Error: 0.015549 units
# Train Epoch 099
# Epoch 099 | Train Loss: 0.218337 | Test Loss: 0.216351 | Avg Vertex Error: 0.015426 units
# Train Epoch 100
# Epoch 100 | Train Loss: 0.217270 | Test Loss: 0.216650 | Avg Vertex Error: 0.015520 units
# Train Epoch 101
# Epoch 101 | Train Loss: 0.217640 | Test Loss: 0.215690 | Avg Vertex Error: 0.015385 units
# Train Epoch 102
# Epoch 102 | Train Loss: 0.216535 | Test Loss: 0.215913 | Avg Vertex Error: 0.015418 units
# Train Epoch 103
# Epoch 103 | Train Loss: 0.217040 | Test Loss: 0.215200 | Avg Vertex Error: 0.015347 units
# Train Epoch 104
# Epoch 104 | Train Loss: 0.216128 | Test Loss: 0.214837 | Avg Vertex Error: 0.015333 units
# Train Epoch 105
# Epoch 105 | Train Loss: 0.216123 | Test Loss: 0.214576 | Avg Vertex Error: 0.015292 units
# Train Epoch 106
# Epoch 106 | Train Loss: 0.215293 | Test Loss: 0.214614 | Avg Vertex Error: 0.015352 units
# Train Epoch 107
# Epoch 107 | Train Loss: 0.215781 | Test Loss: 0.213556 | Avg Vertex Error: 0.015233 units
# Train Epoch 108
# Epoch 108 | Train Loss: 0.214574 | Test Loss: 0.213546 | Avg Vertex Error: 0.015301 units
# Train Epoch 109
# Epoch 109 | Train Loss: 0.214630 | Test Loss: 0.212520 | Avg Vertex Error: 0.015132 units
# Train Epoch 110
# Epoch 110 | Train Loss: 0.213468 | Test Loss: 0.212747 | Avg Vertex Error: 0.015184 units
# Train Epoch 111
# Epoch 111 | Train Loss: 0.213764 | Test Loss: 0.212291 | Avg Vertex Error: 0.015133 units
# Train Epoch 112
# Epoch 112 | Train Loss: 0.213197 | Test Loss: 0.212160 | Avg Vertex Error: 0.015151 units
# Train Epoch 113
# Epoch 113 | Train Loss: 0.213437 | Test Loss: 0.211530 | Avg Vertex Error: 0.015077 units
# Train Epoch 114
# Epoch 114 | Train Loss: 0.212416 | Test Loss: 0.211378 | Avg Vertex Error: 0.015107 units
# Train Epoch 115
# Epoch 115 | Train Loss: 0.212415 | Test Loss: 0.210639 | Avg Vertex Error: 0.015005 units
# Train Epoch 116
# Epoch 116 | Train Loss: 0.211736 | Test Loss: 0.210539 | Avg Vertex Error: 0.015042 units
# Train Epoch 117
# Epoch 117 | Train Loss: 0.211776 | Test Loss: 0.210103 | Avg Vertex Error: 0.014978 units
# Train Epoch 118
# Epoch 118 | Train Loss: 0.210914 | Test Loss: 0.210131 | Avg Vertex Error: 0.015035 units
# Train Epoch 119
# Epoch 119 | Train Loss: 0.211478 | Test Loss: 0.209154 | Avg Vertex Error: 0.014917 units
# Train Epoch 120
# Epoch 120 | Train Loss: 0.210173 | Test Loss: 0.209216 | Avg Vertex Error: 0.014905 units
# Train Epoch 121
# Epoch 121 | Train Loss: 0.210594 | Test Loss: 0.208728 | Avg Vertex Error: 0.014890 units
# Train Epoch 122
# Epoch 122 | Train Loss: 0.209629 | Test Loss: 0.208516 | Avg Vertex Error: 0.014904 units
# Train Epoch 123
# Epoch 123 | Train Loss: 0.209654 | Test Loss: 0.207791 | Avg Vertex Error: 0.014827 units
# Train Epoch 124
# Epoch 124 | Train Loss: 0.208653 | Test Loss: 0.207609 | Avg Vertex Error: 0.014846 units
# Train Epoch 125
# Epoch 125 | Train Loss: 0.208732 | Test Loss: 0.207045 | Avg Vertex Error: 0.014783 units
# Train Epoch 126
# Epoch 126 | Train Loss: 0.207952 | Test Loss: 0.207179 | Avg Vertex Error: 0.014809 units
# Train Epoch 127
# Epoch 127 | Train Loss: 0.208241 | Test Loss: 0.206242 | Avg Vertex Error: 0.014720 units
# Train Epoch 128
# Epoch 128 | Train Loss: 0.207125 | Test Loss: 0.206507 | Avg Vertex Error: 0.014813 units
# Train Epoch 129
# Epoch 129 | Train Loss: 0.207847 | Test Loss: 0.205736 | Avg Vertex Error: 0.014674 units
# Train Epoch 130
# Epoch 130 | Train Loss: 0.206599 | Test Loss: 0.205680 | Avg Vertex Error: 0.014667 units
# Train Epoch 131
# Epoch 131 | Train Loss: 0.206949 | Test Loss: 0.205795 | Avg Vertex Error: 0.014751 units
# Train Epoch 132
# Epoch 132 | Train Loss: 0.206634 | Test Loss: 0.204448 | Avg Vertex Error: 0.014584 units
# Train Epoch 133
# Epoch 133 | Train Loss: 0.205793 | Test Loss: 0.204633 | Avg Vertex Error: 0.014642 units
# Train Epoch 134
# Epoch 134 | Train Loss: 0.205469 | Test Loss: 0.204476 | Avg Vertex Error: 0.014636 units
# Train Epoch 135
# Epoch 135 | Train Loss: 0.205603 | Test Loss: 0.203782 | Avg Vertex Error: 0.014578 units
# Train Epoch 136
# Epoch 136 | Train Loss: 0.204612 | Test Loss: 0.203281 | Avg Vertex Error: 0.014536 units
# Train Epoch 137
# Epoch 137 | Train Loss: 0.204570 | Test Loss: 0.203245 | Avg Vertex Error: 0.014533 units
# Train Epoch 138
# Epoch 138 | Train Loss: 0.204288 | Test Loss: 0.202528 | Avg Vertex Error: 0.014449 units
# Train Epoch 139
# Epoch 139 | Train Loss: 0.204122 | Test Loss: 0.202547 | Avg Vertex Error: 0.014474 units
# Train Epoch 140
# Epoch 140 | Train Loss: 0.203573 | Test Loss: 0.202729 | Avg Vertex Error: 0.014542 units
# Train Epoch 141
# Epoch 141 | Train Loss: 0.203894 | Test Loss: 0.201582 | Avg Vertex Error: 0.014428 units
# Train Epoch 142
# Epoch 142 | Train Loss: 0.202433 | Test Loss: 0.201886 | Avg Vertex Error: 0.014457 units
# Train Epoch 143
# Epoch 143 | Train Loss: 0.203075 | Test Loss: 0.201152 | Avg Vertex Error: 0.014398 units
# Train Epoch 144
# Epoch 144 | Train Loss: 0.201989 | Test Loss: 0.201082 | Avg Vertex Error: 0.014390 units
# Train Epoch 145
# Epoch 145 | Train Loss: 0.202375 | Test Loss: 0.200614 | Avg Vertex Error: 0.014376 units
# Train Epoch 146
# Epoch 146 | Train Loss: 0.201450 | Test Loss: 0.200173 | Avg Vertex Error: 0.014337 units
# Train Epoch 147
# Epoch 147 | Train Loss: 0.201258 | Test Loss: 0.199882 | Avg Vertex Error: 0.014305 units
# Train Epoch 148
# Epoch 148 | Train Loss: 0.200852 | Test Loss: 0.199836 | Avg Vertex Error: 0.014322 units
# Train Epoch 149
# Epoch 149 | Train Loss: 0.201047 | Test Loss: 0.199176 | Avg Vertex Error: 0.014246 units
# Train Epoch 150
# Epoch 150 | Train Loss: 0.200103 | Test Loss: 0.199157 | Avg Vertex Error: 0.014315 units
# Train Epoch 151
# Epoch 151 | Train Loss: 0.200291 | Test Loss: 0.198170 | Avg Vertex Error: 0.014202 units
# Train Epoch 152
# Epoch 152 | Train Loss: 0.199133 | Test Loss: 0.198094 | Avg Vertex Error: 0.014214 units
# Train Epoch 153
# Epoch 153 | Train Loss: 0.199537 | Test Loss: 0.197696 | Avg Vertex Error: 0.014154 units
# Train Epoch 154
# Epoch 154 | Train Loss: 0.198531 | Test Loss: 0.197935 | Avg Vertex Error: 0.014256 units
# Train Epoch 155
# Epoch 155 | Train Loss: 0.199496 | Test Loss: 0.196945 | Avg Vertex Error: 0.014121 units
# Train Epoch 156
# Epoch 156 | Train Loss: 0.197927 | Test Loss: 0.197510 | Avg Vertex Error: 0.014155 units
# Train Epoch 157
# Epoch 157 | Train Loss: 0.198884 | Test Loss: 0.196590 | Avg Vertex Error: 0.014090 units
# Train Epoch 158
# Epoch 158 | Train Loss: 0.197478 | Test Loss: 0.196987 | Avg Vertex Error: 0.014161 units
# Train Epoch 159
# Epoch 159 | Train Loss: 0.198218 | Test Loss: 0.195942 | Avg Vertex Error: 0.014083 units
# Train Epoch 160
# Epoch 160 | Train Loss: 0.196692 | Test Loss: 0.195517 | Avg Vertex Error: 0.014038 units
# Train Epoch 161
# Epoch 161 | Train Loss: 0.196872 | Test Loss: 0.195132 | Avg Vertex Error: 0.013993 units
# Train Epoch 162
# Epoch 162 | Train Loss: 0.195939 | Test Loss: 0.195098 | Avg Vertex Error: 0.014067 units
# Train Epoch 163
# Epoch 163 | Train Loss: 0.196557 | Test Loss: 0.194745 | Avg Vertex Error: 0.013988 units
# Train Epoch 164
# Epoch 164 | Train Loss: 0.195632 | Test Loss: 0.194766 | Avg Vertex Error: 0.013961 units
# Train Epoch 165
# Epoch 165 | Train Loss: 0.196019 | Test Loss: 0.194913 | Avg Vertex Error: 0.014037 units
# Train Epoch 166
# Epoch 166 | Train Loss: 0.195892 | Test Loss: 0.193800 | Avg Vertex Error: 0.013918 units
# Train Epoch 167
# Epoch 167 | Train Loss: 0.195068 | Test Loss: 0.194305 | Avg Vertex Error: 0.014019 units
# Train Epoch 168
# Epoch 168 | Train Loss: 0.195146 | Test Loss: 0.193002 | Avg Vertex Error: 0.013820 units
# Train Epoch 169
# Epoch 169 | Train Loss: 0.194182 | Test Loss: 0.193667 | Avg Vertex Error: 0.013985 units
# Train Epoch 170
# Epoch 170 | Train Loss: 0.195237 | Test Loss: 0.192840 | Avg Vertex Error: 0.013851 units
# Train Epoch 171
# Epoch 171 | Train Loss: 0.193992 | Test Loss: 0.192898 | Avg Vertex Error: 0.013865 units
# Train Epoch 172
# Epoch 172 | Train Loss: 0.193948 | Test Loss: 0.191883 | Avg Vertex Error: 0.013753 units
# Train Epoch 173
# Epoch 173 | Train Loss: 0.193281 | Test Loss: 0.192780 | Avg Vertex Error: 0.013895 units
# Train Epoch 174
# Epoch 174 | Train Loss: 0.193707 | Test Loss: 0.191022 | Avg Vertex Error: 0.013698 units
# Train Epoch 175
# Epoch 175 | Train Loss: 0.192244 | Test Loss: 0.191710 | Avg Vertex Error: 0.013828 units
# Train Epoch 176
# Epoch 176 | Train Loss: 0.192998 | Test Loss: 0.191140 | Avg Vertex Error: 0.013693 units
# Train Epoch 177
# Epoch 177 | Train Loss: 0.192300 | Test Loss: 0.191537 | Avg Vertex Error: 0.013777 units
# Train Epoch 178
# Epoch 178 | Train Loss: 0.192988 | Test Loss: 0.190381 | Avg Vertex Error: 0.013641 units
# Train Epoch 179
# Epoch 179 | Train Loss: 0.191663 | Test Loss: 0.190960 | Avg Vertex Error: 0.013751 units
# Train Epoch 180
# Epoch 180 | Train Loss: 0.192010 | Test Loss: 0.189759 | Avg Vertex Error: 0.013605 units
# Train Epoch 181
# Epoch 181 | Train Loss: 0.191104 | Test Loss: 0.191166 | Avg Vertex Error: 0.013832 units
# Train Epoch 182
# Epoch 182 | Train Loss: 0.192881 | Test Loss: 0.189733 | Avg Vertex Error: 0.013607 units
# Train Epoch 183
# Epoch 183 | Train Loss: 0.191028 | Test Loss: 0.189897 | Avg Vertex Error: 0.013631 units
# Train Epoch 184
# Epoch 184 | Train Loss: 0.191046 | Test Loss: 0.188860 | Avg Vertex Error: 0.013548 units
# Train Epoch 185
# Epoch 185 | Train Loss: 0.190385 | Test Loss: 0.189835 | Avg Vertex Error: 0.013718 units
# Train Epoch 186
# Epoch 186 | Train Loss: 0.191349 | Test Loss: 0.188565 | Avg Vertex Error: 0.013512 units
# Train Epoch 187
# Epoch 187 | Train Loss: 0.190402 | Test Loss: 0.189361 | Avg Vertex Error: 0.013605 units
# Train Epoch 188
# Epoch 188 | Train Loss: 0.190439 | Test Loss: 0.187941 | Avg Vertex Error: 0.013465 units
# Train Epoch 189
# Epoch 189 | Train Loss: 0.189283 | Test Loss: 0.189170 | Avg Vertex Error: 0.013668 units
# Train Epoch 190
# Epoch 190 | Train Loss: 0.190578 | Test Loss: 0.187993 | Avg Vertex Error: 0.013467 units
# Train Epoch 191
# Epoch 191 | Train Loss: 0.189412 | Test Loss: 0.188669 | Avg Vertex Error: 0.013555 units
# Train Epoch 192
# Epoch 192 | Train Loss: 0.189667 | Test Loss: 0.186771 | Avg Vertex Error: 0.013365 units
# Train Epoch 193
# Epoch 193 | Train Loss: 0.188297 | Test Loss: 0.187620 | Avg Vertex Error: 0.013505 units
# Train Epoch 194
# Epoch 194 | Train Loss: 0.188892 | Test Loss: 0.187058 | Avg Vertex Error: 0.013389 units
# Train Epoch 195
# Epoch 195 | Train Loss: 0.188473 | Test Loss: 0.188071 | Avg Vertex Error: 0.013560 units
# Train Epoch 196
# Epoch 196 | Train Loss: 0.189402 | Test Loss: 0.186075 | Avg Vertex Error: 0.013313 units
# Train Epoch 197
# Epoch 197 | Train Loss: 0.187634 | Test Loss: 0.187212 | Avg Vertex Error: 0.013477 units
# Train Epoch 198
# Epoch 198 | Train Loss: 0.188364 | Test Loss: 0.185761 | Avg Vertex Error: 0.013297 units
# Train Epoch 199
# Epoch 199 | Train Loss: 0.187435 | Test Loss: 0.187182 | Avg Vertex Error: 0.013512 units
# Train Epoch 200
# Epoch 200 | Train Loss: 0.188645 | Test Loss: 0.185635 | Avg Vertex Error: 0.013308 units
# Train Epoch 201
# Epoch 201 | Train Loss: 0.187085 | Test Loss: 0.186871 | Avg Vertex Error: 0.013509 units
# Train Epoch 202
# Epoch 202 | Train Loss: 0.188225 | Test Loss: 0.185167 | Avg Vertex Error: 0.013270 units
# Train Epoch 203
# Epoch 203 | Train Loss: 0.186564 | Test Loss: 0.185860 | Avg Vertex Error: 0.013344 units
# Train Epoch 204
# Epoch 204 | Train Loss: 0.186796 | Test Loss: 0.184936 | Avg Vertex Error: 0.013264 units
# Train Epoch 205
# Epoch 205 | Train Loss: 0.186092 | Test Loss: 0.185430 | Avg Vertex Error: 0.013329 units
# Train Epoch 206
# Epoch 206 | Train Loss: 0.186537 | Test Loss: 0.183996 | Avg Vertex Error: 0.013179 units
# Train Epoch 207
# Epoch 207 | Train Loss: 0.185458 | Test Loss: 0.185235 | Avg Vertex Error: 0.013376 units
# Train Epoch 208
# Epoch 208 | Train Loss: 0.186643 | Test Loss: 0.183980 | Avg Vertex Error: 0.013172 units
# Train Epoch 209
# Epoch 209 | Train Loss: 0.185519 | Test Loss: 0.185018 | Avg Vertex Error: 0.013315 units
# Train Epoch 210
# Epoch 210 | Train Loss: 0.186134 | Test Loss: 0.183343 | Avg Vertex Error: 0.013109 units
# Train Epoch 211
# Epoch 211 | Train Loss: 0.184941 | Test Loss: 0.184284 | Avg Vertex Error: 0.013250 units
# Train Epoch 212
# Epoch 212 | Train Loss: 0.185384 | Test Loss: 0.183072 | Avg Vertex Error: 0.013097 units
# Train Epoch 213
# Epoch 213 | Train Loss: 0.184658 | Test Loss: 0.184086 | Avg Vertex Error: 0.013218 units
# Train Epoch 214
# Epoch 214 | Train Loss: 0.185354 | Test Loss: 0.182484 | Avg Vertex Error: 0.013046 units
# Train Epoch 215
# Epoch 215 | Train Loss: 0.184278 | Test Loss: 0.183192 | Avg Vertex Error: 0.013122 units
# Train Epoch 216
# Epoch 216 | Train Loss: 0.184031 | Test Loss: 0.182280 | Avg Vertex Error: 0.013082 units
# Train Epoch 217
# Epoch 217 | Train Loss: 0.183791 | Test Loss: 0.182489 | Avg Vertex Error: 0.013070 units
# Train Epoch 218
# Epoch 218 | Train Loss: 0.183676 | Test Loss: 0.182177 | Avg Vertex Error: 0.013064 units
# Train Epoch 219
# Epoch 219 | Train Loss: 0.183997 | Test Loss: 0.182238 | Avg Vertex Error: 0.013074 units
# Train Epoch 220
# Epoch 220 | Train Loss: 0.183161 | Test Loss: 0.181324 | Avg Vertex Error: 0.012961 units
# Train Epoch 221
# Epoch 221 | Train Loss: 0.182763 | Test Loss: 0.181874 | Avg Vertex Error: 0.013026 units
# Train Epoch 222
# Epoch 222 | Train Loss: 0.182946 | Test Loss: 0.181060 | Avg Vertex Error: 0.012946 units
# Train Epoch 223
# Epoch 223 | Train Loss: 0.182395 | Test Loss: 0.181977 | Avg Vertex Error: 0.013080 units
# Train Epoch 224
# Epoch 224 | Train Loss: 0.183074 | Test Loss: 0.180361 | Avg Vertex Error: 0.012894 units
# Train Epoch 225
# Epoch 225 | Train Loss: 0.181710 | Test Loss: 0.181077 | Avg Vertex Error: 0.013001 units
# Train Epoch 226
# Epoch 226 | Train Loss: 0.182446 | Test Loss: 0.180077 | Avg Vertex Error: 0.012890 units
# Train Epoch 227
# Epoch 227 | Train Loss: 0.181471 | Test Loss: 0.180533 | Avg Vertex Error: 0.012936 units
# Train Epoch 228
# Epoch 228 | Train Loss: 0.181441 | Test Loss: 0.179818 | Avg Vertex Error: 0.012864 units
# Train Epoch 229
# Epoch 229 | Train Loss: 0.181420 | Test Loss: 0.180300 | Avg Vertex Error: 0.012927 units
# Train Epoch 230
# Epoch 230 | Train Loss: 0.181356 | Test Loss: 0.179127 | Avg Vertex Error: 0.012787 units
# Train Epoch 231
# Epoch 231 | Train Loss: 0.180616 | Test Loss: 0.180437 | Avg Vertex Error: 0.013006 units
# Train Epoch 232
# Epoch 232 | Train Loss: 0.182036 | Test Loss: 0.179349 | Avg Vertex Error: 0.012862 units
# Train Epoch 233
# Epoch 233 | Train Loss: 0.180967 | Test Loss: 0.180390 | Avg Vertex Error: 0.013009 units
# Train Epoch 234
# Epoch 234 | Train Loss: 0.181883 | Test Loss: 0.178525 | Avg Vertex Error: 0.012774 units
# Train Epoch 235
# Epoch 235 | Train Loss: 0.180110 | Test Loss: 0.179333 | Avg Vertex Error: 0.012864 units
# Train Epoch 236
# Epoch 236 | Train Loss: 0.180681 | Test Loss: 0.178151 | Avg Vertex Error: 0.012735 units
# Train Epoch 237
# Epoch 237 | Train Loss: 0.179654 | Test Loss: 0.179121 | Avg Vertex Error: 0.012889 units
# Train Epoch 238
# Epoch 238 | Train Loss: 0.180608 | Test Loss: 0.178110 | Avg Vertex Error: 0.012748 units
# Train Epoch 239
# Epoch 239 | Train Loss: 0.179746 | Test Loss: 0.179331 | Avg Vertex Error: 0.012894 units
# Train Epoch 240
# Epoch 240 | Train Loss: 0.180645 | Test Loss: 0.177398 | Avg Vertex Error: 0.012676 units
# Train Epoch 241
# Epoch 241 | Train Loss: 0.178658 | Test Loss: 0.178325 | Avg Vertex Error: 0.012811 units
# Train Epoch 242
# Epoch 242 | Train Loss: 0.179589 | Test Loss: 0.177059 | Avg Vertex Error: 0.012657 units
# Train Epoch 243
# Epoch 243 | Train Loss: 0.178693 | Test Loss: 0.177984 | Avg Vertex Error: 0.012754 units
# Train Epoch 244
# Epoch 244 | Train Loss: 0.179325 | Test Loss: 0.176911 | Avg Vertex Error: 0.012629 units
# Train Epoch 245
# Epoch 245 | Train Loss: 0.178228 | Test Loss: 0.177438 | Avg Vertex Error: 0.012728 units
# Train Epoch 246
# Epoch 246 | Train Loss: 0.178770 | Test Loss: 0.176974 | Avg Vertex Error: 0.012662 units
# Train Epoch 247
# Epoch 247 | Train Loss: 0.178345 | Test Loss: 0.177690 | Avg Vertex Error: 0.012727 units
# Train Epoch 248
# Epoch 248 | Train Loss: 0.179148 | Test Loss: 0.176300 | Avg Vertex Error: 0.012596 units
# Train Epoch 249
# Epoch 249 | Train Loss: 0.177446 | Test Loss: 0.176859 | Avg Vertex Error: 0.012719 units
# Train Epoch 250
# Epoch 250 | Train Loss: 0.178350 | Test Loss: 0.176194 | Avg Vertex Error: 0.012587 units
# Train Epoch 251
# Epoch 251 | Train Loss: 0.177380 | Test Loss: 0.176832 | Avg Vertex Error: 0.012684 units
# Train Epoch 252
# Epoch 252 | Train Loss: 0.178274 | Test Loss: 0.175652 | Avg Vertex Error: 0.012575 units
# Train Epoch 253
# Epoch 253 | Train Loss: 0.176946 | Test Loss: 0.175938 | Avg Vertex Error: 0.012611 units
# Train Epoch 254
# Epoch 254 | Train Loss: 0.177395 | Test Loss: 0.175712 | Avg Vertex Error: 0.012568 units
# Train Epoch 255
# Epoch 255 | Train Loss: 0.176663 | Test Loss: 0.175857 | Avg Vertex Error: 0.012617 units
# Train Epoch 256
# Epoch 256 | Train Loss: 0.177438 | Test Loss: 0.175181 | Avg Vertex Error: 0.012516 units
# Train Epoch 257
# Epoch 257 | Train Loss: 0.176498 | Test Loss: 0.175510 | Avg Vertex Error: 0.012589 units
# Train Epoch 258
# Epoch 258 | Train Loss: 0.177025 | Test Loss: 0.174811 | Avg Vertex Error: 0.012513 units
# Train Epoch 259
# Epoch 259 | Train Loss: 0.176106 | Test Loss: 0.175313 | Avg Vertex Error: 0.012580 units
# Train Epoch 260
# Epoch 260 | Train Loss: 0.176464 | Test Loss: 0.174433 | Avg Vertex Error: 0.012486 units
# Train Epoch 261
# Epoch 261 | Train Loss: 0.175568 | Test Loss: 0.174976 | Avg Vertex Error: 0.012550 units
# Train Epoch 262
# Epoch 262 | Train Loss: 0.176569 | Test Loss: 0.173981 | Avg Vertex Error: 0.012433 units
# Train Epoch 263
# Epoch 263 | Train Loss: 0.175548 | Test Loss: 0.174799 | Avg Vertex Error: 0.012539 units
# Train Epoch 264
# Epoch 264 | Train Loss: 0.176255 | Test Loss: 0.173687 | Avg Vertex Error: 0.012400 units
# Train Epoch 265
# Epoch 265 | Train Loss: 0.175425 | Test Loss: 0.174709 | Avg Vertex Error: 0.012537 units
# Train Epoch 266
# Epoch 266 | Train Loss: 0.175898 | Test Loss: 0.173453 | Avg Vertex Error: 0.012405 units
# Train Epoch 267
# Epoch 267 | Train Loss: 0.175137 | Test Loss: 0.174450 | Avg Vertex Error: 0.012470 units
# Train Epoch 268
# Epoch 268 | Train Loss: 0.175850 | Test Loss: 0.172997 | Avg Vertex Error: 0.012354 units
# Train Epoch 269
# Epoch 269 | Train Loss: 0.174595 | Test Loss: 0.173781 | Avg Vertex Error: 0.012465 units
# Train Epoch 270
# Epoch 270 | Train Loss: 0.175157 | Test Loss: 0.173069 | Avg Vertex Error: 0.012354 units
# Train Epoch 271
# Epoch 271 | Train Loss: 0.174941 | Test Loss: 0.173992 | Avg Vertex Error: 0.012493 units
# Train Epoch 272
# Epoch 272 | Train Loss: 0.175659 | Test Loss: 0.172453 | Avg Vertex Error: 0.012322 units
# Train Epoch 273
# Epoch 273 | Train Loss: 0.174003 | Test Loss: 0.173237 | Avg Vertex Error: 0.012429 units
# Train Epoch 274
# Epoch 274 | Train Loss: 0.174941 | Test Loss: 0.172904 | Avg Vertex Error: 0.012362 units
# Train Epoch 275
# Epoch 275 | Train Loss: 0.174400 | Test Loss: 0.173167 | Avg Vertex Error: 0.012413 units
# Train Epoch 276
# Epoch 276 | Train Loss: 0.174630 | Test Loss: 0.171964 | Avg Vertex Error: 0.012290 units
# Train Epoch 277
# Epoch 277 | Train Loss: 0.173129 | Test Loss: 0.172459 | Avg Vertex Error: 0.012348 units
# Train Epoch 278
# Epoch 278 | Train Loss: 0.173813 | Test Loss: 0.172098 | Avg Vertex Error: 0.012288 units
# Train Epoch 279
# Epoch 279 | Train Loss: 0.173659 | Test Loss: 0.172575 | Avg Vertex Error: 0.012341 units
# Train Epoch 280
# Epoch 280 | Train Loss: 0.173773 | Test Loss: 0.171334 | Avg Vertex Error: 0.012234 units
# Train Epoch 281
# Epoch 281 | Train Loss: 0.172737 | Test Loss: 0.172235 | Avg Vertex Error: 0.012354 units
# Train Epoch 282
# Epoch 282 | Train Loss: 0.173457 | Test Loss: 0.171149 | Avg Vertex Error: 0.012228 units
# Train Epoch 283
# Epoch 283 | Train Loss: 0.172930 | Test Loss: 0.172264 | Avg Vertex Error: 0.012340 units
# Train Epoch 284
# Epoch 284 | Train Loss: 0.173366 | Test Loss: 0.170752 | Avg Vertex Error: 0.012186 units
# Train Epoch 285
# Epoch 285 | Train Loss: 0.172437 | Test Loss: 0.171856 | Avg Vertex Error: 0.012344 units
# Train Epoch 286
# Epoch 286 | Train Loss: 0.173444 | Test Loss: 0.170613 | Avg Vertex Error: 0.012182 units
# Train Epoch 287
# Epoch 287 | Train Loss: 0.172071 | Test Loss: 0.171854 | Avg Vertex Error: 0.012355 units
# Train Epoch 288
# Epoch 288 | Train Loss: 0.172969 | Test Loss: 0.170002 | Avg Vertex Error: 0.012167 units
# Train Epoch 289
# Epoch 289 | Train Loss: 0.171611 | Test Loss: 0.170352 | Avg Vertex Error: 0.012187 units
# Train Epoch 290
# Epoch 290 | Train Loss: 0.171744 | Test Loss: 0.170516 | Avg Vertex Error: 0.012217 units
# Train Epoch 291
# Epoch 291 | Train Loss: 0.172224 | Test Loss: 0.170143 | Avg Vertex Error: 0.012130 units
# Train Epoch 292
# Epoch 292 | Train Loss: 0.171509 | Test Loss: 0.169941 | Avg Vertex Error: 0.012160 units
# Train Epoch 293
# Epoch 293 | Train Loss: 0.171562 | Test Loss: 0.170451 | Avg Vertex Error: 0.012182 units
# Train Epoch 294
# Epoch 294 | Train Loss: 0.171751 | Test Loss: 0.169584 | Avg Vertex Error: 0.012104 units
# Train Epoch 295
# Epoch 295 | Train Loss: 0.171232 | Test Loss: 0.170185 | Avg Vertex Error: 0.012140 units
# Train Epoch 296
# Epoch 296 | Train Loss: 0.171768 | Test Loss: 0.169416 | Avg Vertex Error: 0.012128 units
# Train Epoch 297
# Epoch 297 | Train Loss: 0.170626 | Test Loss: 0.169395 | Avg Vertex Error: 0.012096 units
# Train Epoch 298
# Epoch 298 | Train Loss: 0.170935 | Test Loss: 0.169301 | Avg Vertex Error: 0.012112 units
# Train Epoch 299
# Epoch 299 | Train Loss: 0.170793 | Test Loss: 0.169582 | Avg Vertex Error: 0.012124 units
# Train Epoch 300
# Epoch 300 | Train Loss: 0.170933 | Test Loss: 0.168864 | Avg Vertex Error: 0.012070 units
# Train Epoch 301
# Epoch 301 | Train Loss: 0.170536 | Test Loss: 0.169273 | Avg Vertex Error: 0.012093 units
# Train Epoch 302
# Epoch 302 | Train Loss: 0.170433 | Test Loss: 0.169073 | Avg Vertex Error: 0.012123 units
# Train Epoch 303
# Epoch 303 | Train Loss: 0.170720 | Test Loss: 0.169142 | Avg Vertex Error: 0.012059 units
# Train Epoch 304
# Epoch 304 | Train Loss: 0.170112 | Test Loss: 0.169063 | Avg Vertex Error: 0.012190 units
# Train Epoch 305
# Epoch 305 | Train Loss: 0.170922 | Test Loss: 0.168331 | Avg Vertex Error: 0.012045 units
# Train Epoch 306
# Epoch 306 | Train Loss: 0.169784 | Test Loss: 0.168380 | Avg Vertex Error: 0.012042 units
# Train Epoch 307
# Epoch 307 | Train Loss: 0.169608 | Test Loss: 0.168043 | Avg Vertex Error: 0.011993 units
# Train Epoch 308
# Epoch 308 | Train Loss: 0.169531 | Test Loss: 0.168800 | Avg Vertex Error: 0.012049 units
# Train Epoch 309
# Epoch 309 | Train Loss: 0.169680 | Test Loss: 0.167807 | Avg Vertex Error: 0.011968 units
# Train Epoch 310
# Epoch 310 | Train Loss: 0.169474 | Test Loss: 0.168246 | Avg Vertex Error: 0.012050 units
# Train Epoch 311
# Epoch 311 | Train Loss: 0.169247 | Test Loss: 0.167466 | Avg Vertex Error: 0.011931 units
# Train Epoch 312
# Epoch 312 | Train Loss: 0.169031 | Test Loss: 0.168079 | Avg Vertex Error: 0.011984 units
# Train Epoch 313
# Epoch 313 | Train Loss: 0.169095 | Test Loss: 0.167578 | Avg Vertex Error: 0.011967 units
# Train Epoch 314
# Epoch 314 | Train Loss: 0.168876 | Test Loss: 0.167306 | Avg Vertex Error: 0.011931 units
# Train Epoch 315
# Epoch 315 | Train Loss: 0.168338 | Test Loss: 0.167484 | Avg Vertex Error: 0.011982 units
# Train Epoch 316
# Epoch 316 | Train Loss: 0.168952 | Test Loss: 0.167198 | Avg Vertex Error: 0.011944 units
# Train Epoch 317
# Epoch 317 | Train Loss: 0.168476 | Test Loss: 0.167370 | Avg Vertex Error: 0.011978 units
# Train Epoch 318
# Epoch 318 | Train Loss: 0.168738 | Test Loss: 0.166824 | Avg Vertex Error: 0.011889 units
# Train Epoch 319
# Epoch 319 | Train Loss: 0.168056 | Test Loss: 0.167520 | Avg Vertex Error: 0.011998 units
# Train Epoch 320
# Epoch 320 | Train Loss: 0.169055 | Test Loss: 0.166221 | Avg Vertex Error: 0.011840 units
# Train Epoch 321
# Epoch 321 | Train Loss: 0.167301 | Test Loss: 0.166876 | Avg Vertex Error: 0.011971 units
# Train Epoch 322
# Epoch 322 | Train Loss: 0.168579 | Test Loss: 0.166468 | Avg Vertex Error: 0.011860 units
# Train Epoch 323
# Epoch 323 | Train Loss: 0.167394 | Test Loss: 0.166716 | Avg Vertex Error: 0.011907 units
# Train Epoch 324
# Epoch 324 | Train Loss: 0.168364 | Test Loss: 0.166180 | Avg Vertex Error: 0.011830 units
# Train Epoch 325
# Epoch 325 | Train Loss: 0.167489 | Test Loss: 0.166638 | Avg Vertex Error: 0.011925 units
# Train Epoch 326
# Epoch 326 | Train Loss: 0.168018 | Test Loss: 0.165599 | Avg Vertex Error: 0.011803 units
# Train Epoch 327
# Epoch 327 | Train Loss: 0.167156 | Test Loss: 0.166344 | Avg Vertex Error: 0.011912 units
# Train Epoch 328
# Epoch 328 | Train Loss: 0.167838 | Test Loss: 0.165656 | Avg Vertex Error: 0.011801 units
# Train Epoch 329
# Epoch 329 | Train Loss: 0.166904 | Test Loss: 0.165955 | Avg Vertex Error: 0.011833 units
# Train Epoch 330
# Epoch 330 | Train Loss: 0.167380 | Test Loss: 0.165275 | Avg Vertex Error: 0.011781 units
# Train Epoch 331
# Epoch 331 | Train Loss: 0.166413 | Test Loss: 0.165495 | Avg Vertex Error: 0.011822 units
# Train Epoch 332
# Epoch 332 | Train Loss: 0.166927 | Test Loss: 0.165136 | Avg Vertex Error: 0.011767 units
# Train Epoch 333
# Epoch 333 | Train Loss: 0.166489 | Test Loss: 0.166051 | Avg Vertex Error: 0.011849 units
# Train Epoch 334
# Epoch 334 | Train Loss: 0.167040 | Test Loss: 0.164749 | Avg Vertex Error: 0.011721 units
# Train Epoch 335
# Epoch 335 | Train Loss: 0.166151 | Test Loss: 0.165529 | Avg Vertex Error: 0.011834 units
# Train Epoch 336
# Epoch 336 | Train Loss: 0.166831 | Test Loss: 0.164772 | Avg Vertex Error: 0.011724 units
# Train Epoch 337
# Epoch 337 | Train Loss: 0.165815 | Test Loss: 0.164953 | Avg Vertex Error: 0.011822 units
# Train Epoch 338
# Epoch 338 | Train Loss: 0.166385 | Test Loss: 0.164391 | Avg Vertex Error: 0.011718 units
# Train Epoch 339
# Epoch 339 | Train Loss: 0.165675 | Test Loss: 0.164944 | Avg Vertex Error: 0.011805 units
# Train Epoch 340
# Epoch 340 | Train Loss: 0.166933 | Test Loss: 0.163995 | Avg Vertex Error: 0.011683 units
# Train Epoch 341
# Epoch 341 | Train Loss: 0.165353 | Test Loss: 0.164903 | Avg Vertex Error: 0.011836 units
# Train Epoch 342
# Epoch 342 | Train Loss: 0.166003 | Test Loss: 0.164051 | Avg Vertex Error: 0.011686 units
# Train Epoch 343
# Epoch 343 | Train Loss: 0.165316 | Test Loss: 0.164067 | Avg Vertex Error: 0.011695 units
# Train Epoch 344
# Epoch 344 | Train Loss: 0.165785 | Test Loss: 0.163956 | Avg Vertex Error: 0.011710 units
# Train Epoch 345
# Epoch 345 | Train Loss: 0.165080 | Test Loss: 0.163564 | Avg Vertex Error: 0.011639 units
# Train Epoch 346
# Epoch 346 | Train Loss: 0.165598 | Test Loss: 0.163738 | Avg Vertex Error: 0.011660 units
# Train Epoch 347
# Epoch 347 | Train Loss: 0.164916 | Test Loss: 0.164204 | Avg Vertex Error: 0.011752 units
# Train Epoch 348
# Epoch 348 | Train Loss: 0.165707 | Test Loss: 0.163505 | Avg Vertex Error: 0.011651 units
# Train Epoch 349
# Epoch 349 | Train Loss: 0.164590 | Test Loss: 0.164451 | Avg Vertex Error: 0.011822 units
# Train Epoch 350
# Epoch 350 | Train Loss: 0.166015 | Test Loss: 0.163207 | Avg Vertex Error: 0.011664 units
# Train Epoch 351
# Epoch 351 | Train Loss: 0.164508 | Test Loss: 0.163518 | Avg Vertex Error: 0.011661 units
# Train Epoch 352
# Epoch 352 | Train Loss: 0.165004 | Test Loss: 0.162993 | Avg Vertex Error: 0.011632 units
# Train Epoch 353
# Epoch 353 | Train Loss: 0.164009 | Test Loss: 0.163322 | Avg Vertex Error: 0.011642 units
# Train Epoch 354
# Epoch 354 | Train Loss: 0.164302 | Test Loss: 0.162796 | Avg Vertex Error: 0.011594 units
# Train Epoch 355
# Epoch 355 | Train Loss: 0.164248 | Test Loss: 0.163593 | Avg Vertex Error: 0.011665 units
# Train Epoch 356
# Epoch 356 | Train Loss: 0.164477 | Test Loss: 0.162872 | Avg Vertex Error: 0.011607 units
# Train Epoch 357
# Epoch 357 | Train Loss: 0.164188 | Test Loss: 0.163011 | Avg Vertex Error: 0.011637 units
# Train Epoch 358
# Epoch 358 | Train Loss: 0.164568 | Test Loss: 0.162161 | Avg Vertex Error: 0.011524 units
# Train Epoch 359
# Epoch 359 | Train Loss: 0.163421 | Test Loss: 0.163173 | Avg Vertex Error: 0.011738 units
# Train Epoch 360
# Epoch 360 | Train Loss: 0.164921 | Test Loss: 0.162448 | Avg Vertex Error: 0.011607 units
# Train Epoch 361
# Epoch 361 | Train Loss: 0.163664 | Test Loss: 0.163683 | Avg Vertex Error: 0.011780 units
# Train Epoch 362
# Epoch 362 | Train Loss: 0.164996 | Test Loss: 0.161985 | Avg Vertex Error: 0.011590 units
# Train Epoch 363
# Epoch 363 | Train Loss: 0.163035 | Test Loss: 0.161937 | Avg Vertex Error: 0.011538 units
# Train Epoch 364
# Epoch 364 | Train Loss: 0.163190 | Test Loss: 0.161895 | Avg Vertex Error: 0.011514 units
# Train Epoch 365
# Epoch 365 | Train Loss: 0.163283 | Test Loss: 0.162309 | Avg Vertex Error: 0.011578 units
# Train Epoch 366
# Epoch 366 | Train Loss: 0.163262 | Test Loss: 0.161534 | Avg Vertex Error: 0.011474 units
# Train Epoch 367
# Epoch 367 | Train Loss: 0.163054 | Test Loss: 0.162499 | Avg Vertex Error: 0.011636 units
# Train Epoch 368
# Epoch 368 | Train Loss: 0.163972 | Test Loss: 0.161374 | Avg Vertex Error: 0.011488 units
# Train Epoch 369
# Epoch 369 | Train Loss: 0.163003 | Test Loss: 0.161669 | Avg Vertex Error: 0.011516 units
# Train Epoch 370
# Epoch 370 | Train Loss: 0.163292 | Test Loss: 0.161232 | Avg Vertex Error: 0.011475 units
# Train Epoch 371
# Epoch 371 | Train Loss: 0.162487 | Test Loss: 0.162238 | Avg Vertex Error: 0.011571 units
# Train Epoch 372
# Epoch 372 | Train Loss: 0.163465 | Test Loss: 0.161198 | Avg Vertex Error: 0.011455 units
# Train Epoch 373
# Epoch 373 | Train Loss: 0.162660 | Test Loss: 0.161961 | Avg Vertex Error: 0.011577 units
# Train Epoch 374
# Epoch 374 | Train Loss: 0.163199 | Test Loss: 0.161097 | Avg Vertex Error: 0.011460 units
# Train Epoch 375
# Epoch 375 | Train Loss: 0.162494 | Test Loss: 0.161631 | Avg Vertex Error: 0.011566 units
# Train Epoch 376
# Epoch 376 | Train Loss: 0.162933 | Test Loss: 0.160299 | Avg Vertex Error: 0.011413 units
# Train Epoch 377
# Epoch 377 | Train Loss: 0.161548 | Test Loss: 0.161354 | Avg Vertex Error: 0.011542 units
# Train Epoch 378
# Epoch 378 | Train Loss: 0.162540 | Test Loss: 0.160562 | Avg Vertex Error: 0.011435 units
# Train Epoch 379
# Epoch 379 | Train Loss: 0.161800 | Test Loss: 0.161486 | Avg Vertex Error: 0.011592 units
# Train Epoch 380
# Epoch 380 | Train Loss: 0.163339 | Test Loss: 0.160267 | Avg Vertex Error: 0.011440 units
# Train Epoch 381
# Epoch 381 | Train Loss: 0.161007 | Test Loss: 0.160716 | Avg Vertex Error: 0.011471 units
# Train Epoch 382
# Epoch 382 | Train Loss: 0.162164 | Test Loss: 0.159797 | Avg Vertex Error: 0.011371 units
# Train Epoch 383
# Epoch 383 | Train Loss: 0.160951 | Test Loss: 0.160264 | Avg Vertex Error: 0.011453 units
# Train Epoch 384
# Epoch 384 | Train Loss: 0.161403 | Test Loss: 0.159741 | Avg Vertex Error: 0.011348 units
# Train Epoch 385
# Epoch 385 | Train Loss: 0.160932 | Test Loss: 0.160673 | Avg Vertex Error: 0.011492 units
# Train Epoch 386
# Epoch 386 | Train Loss: 0.162535 | Test Loss: 0.160819 | Avg Vertex Error: 0.011496 units
# Train Epoch 387
# Epoch 387 | Train Loss: 0.161436 | Test Loss: 0.160696 | Avg Vertex Error: 0.011564 units
# Train Epoch 388
# Epoch 388 | Train Loss: 0.162346 | Test Loss: 0.159899 | Avg Vertex Error: 0.011415 units
# Train Epoch 389
# Epoch 389 | Train Loss: 0.160837 | Test Loss: 0.160999 | Avg Vertex Error: 0.011594 units
# Train Epoch 390
# Epoch 390 | Train Loss: 0.162394 | Test Loss: 0.159279 | Avg Vertex Error: 0.011378 units
# Train Epoch 391
# Epoch 391 | Train Loss: 0.160638 | Test Loss: 0.159549 | Avg Vertex Error: 0.011411 units
# Train Epoch 392
# Epoch 392 | Train Loss: 0.161227 | Test Loss: 0.159418 | Avg Vertex Error: 0.011344 units
# Train Epoch 393
# Epoch 393 | Train Loss: 0.160187 | Test Loss: 0.159390 | Avg Vertex Error: 0.011376 units
# Train Epoch 394
# Epoch 394 | Train Loss: 0.161032 | Test Loss: 0.158918 | Avg Vertex Error: 0.011305 units
# Train Epoch 395
# Epoch 395 | Train Loss: 0.160002 | Test Loss: 0.159488 | Avg Vertex Error: 0.011390 units
# Train Epoch 396
# Epoch 396 | Train Loss: 0.160971 | Test Loss: 0.158470 | Avg Vertex Error: 0.011254 units
# Train Epoch 397
# Epoch 397 | Train Loss: 0.159919 | Test Loss: 0.159213 | Avg Vertex Error: 0.011334 units
# Train Epoch 398
# Epoch 398 | Train Loss: 0.160364 | Test Loss: 0.158768 | Avg Vertex Error: 0.011287 units
# Train Epoch 399
# Epoch 399 | Train Loss: 0.160059 | Test Loss: 0.159043 | Avg Vertex Error: 0.011354 units
# Train Epoch 400
# Epoch 400 | Train Loss: 0.160282 | Test Loss: 0.158367 | Avg Vertex Error: 0.011268 units
# Train Epoch 401
# Epoch 401 | Train Loss: 0.159775 | Test Loss: 0.158673 | Avg Vertex Error: 0.011303 units
# Train Epoch 402
# Epoch 402 | Train Loss: 0.160104 | Test Loss: 0.158130 | Avg Vertex Error: 0.011242 units
# Train Epoch 403
# Epoch 403 | Train Loss: 0.159479 | Test Loss: 0.158822 | Avg Vertex Error: 0.011326 units
# Train Epoch 404
# Epoch 404 | Train Loss: 0.159895 | Test Loss: 0.157893 | Avg Vertex Error: 0.011214 units
# Train Epoch 405
# Epoch 405 | Train Loss: 0.159570 | Test Loss: 0.158621 | Avg Vertex Error: 0.011307 units
# Train Epoch 406
# Epoch 406 | Train Loss: 0.159642 | Test Loss: 0.157754 | Avg Vertex Error: 0.011215 units
# Train Epoch 407
# Epoch 407 | Train Loss: 0.159005 | Test Loss: 0.158620 | Avg Vertex Error: 0.011335 units
# Train Epoch 408
# Epoch 408 | Train Loss: 0.160016 | Test Loss: 0.157569 | Avg Vertex Error: 0.011202 units
# Train Epoch 409
# Epoch 409 | Train Loss: 0.158701 | Test Loss: 0.158323 | Avg Vertex Error: 0.011331 units
# Train Epoch 410
# Epoch 410 | Train Loss: 0.159904 | Test Loss: 0.158037 | Avg Vertex Error: 0.011258 units
# Train Epoch 411
# Epoch 411 | Train Loss: 0.158763 | Test Loss: 0.158539 | Avg Vertex Error: 0.011347 units
# Train Epoch 412
# Epoch 412 | Train Loss: 0.160353 | Test Loss: 0.157762 | Avg Vertex Error: 0.011231 units
# Train Epoch 413
# Epoch 413 | Train Loss: 0.158675 | Test Loss: 0.158083 | Avg Vertex Error: 0.011354 units
# Train Epoch 414
# Epoch 414 | Train Loss: 0.159765 | Test Loss: 0.157107 | Avg Vertex Error: 0.011174 units
# Train Epoch 415
# Epoch 415 | Train Loss: 0.158346 | Test Loss: 0.158025 | Avg Vertex Error: 0.011379 units
# Train Epoch 416
# Epoch 416 | Train Loss: 0.159585 | Test Loss: 0.157085 | Avg Vertex Error: 0.011236 units
# Train Epoch 417
# Epoch 417 | Train Loss: 0.158222 | Test Loss: 0.156841 | Avg Vertex Error: 0.011159 units
# Train Epoch 418
# Epoch 418 | Train Loss: 0.158571 | Test Loss: 0.156611 | Avg Vertex Error: 0.011147 units
# Train Epoch 419
# Epoch 419 | Train Loss: 0.157673 | Test Loss: 0.156999 | Avg Vertex Error: 0.011202 units
# Train Epoch 420
# Epoch 420 | Train Loss: 0.158030 | Test Loss: 0.156678 | Avg Vertex Error: 0.011112 units
# Train Epoch 421
# Epoch 421 | Train Loss: 0.157991 | Test Loss: 0.157317 | Avg Vertex Error: 0.011224 units
# Train Epoch 422
# Epoch 422 | Train Loss: 0.158988 | Test Loss: 0.156851 | Avg Vertex Error: 0.011141 units
# Train Epoch 423
# Epoch 423 | Train Loss: 0.157934 | Test Loss: 0.156394 | Avg Vertex Error: 0.011097 units
# Train Epoch 424
# Epoch 424 | Train Loss: 0.158018 | Test Loss: 0.156393 | Avg Vertex Error: 0.011127 units
# Train Epoch 425
# Epoch 425 | Train Loss: 0.157486 | Test Loss: 0.156689 | Avg Vertex Error: 0.011130 units
# Train Epoch 426
# Epoch 426 | Train Loss: 0.158011 | Test Loss: 0.155822 | Avg Vertex Error: 0.011051 units
# Train Epoch 427
# Epoch 427 | Train Loss: 0.157165 | Test Loss: 0.156318 | Avg Vertex Error: 0.011150 units
# Train Epoch 428
# Epoch 428 | Train Loss: 0.157779 | Test Loss: 0.155857 | Avg Vertex Error: 0.011064 units
# Train Epoch 429
# Epoch 429 | Train Loss: 0.157068 | Test Loss: 0.157022 | Avg Vertex Error: 0.011281 units
# Train Epoch 430
# Epoch 430 | Train Loss: 0.158535 | Test Loss: 0.155600 | Avg Vertex Error: 0.011090 units
# Train Epoch 431
# Epoch 431 | Train Loss: 0.156957 | Test Loss: 0.155779 | Avg Vertex Error: 0.011085 units
# Train Epoch 432
# Epoch 432 | Train Loss: 0.157379 | Test Loss: 0.155254 | Avg Vertex Error: 0.011021 units
# Train Epoch 433
# Epoch 433 | Train Loss: 0.156239 | Test Loss: 0.155883 | Avg Vertex Error: 0.011161 units
# Train Epoch 434
# Epoch 434 | Train Loss: 0.156987 | Test Loss: 0.155614 | Avg Vertex Error: 0.011062 units
# Train Epoch 435
# Epoch 435 | Train Loss: 0.156561 | Test Loss: 0.155578 | Avg Vertex Error: 0.011088 units
# Train Epoch 436
# Epoch 436 | Train Loss: 0.157360 | Test Loss: 0.155146 | Avg Vertex Error: 0.011015 units
# Train Epoch 437
# Epoch 437 | Train Loss: 0.156378 | Test Loss: 0.155842 | Avg Vertex Error: 0.011155 units
# Train Epoch 438
# Epoch 438 | Train Loss: 0.157588 | Test Loss: 0.155246 | Avg Vertex Error: 0.011089 units
# Train Epoch 439
# Epoch 439 | Train Loss: 0.156213 | Test Loss: 0.155806 | Avg Vertex Error: 0.011172 units
# Train Epoch 440
# Epoch 440 | Train Loss: 0.157166 | Test Loss: 0.154642 | Avg Vertex Error: 0.010991 units
# Train Epoch 441
# Epoch 441 | Train Loss: 0.156058 | Test Loss: 0.155144 | Avg Vertex Error: 0.011038 units
# Train Epoch 442
# Epoch 442 | Train Loss: 0.156341 | Test Loss: 0.155409 | Avg Vertex Error: 0.011047 units
# Train Epoch 443
# Epoch 443 | Train Loss: 0.156132 | Test Loss: 0.155024 | Avg Vertex Error: 0.011041 units
# Train Epoch 444
# Epoch 444 | Train Loss: 0.156768 | Test Loss: 0.154506 | Avg Vertex Error: 0.010996 units
# Train Epoch 445
# Epoch 445 | Train Loss: 0.155565 | Test Loss: 0.154373 | Avg Vertex Error: 0.010954 units
# Train Epoch 446
# Epoch 446 | Train Loss: 0.155863 | Test Loss: 0.155112 | Avg Vertex Error: 0.011007 units
# Train Epoch 447
# Epoch 447 | Train Loss: 0.155882 | Test Loss: 0.154335 | Avg Vertex Error: 0.010980 units
# Train Epoch 448
# Epoch 448 | Train Loss: 0.156283 | Test Loss: 0.154134 | Avg Vertex Error: 0.010928 units
# Train Epoch 449
# Epoch 449 | Train Loss: 0.155605 | Test Loss: 0.154785 | Avg Vertex Error: 0.011022 units
# Train Epoch 450
# Epoch 450 | Train Loss: 0.156365 | Test Loss: 0.153796 | Avg Vertex Error: 0.010920 units
# Train Epoch 451
# Epoch 451 | Train Loss: 0.155399 | Test Loss: 0.154775 | Avg Vertex Error: 0.011072 units
# Train Epoch 452
# Epoch 452 | Train Loss: 0.156195 | Test Loss: 0.153959 | Avg Vertex Error: 0.010927 units
# Train Epoch 453
# Epoch 453 | Train Loss: 0.155074 | Test Loss: 0.154515 | Avg Vertex Error: 0.010997 units
# Train Epoch 454
# Epoch 454 | Train Loss: 0.155827 | Test Loss: 0.153561 | Avg Vertex Error: 0.010918 units
# Train Epoch 455
# Epoch 455 | Train Loss: 0.155126 | Test Loss: 0.154551 | Avg Vertex Error: 0.011012 units
# Train Epoch 456
# Epoch 456 | Train Loss: 0.155400 | Test Loss: 0.153287 | Avg Vertex Error: 0.010858 units
# Train Epoch 457
# Epoch 457 | Train Loss: 0.154972 | Test Loss: 0.153679 | Avg Vertex Error: 0.010894 units
# Train Epoch 458
# Epoch 458 | Train Loss: 0.154907 | Test Loss: 0.154018 | Avg Vertex Error: 0.010938 units
# Train Epoch 459
# Epoch 459 | Train Loss: 0.155571 | Test Loss: 0.154079 | Avg Vertex Error: 0.010967 units
# Train Epoch 460
# Epoch 460 | Train Loss: 0.155218 | Test Loss: 0.153286 | Avg Vertex Error: 0.010866 units
# Train Epoch 461
# Epoch 461 | Train Loss: 0.154262 | Test Loss: 0.153337 | Avg Vertex Error: 0.010942 units
# Train Epoch 462
# Epoch 462 | Train Loss: 0.154673 | Test Loss: 0.153269 | Avg Vertex Error: 0.010882 units
# Train Epoch 463
# Epoch 463 | Train Loss: 0.154660 | Test Loss: 0.153883 | Avg Vertex Error: 0.010970 units
# Train Epoch 464
# Epoch 464 | Train Loss: 0.155184 | Test Loss: 0.152748 | Avg Vertex Error: 0.010833 units
# Train Epoch 465
# Epoch 465 | Train Loss: 0.154229 | Test Loss: 0.153191 | Avg Vertex Error: 0.010932 units
# Train Epoch 466
# Epoch 466 | Train Loss: 0.154347 | Test Loss: 0.152494 | Avg Vertex Error: 0.010803 units
# Train Epoch 467
# Epoch 467 | Train Loss: 0.153614 | Test Loss: 0.153122 | Avg Vertex Error: 0.010967 units
# Train Epoch 468
# Epoch 468 | Train Loss: 0.154216 | Test Loss: 0.152476 | Avg Vertex Error: 0.010834 units
# Train Epoch 469
# Epoch 469 | Train Loss: 0.153905 | Test Loss: 0.152920 | Avg Vertex Error: 0.010907 units
# Train Epoch 470
# Epoch 470 | Train Loss: 0.154158 | Test Loss: 0.152065 | Avg Vertex Error: 0.010773 units
# Train Epoch 471
# Epoch 471 | Train Loss: 0.153951 | Test Loss: 0.153622 | Avg Vertex Error: 0.010988 units
# Train Epoch 472
# Epoch 472 | Train Loss: 0.154779 | Test Loss: 0.152439 | Avg Vertex Error: 0.010836 units
# Train Epoch 473
# Epoch 473 | Train Loss: 0.153416 | Test Loss: 0.152131 | Avg Vertex Error: 0.010803 units
# Train Epoch 474
# Epoch 474 | Train Loss: 0.153880 | Test Loss: 0.152215 | Avg Vertex Error: 0.010800 units
# Train Epoch 475
# Epoch 475 | Train Loss: 0.153464 | Test Loss: 0.152391 | Avg Vertex Error: 0.010874 units
# Train Epoch 476
# Epoch 476 | Train Loss: 0.153718 | Test Loss: 0.151634 | Avg Vertex Error: 0.010755 units
# Train Epoch 477
# Epoch 477 | Train Loss: 0.153060 | Test Loss: 0.152485 | Avg Vertex Error: 0.010867 units
# Train Epoch 478
# Epoch 478 | Train Loss: 0.153499 | Test Loss: 0.151717 | Avg Vertex Error: 0.010738 units
# Train Epoch 479
# Epoch 479 | Train Loss: 0.152897 | Test Loss: 0.152372 | Avg Vertex Error: 0.010826 units
# Train Epoch 480
# Epoch 480 | Train Loss: 0.153647 | Test Loss: 0.151281 | Avg Vertex Error: 0.010710 units
# Train Epoch 481
# Epoch 481 | Train Loss: 0.152709 | Test Loss: 0.152448 | Avg Vertex Error: 0.010900 units
# Train Epoch 482
# Epoch 482 | Train Loss: 0.153434 | Test Loss: 0.151326 | Avg Vertex Error: 0.010741 units
# Train Epoch 483
# Epoch 483 | Train Loss: 0.152560 | Test Loss: 0.151834 | Avg Vertex Error: 0.010807 units
# Train Epoch 484
# Epoch 484 | Train Loss: 0.153207 | Test Loss: 0.150570 | Avg Vertex Error: 0.010658 units
# Train Epoch 485
# Epoch 485 | Train Loss: 0.151791 | Test Loss: 0.151061 | Avg Vertex Error: 0.010768 units
# Train Epoch 486
# Epoch 486 | Train Loss: 0.152741 | Test Loss: 0.150890 | Avg Vertex Error: 0.010685 units
# Train Epoch 487
# Epoch 487 | Train Loss: 0.152231 | Test Loss: 0.152025 | Avg Vertex Error: 0.010876 units
# Train Epoch 488
# Epoch 488 | Train Loss: 0.153675 | Test Loss: 0.150658 | Avg Vertex Error: 0.010680 units
# Train Epoch 489
# Epoch 489 | Train Loss: 0.152186 | Test Loss: 0.151135 | Avg Vertex Error: 0.010714 units
# Train Epoch 490
# Epoch 490 | Train Loss: 0.152694 | Test Loss: 0.151071 | Avg Vertex Error: 0.010720 units
# Train Epoch 491
# Epoch 491 | Train Loss: 0.152210 | Test Loss: 0.151114 | Avg Vertex Error: 0.010737 units
# Train Epoch 492
# Epoch 492 | Train Loss: 0.152288 | Test Loss: 0.150536 | Avg Vertex Error: 0.010658 units
# Train Epoch 493
# Epoch 493 | Train Loss: 0.151817 | Test Loss: 0.150777 | Avg Vertex Error: 0.010677 units
# Train Epoch 494
# Epoch 494 | Train Loss: 0.152239 | Test Loss: 0.150071 | Avg Vertex Error: 0.010663 units
# Train Epoch 495
# Epoch 495 | Train Loss: 0.151229 | Test Loss: 0.150925 | Avg Vertex Error: 0.010763 units
# Train Epoch 496
# Epoch 496 | Train Loss: 0.152158 | Test Loss: 0.150009 | Avg Vertex Error: 0.010634 units
# Train Epoch 497
# Epoch 497 | Train Loss: 0.151470 | Test Loss: 0.150608 | Avg Vertex Error: 0.010751 units
# Train Epoch 498
# Epoch 498 | Train Loss: 0.152205 | Test Loss: 0.149962 | Avg Vertex Error: 0.010621 units
# Train Epoch 499
# Epoch 499 | Train Loss: 0.150956 | Test Loss: 0.150018 | Avg Vertex Error: 0.010661 units
# Train Epoch 500
# Epoch 500 | Train Loss: 0.152276 | Test Loss: 0.149813 | Avg Vertex Error: 0.010608 units

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# 1. Combine the collected batches into single large arrays
preds_np = np.concatenate(all_pred_deltas, axis=0)     # Shape: (Total_Frames, Vertices, 3)
targets_np = np.concatenate(all_target_deltas, axis=0) # Shape: (Total_Frames, Vertices, 3)

# 2. Reshape to 2D: (Total_Frames, Vertices * 3)
preds_2d = preds_np.reshape(preds_np.shape[0], -1)
targets_2d = targets_np.reshape(targets_np.shape[0], -1)

# 3. Initialize PCA
pca = PCA(n_components=2) # 2 components for a 2D scatter plot

# CRITICAL: Fit the PCA on the TARGETS (Ground Truth) to define the coordinate space.
# If you fit two separate PCAs, the axes will mean different things and you cannot compare them!
pca.fit(targets_2d)

# Transform both datasets into this shared PCA space
pca_targets = pca.transform(targets_2d)
pca_preds = pca.transform(preds_2d)

# 4. Plot the comparison
plt.figure(figsize=(10, 8))

# Plot ground truth in blue
plt.scatter(pca_targets[:, 0], pca_targets[:, 1], alpha=0.5, label='Ground Truth (Targets)', color='blue', s=10)

# Plot predictions in red
plt.scatter(pca_preds[:, 0], pca_preds[:, 1], alpha=0.5, label='Model Predictions', color='red', s=10)

plt.title('PCA of Cloth Dynamics: Ground Truth vs Predictions')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Flatten the arrays so we just have a massive list of X, Y, and Z coordinates
true_flat = targets_pos_np.reshape(-1)
pred_flat = preds_pos_np.reshape(-1)

plt.figure(figsize=(12, 12))
plt.scatter(true_flat, pred_flat, alpha=0.1, color='purple', s=2)

# Draw the perfect prediction line (y = x)
min_val = min(true_flat.min(), pred_flat.min())
max_val = max(true_flat.max(), pred_flat.max())
plt.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='--', linewidth=2, label='Perfect Prediction')

plt.title('Predicted vs. Real Positions (All Coordinates)')
plt.xlabel('Real Position Coordinate')
plt.ylabel('Predicted Position Coordinate')
plt.legend()
plt.grid(True)
plt.axis('equal') # Keeps the aspect ratio square
plt.show()

# %%
# Choose a random frame from your test set to visualize
frame_idx = 33 # Change this to look at different moments
num_vertices = targets_pos_np.shape[1]

real_frame = targets_pos_np[frame_idx] # Shape: (Vertices, 3)
pred_frame = preds_pos_np[frame_idx]   # Shape: (Vertices, 3)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Extract X, Y, Z for Real positions
rx, ry, rz = real_frame[:, 0], real_frame[:, 1], real_frame[:, 2]
# Extract X, Y, Z for Predicted positions
px, py, pz = pred_frame[:, 0], pred_frame[:, 1], pred_frame[:, 2]

# Plot the real cloth vertices in Blue
ax.scatter(rx, ry, rz, c='blue', label='Real Shape', s=50, marker='o')

# Plot the predicted cloth vertices in Red
ax.scatter(px, py, pz, c='red', label='Predicted Shape', s=50, marker='x')

# Draw lines connecting the predicted vertex to the real vertex to show the error
for i in range(num_vertices):
    ax.plot([rx[i], px[i]], [ry[i], py[i]], [rz[i], pz[i]], color='gray', linestyle='dotted')

ax.set_title(f'Cloth Shape Comparison (Frame {frame_idx})')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.legend()
plt.show()

# %%
import torch
import sys
import onnx
import onnxruntime

# 1. Load your trained model (make sure it's in eval mode)
model.eval()

# 2. NUEVO: Creamos el dummy input con 4 dimensiones: 
# [Batch=1, Seq_Len=5, Vertices=num_vertices, Features=num_features]
dummy_input = torch.randn(1, 5, num_vertices, num_features)

# 3. Export to ONNX (el resto se mantiene igual)
onnx_program = torch.onnx.export(
    model,                      
    dummy_input,                # Tu [1, 5, 6, 4]
    "cloth_BIG_rnn.onnx", 
    export_params=True,         
    opset_version=15,           # <--- Subir a 15
    input_names=['input'],      
    output_names=['output'],    
)

print("Exported to ONNX with strict 4D sequential shapes!")
# Out:
# Exported to ONNX with strict 4D sequential shapes!
